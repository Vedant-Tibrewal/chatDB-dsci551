# %%
import mysql.connector
import json
from pymongo import MongoClient
import pandas as pd

# %%
#Healthcare Schema

SQL = {
  "hospitals": {
    "pk": ["admissionid"],
    "fk": {
      "patients": "patientid",
      "insurance": "insuranceid"
    },
    "admissionid": "INT",
    "patientid": "INT",
    "insuranceid": "INT",
    "doctor": "VARCHAR(255)",
    "hospitalname": "VARCHAR(255)",
    "intakedate": "DATE",
    "dischargedate": "DATE",
    "roomnumber": "INT",
    "carelevel": "VARCHAR(50)",
    "testresults": "VARCHAR(50)"
  },

  "patients": {
    "pk": ["patientid"],
    "fk": {},
    "patientid": "INT",
    "patientname": "VARCHAR(255)",
    "age": "INT",
    "gender": "VARCHAR(10)",
    "bloodtype": "VARCHAR(5)",
    "disease": "VARCHAR(255)"
  },

  "insurance": {
    "pk": ["insuranceid"],
    "fk": {
      "patients": "patientid"
    },
    "insuranceid": "INT",
    "patientid": "INT",
    "insuranceprovider": "VARCHAR(255)",
    "billingcost": "DECIMAL(10, 2)",
    "benefit": "VARCHAR(50)"
  },

  "prescriptions": {
    "pk": ["prescriptionid"],
    "fk": {
      "patients": "patientid"
    },
    "prescriptionid": "INT",
    "patientid": "INT",
    "medication": "VARCHAR(255)",
    "drug_quantity": "VARCHAR(50)"
  }
}

# %%
new_schema = dict()

# %%
def show_tables_and_primary_keys(db_config):
    try:
        # Establish a connection to the MySQL database
        conn = mysql.connector.connect(**db_config)
        cursor = conn.cursor()

        # Query to retrieve tables and their primary keys
        query = """
        SELECT 
            tab.table_name,
            GROUP_CONCAT(kcu.column_name ORDER BY kcu.ordinal_position SEPARATOR ', ') AS primary_keys
        FROM 
            information_schema.tables tab
        LEFT JOIN 
            information_schema.table_constraints tco
            ON tab.table_schema = tco.table_schema
            AND tab.table_name = tco.table_name
            AND tco.constraint_type = 'PRIMARY KEY'
        LEFT JOIN 
            information_schema.key_column_usage kcu
            ON tco.constraint_schema = kcu.constraint_schema
            AND tco.constraint_name = kcu.constraint_name
            AND tco.table_name = kcu.table_name
        WHERE 
            tab.table_schema = %s
        GROUP BY 
            tab.table_schema,
            tab.table_name
        ORDER BY 
            tab.table_name;
        """

        # Execute the query
        cursor.execute(query, (db_config['database'],))
        
        # Fetch all results
        results = cursor.fetchall()

        pk = []
        # Print the results
        print(f"Tables and Primary Keys in database '{db_config['database']}':")
        for table_name, primary_keys in results:
            pk.append((table_name, primary_keys))
            if primary_keys:
                print(f"Table: {table_name}, Primary Key(s): {primary_keys}")
            else:
                print(f"Table: {table_name}, No Primary Key")

    except mysql.connector.Error as err:
        print(f"Error: {err}")
    finally:
        # Close the connection
        if conn.is_connected():
            cursor.close()
            conn.close()

    return pk
# Usage example:
# db_config = {
#     'host': 'localhost',
#     'user': 'your_username',
#     'password': 'your_password',
#     'database': 'your_database_name'
# }
# show_tables_and_primary_keys(db_config)

# %%
import pandas as pd
import mysql.connector
import re

def normalize_column_names(df):
    normalized_columns = []
    for col in df.columns:
        normalized_col = col.lower()  # Convert to lower case
        normalized_col = re.sub(r'\s+|\W+', '_', normalized_col)  # Replace spaces and special characters
        normalized_columns.append(normalized_col)
    df.columns = normalized_columns
    return df

def infer_mysql_datatype(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'VARCHAR(255)'

def insert_csv_to_mysql(csv_file, db_config, table_name, db_schema):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    df = normalize_column_names(df)
    # Establish a connection to the MySQL database
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor()
    
    # Check if the table exists
    cursor.execute(f"SHOW TABLES LIKE '{table_name}'")
    table_exists = cursor.fetchone()
    
    if not table_exists:
    # Create the table
        columns = df.columns.tolist()
        sql_types = {col: infer_mysql_datatype(dtype) for col, dtype in df.dtypes.items()}
        column_definitions = [f"{col} {sql_types[col]}" for col in columns]
        db_schema[table_name] = {}
        db_schema[table_name] = {**sql_types}

        pk_columns = ["Create new auto-increment primary key"] + columns
        
        # Ask user to select primary key
        print("Select the primary key column:")
        for i, col in enumerate(pk_columns):
            print(f"{i}. {col}")
        pk_choice = int(input("Enter the number of the primary key column: "))
        
        db_schema[table_name]["pk"] = []
        if pk_choice == 0:
            column_definitions.insert(0, "id INT AUTO_INCREMENT PRIMARY KEY")
            db_schema[table_name]["pk"].append("id")

        else:
            db_schema[table_name]["pk"].append(columns[pk_choice - 1])
            column_definitions[pk_choice - 1] += " PRIMARY KEY"
        
        # Ask user if they want to add a foreign key
        db_schema[table_name]["fk"] = dict()
        add_fk = input("Do you want to add a foreign key? (y/n): ").lower() == 'y'
        if add_fk:
            fk_num = int(input("how many foreign keys present?"))
            print("select foreign table and its primary key")
            primary_keys = show_tables_and_primary_keys(db_config)
            for i, table in enumerate(primary_keys):
                print(f"{i}. {table}")

            fk_definition = ""

            while fk_num>0:

                fk_choice = int(input("Enter the number of the table and pk associated: "))
                
                fk_table = primary_keys[fk_choice][0]
                fk_ref_column = primary_keys[fk_choice][1]
                db_schema[table_name]["fk"][fk_table] = fk_ref_column
                fk_column = input("Enter the name of the foreign key column in current table: ")
                fk_definition += f", FOREIGN KEY ({fk_column}) REFERENCES {fk_table}({fk_ref_column})"
                fk_num -= 1
        else:
            fk_definition = ""

        
        # Create table SQL
        create_table_sql = f""" 
        CREATE TABLE {table_name} (
            {', '.join(column_definitions)}
            {fk_definition}
        )
        """
        cursor.execute(create_table_sql)
        print(f"Table {table_name} created successfully.")
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        columns = ', '.join(df.columns)
        placeholders = ', '.join(['%s'] * len(df.columns))
        sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))
    
    # Commit the transaction and close the connection
    conn.commit()
    cursor.close()
    conn.close()
    print(f"Data inserted into {table_name} successfully.")

# %%
def insert_csv_to_mysql(csv_file, db_config, table_name, db_schema):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    df = normalize_column_names(df)
    # Establish a connection to the MySQL database
    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor()
    
    # Check if the table exists
    cursor.execute(f"SHOW TABLES LIKE '{table_name}'")
    table_exists = cursor.fetchone()
    
    if not table_exists:
    # Create the table
        columns = df.columns.tolist()
        sql_types = {col: infer_mysql_datatype(dtype) for col, dtype in df.dtypes.items()}
        column_definitions = [f"{col} {sql_types[col]}" for col in columns]
        db_schema[table_name] = {}
        db_schema[table_name] = {**sql_types}

        pk_columns = ["Create new auto-increment primary key"] + columns
        
        # Ask user to select primary key
        print("Select the primary key column:")
        for i, col in enumerate(pk_columns):
            print(f"{i}. {col}")
        pk_choice = int(input("Enter the number of the primary key column: "))
        
        db_schema[table_name]["pk"] = []
        if pk_choice == 0:
            column_definitions.insert(0, "id INT AUTO_INCREMENT PRIMARY KEY")
            db_schema[table_name]["pk"].append("id")

        else:
            db_schema[table_name]["pk"].append(columns[pk_choice - 1])
            column_definitions[pk_choice - 1] += " PRIMARY KEY"
        
        # Ask user if they want to add a foreign key
        db_schema[table_name]["fk"] = dict()
        add_fk = input("Do you want to add a foreign key? (y/n): ").lower() == 'y'
        if add_fk:
            fk_num = int(input("how many foreign keys present?"))
            print("select foreign table and its primary key")
            primary_keys = show_tables_and_primary_keys(db_config)
            for i, table in enumerate(primary_keys):
                print(f"{i}. {table}")

            fk_definition = ""

            while fk_num>0:

                fk_choice = int(input("Enter the number of the table and pk associated: "))
                
                fk_table = primary_keys[fk_choice][0]
                fk_ref_column = primary_keys[fk_choice][1]
                db_schema[table_name]["fk"][fk_table] = fk_ref_column
                fk_column = input("Enter the name of the foreign key column in current table: ")
                fk_definition += f", FOREIGN KEY ({fk_column}) REFERENCES {fk_table}({fk_ref_column})"
                fk_num -= 1
        else:
            fk_definition = ""

        
        # Create table SQL
        create_table_sql = f""" 
        CREATE TABLE {table_name} (
            {', '.join(column_definitions)}
            {fk_definition}
        )
        """
        cursor.execute(create_table_sql)
        print(f"Table {table_name} created successfully.")
    # Insert DataFrame records one by one
    for _, row in df.iterrows():
        columns = ', '.join(df.columns)
        placeholders = ', '.join(['%s'] * len(df.columns))
        sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
        cursor.execute(sql, tuple(row))
    
    # Commit the transaction and close the connection
    conn.commit()
    cursor.close()
    conn.close()
    print(f"Data inserted into {table_name} successfully.")

# %%
db_config = {
    "user": "root",
    "password": "Ptjthtvtag123@@",
    "host": "127.0.0.1",
    "database": "chatdb",
    "raise_on_warnings": True}
insert_csv_to_mysql("patients_table.csv", db_config, "patients", new_schema)
# Out:
# Select the primary key column:
# 0. Create new auto-increment primary key
# 1. patientid
# 2. patientname
# 3. age
# 4. gender
# 5. bloodtype
# 6. disease
# Table patients created successfully.
# Data inserted into patients successfully.

# %%
new_schema
# Out:
# {'patients': {'patientid': 'INT',
#   'patientname': 'VARCHAR(255)',
#   'age': 'INT',
#   'gender': 'VARCHAR(255)',
#   'bloodtype': 'VARCHAR(255)',
#   'disease': 'VARCHAR(255)',
#   'pk': ['patientid'],
#   'fk': {}}}

# %%
db_config = {
    "user": "root",
    "password": "Ptjthtvtag123@@",
    "host": "127.0.0.1",
    "database": "chatdb",
    "raise_on_warnings": True}
insert_csv_to_mysql("insurance_table.csv", db_config, "insurance", new_schema)
# Out:
# Select the primary key column:
# 0. Create new auto-increment primary key
# 1. insuranceid
# 2. patientid
# 3. insuranceprovider
# 4. billingcost
# 5. benefit
# select foreign table and its primary key
# Tables and Primary Keys in database 'chatdb':
# Table: patients, Primary Key(s): patientid
# 0. ('patients', 'patientid')
# Table insurance created successfully.
# Data inserted into insurance successfully.

# %%
new_schema
# Out:
# {'patients': {'patientid': 'INT',
#   'patientname': 'VARCHAR(255)',
#   'age': 'INT',
#   'gender': 'VARCHAR(255)',
#   'bloodtype': 'VARCHAR(255)',
#   'disease': 'VARCHAR(255)',
#   'pk': ['patientid'],
#   'fk': {}},
#  'insurance': {'insuranceid': 'INT',
#   'patientid': 'INT',
#   'insuranceprovider': 'VARCHAR(255)',
#   'billingcost': 'FLOAT',
#   'benefit': 'VARCHAR(255)',
#   'pk': ['insuranceid'],
#   'fk': {'patients': 'patientid'}}}

# %%
db_config = {
    "user": "root",
    "password": "Ptjthtvtag123@@",
    "host": "127.0.0.1",
    "database": "chatdb",
    "raise_on_warnings": True}
insert_csv_to_mysql("hospitals_table.csv", db_config, "hospitals", new_schema)
# Out:
# Select the primary key column:
# 0. Create new auto-increment primary key
# 1. admissionid
# 2. patientid
# 3. insuranceid
# 4. doctor
# 5. hospitalname
# 6. intakedate
# 7. dischargedate
# 8. roomnumber
# 9. carelevel
# 10. testresults
# select foreign table and its primary key
# Tables and Primary Keys in database 'chatdb':
# Table: insurance, Primary Key(s): insuranceid
# Table: patients, Primary Key(s): patientid
# 0. ('insurance', 'insuranceid')
# 1. ('patients', 'patientid')
# Table hospitals created successfully.
# Data inserted into hospitals successfully.

# %%
new_schema
# Out:
# {'patients': {'patientid': 'INT',
#   'patientname': 'VARCHAR(255)',
#   'age': 'INT',
#   'gender': 'VARCHAR(255)',
#   'bloodtype': 'VARCHAR(255)',
#   'disease': 'VARCHAR(255)',
#   'pk': ['patientid'],
#   'fk': {}},
#  'insurance': {'insuranceid': 'INT',
#   'patientid': 'INT',
#   'insuranceprovider': 'VARCHAR(255)',
#   'billingcost': 'FLOAT',
#   'benefit': 'VARCHAR(255)',
#   'pk': ['insuranceid'],
#   'fk': {'patients': 'patientid'}},
#  'hospitals': {'admissionid': 'INT',
#   'patientid': 'INT',
#   'insuranceid': 'INT',
#   'doctor': 'VARCHAR(255)',
#   'hospitalname': 'VARCHAR(255)',
#   'intakedate': 'VARCHAR(255)',
#   'dischargedate': 'VARCHAR(255)',
#   'roomnumber': 'INT',
#   'carelevel': 'VARCHAR(255)',
#   'testresults': 'VARCHAR(255)',
#   'pk': ['admissionid'],
#   'fk': {'insurance': 'insuranceid', 'patients': 'patientid'}}}

# %% [markdown]
# ## MongoDB

# %%
import pandas as pd
import json

def csv_to_json_mongo(csv_file, save_file, primary_key):
    # Read the CSV file using Pandas
    data = pd.read_csv(csv_file)
    
    # Convert the DataFrame to a list of dictionaries (JSON format)
    json_output = data.to_dict(orient='records')
    
    # Convert lists of values into MongoDB accepted format
    json_ready = []
    for record in json_output:
        json_ready.append({key: value for key, value in record.items() if pd.notna(value)})  # remove NaN values
    for record in json_ready:
        record['_id'] = record[primary_key]

    with open(save_file, 'w') as file:
        json.dump(json_ready, file, indent=4)
    
    return json_ready

# %%
csv_to_json_mongo("patients_table.csv", "patients.json", "patientid")
# Out:
# [{'patientid': 1,
#   'patientname': 'BobbyJacksOn',
#   'age': 30,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 1},
#  {'patientid': 2,
#   'patientname': 'LesLieTErRy',
#   'age': 62,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 2},
#  {'patientid': 3,
#   'patientname': 'DaNnYsMitH',
#   'age': 76,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 3},
#  {'patientid': 4,
#   'patientname': 'andrEwwaTtS',
#   'age': 28,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 4},
#  {'patientid': 5,
#   'patientname': 'adrIENNEbEll',
#   'age': 43,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 5},
#  {'patientid': 6,
#   'patientname': 'EMILYJOHNSOn',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 6},
#  {'patientid': 7,
#   'patientname': 'edwArDEDWaRDs',
#   'age': 21,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 7},
#  {'patientid': 8,
#   'patientname': 'CHrisTInAMARtinez',
#   'age': 20,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 8},
#  {'patientid': 9,
#   'patientname': 'JASmINeaGuIlaR',
#   'age': 82,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 9},
#  {'patientid': 10,
#   'patientname': 'ChRISTopherBerG',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 10},
#  {'patientid': 11,
#   'patientname': 'mIchElLedaniELs',
#   'age': 72,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 11},
#  {'patientid': 12,
#   'patientname': 'aaRonMARtiNeZ',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 12},
#  {'patientid': 13,
#   'patientname': 'connORHANsEn',
#   'age': 75,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 13},
#  {'patientid': 14,
#   'patientname': 'rObeRtbAuer',
#   'age': 68,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 14},
#  {'patientid': 15,
#   'patientname': 'bROOkEbrady',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 15},
#  {'patientid': 16,
#   'patientname': 'MS.nAtalIEgAMble',
#   'age': 46,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Obesity',
#   '_id': 16},
#  {'patientid': 17,
#   'patientname': 'haleyperkins',
#   'age': 63,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 17},
#  {'patientid': 18,
#   'patientname': 'mRS.jamiEcAMPBELl',
#   'age': 38,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Obesity',
#   '_id': 18},
#  {'patientid': 19,
#   'patientname': 'LuKEBuRgEss',
#   'age': 34,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 19},
#  {'patientid': 20,
#   'patientname': 'dANIELschmIdt',
#   'age': 63,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 20},
#  {'patientid': 21,
#   'patientname': 'tIMOTHYburNs',
#   'age': 67,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 21},
#  {'patientid': 22,
#   'patientname': 'ChRISToPHErBRiGhT',
#   'age': 48,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 22},
#  {'patientid': 23,
#   'patientname': 'KatHRYnStewArt',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 23},
#  {'patientid': 24,
#   'patientname': 'dR.EilEEnthomPsoN',
#   'age': 59,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 24},
#  {'patientid': 25,
#   'patientname': 'PAUlhEndERsOn',
#   'age': 72,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 25},
#  {'patientid': 26,
#   'patientname': 'PeTERfiTzgeRaLd',
#   'age': 73,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 26},
#  {'patientid': 27,
#   'patientname': 'cathysMaLl',
#   'age': 51,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 27},
#  {'patientid': 28,
#   'patientname': 'mr.KenNEthMoORE',
#   'age': 34,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 28},
#  {'patientid': 29,
#   'patientname': 'MaRyhUNter',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 29},
#  {'patientid': 30,
#   'patientname': 'jOSHUAOLiVer',
#   'age': 63,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 30},
#  {'patientid': 31,
#   'patientname': 'ThOMASMartInEZ',
#   'age': 34,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 31},
#  {'patientid': 32,
#   'patientname': 'JAmESpattERson',
#   'age': 23,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 32},
#  {'patientid': 33,
#   'patientname': 'WilLIAMcOOPEr',
#   'age': 78,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 33},
#  {'patientid': 34,
#   'patientname': 'ErinoRTEga',
#   'age': 43,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 34},
#  {'patientid': 35,
#   'patientname': 'NicOlERodriGUEz',
#   'age': 30,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Diabetes',
#   '_id': 35},
#  {'patientid': 36,
#   'patientname': 'DAvIDAndErSON',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 36},
#  {'patientid': 37,
#   'patientname': 'DEnIseToRRES',
#   'age': 33,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Diabetes',
#   '_id': 37},
#  {'patientid': 38,
#   'patientname': 'CasSAndrARobinson',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 38},
#  {'patientid': 39,
#   'patientname': 'NIcOlELUcErO',
#   'age': 70,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 39},
#  {'patientid': 40,
#   'patientname': 'PAmelafErNanDeZ',
#   'age': 57,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 40},
#  {'patientid': 41,
#   'patientname': 'chRiSTOPHerLEe',
#   'age': 74,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 41},
#  {'patientid': 42,
#   'patientname': 'ThomASmorsE',
#   'age': 81,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 42},
#  {'patientid': 43,
#   'patientname': 'Mr.eRiCLane',
#   'age': 49,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 43},
#  {'patientid': 44,
#   'patientname': 'KAThEriNESmiTH',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 44},
#  {'patientid': 45,
#   'patientname': 'pAULwILLiAmS',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 45},
#  {'patientid': 46,
#   'patientname': 'lYNnMaRtinez',
#   'age': 65,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 46},
#  {'patientid': 47,
#   'patientname': 'chRIsTOpHErCHaPmAN',
#   'age': 31,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 47},
#  {'patientid': 48,
#   'patientname': 'CHRisfRYe',
#   'age': 58,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 48},
#  {'patientid': 49,
#   'patientname': 'kyLEbEnneTT',
#   'age': 22,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 49},
#  {'patientid': 50,
#   'patientname': 'BRandOncoLLINS',
#   'age': 77,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 50},
#  {'patientid': 51,
#   'patientname': 'mIchaelLiU',
#   'age': 30,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 51},
#  {'patientid': 52,
#   'patientname': 'STepHaNiekEnt',
#   'age': 42,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 52},
#  {'patientid': 53,
#   'patientname': 'JessEBaNks',
#   'age': 67,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 53},
#  {'patientid': 54,
#   'patientname': 'PeGGYLEe',
#   'age': 24,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 54},
#  {'patientid': 55,
#   'patientname': 'TAmARahErNAndez',
#   'age': 84,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 55},
#  {'patientid': 56,
#   'patientname': 'mR.DAVIDpIERceMd',
#   'age': 73,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 56},
#  {'patientid': 57,
#   'patientname': 'beThaNYMoOrE',
#   'age': 55,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 57},
#  {'patientid': 58,
#   'patientname': 'MIChaelMIllS',
#   'age': 23,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 58},
#  {'patientid': 59,
#   'patientname': 'kyleWiley',
#   'age': 40,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 59},
#  {'patientid': 60,
#   'patientname': 'jACqUeLINEjORdaN',
#   'age': 51,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 60},
#  {'patientid': 61,
#   'patientname': 'ASHleYguTIERreZ',
#   'age': 83,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 61},
#  {'patientid': 62,
#   'patientname': 'KimScOtt',
#   'age': 63,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 62},
#  {'patientid': 63,
#   'patientname': 'tRAvIscarTeR',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 63},
#  {'patientid': 64,
#   'patientname': 'LArryrodgeRs',
#   'age': 23,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 64},
#  {'patientid': 65,
#   'patientname': 'NancyglOVeR',
#   'age': 58,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 65},
#  {'patientid': 66,
#   'patientname': 'JessIcaking',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 66},
#  {'patientid': 67,
#   'patientname': 'ChRiStOPhERgOnzAlez',
#   'age': 59,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 67},
#  {'patientid': 68,
#   'patientname': 'jOhNhARTmAN',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 68},
#  {'patientid': 69,
#   'patientname': 'MicHAElMillEr',
#   'age': 31,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 69},
#  {'patientid': 70,
#   'patientname': 'EricamyERS',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 70},
#  {'patientid': 71,
#   'patientname': 'cAROlPaTtERSoN',
#   'age': 29,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 71},
#  {'patientid': 72,
#   'patientname': 'JOSeLopEz',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 72},
#  {'patientid': 73,
#   'patientname': 'kEVInSiMmoNsJr.',
#   'age': 24,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 73},
#  {'patientid': 74,
#   'patientname': 'DuANeHaneY',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 74},
#  {'patientid': 75,
#   'patientname': 'JONathAnyaTeS',
#   'age': 57,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 75},
#  {'patientid': 76,
#   'patientname': 'johNTHoMaS',
#   'age': 74,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 76},
#  {'patientid': 77,
#   'patientname': 'AdriaNBuckLEY',
#   'age': 22,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 77},
#  {'patientid': 78,
#   'patientname': 'apRilSANTIAgO',
#   'age': 33,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 78},
#  {'patientid': 79,
#   'patientname': 'DIanescHultz',
#   'age': 57,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Arthritis',
#   '_id': 79},
#  {'patientid': 80,
#   'patientname': 'tiMOThYmyers',
#   'age': 61,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 80},
#  {'patientid': 81,
#   'patientname': 'NICOLEHUGhes',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 81},
#  {'patientid': 82,
#   'patientname': 'ChAdMorEnO',
#   'age': 67,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 82},
#  {'patientid': 83,
#   'patientname': 'SeaNjenniNGs',
#   'age': 80,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 83},
#  {'patientid': 84,
#   'patientname': 'DIAnEbrAnch',
#   'age': 44,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 84},
#  {'patientid': 85,
#   'patientname': 'cindYOROzco',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 85},
#  {'patientid': 86,
#   'patientname': 'pAtriCIaMEdinA',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 86},
#  {'patientid': 87,
#   'patientname': 'kayLapadillA',
#   'age': 63,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 87},
#  {'patientid': 88,
#   'patientname': 'JUanklEiN',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 88},
#  {'patientid': 89,
#   'patientname': 'wILLIAMhIlL',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 89},
#  {'patientid': 90,
#   'patientname': 'CARLBEst',
#   'age': 60,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 90},
#  {'patientid': 91,
#   'patientname': 'TInAGriFfin',
#   'age': 49,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 91},
#  {'patientid': 92,
#   'patientname': 'MR.TYlerTAYLORPhd',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 92},
#  {'patientid': 93,
#   'patientname': 'TAyLoRhoweLlDds',
#   'age': 35,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 93},
#  {'patientid': 94,
#   'patientname': 'mIcHAeLMaRTIn',
#   'age': 84,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 94},
#  {'patientid': 95,
#   'patientname': 'heatHERmIller',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 95},
#  {'patientid': 96,
#   'patientname': 'cathERinEgArDnEr',
#   'age': 79,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 96},
#  {'patientid': 97,
#   'patientname': 'ANNETHOMPSoN',
#   'age': 76,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 97},
#  {'patientid': 98,
#   'patientname': 'TOddcoopeR',
#   'age': 55,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 98},
#  {'patientid': 99,
#   'patientname': 'PhILLIPlyOnS',
#   'age': 53,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 99},
#  {'patientid': 100,
#   'patientname': 'MaRkfoRD',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 100},
#  {'patientid': 101,
#   'patientname': 'mARcUSZAmorA',
#   'age': 69,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 101},
#  {'patientid': 102,
#   'patientname': 'KaTiEhENry',
#   'age': 70,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 102},
#  {'patientid': 103,
#   'patientname': 'wilLIAmmorTON',
#   'age': 21,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 103},
#  {'patientid': 104,
#   'patientname': 'KaTRinamaRTin',
#   'age': 47,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 104},
#  {'patientid': 105,
#   'patientname': 'HunTeRmckAy',
#   'age': 85,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 105},
#  {'patientid': 106,
#   'patientname': 'dWAYnEDAViS',
#   'age': 28,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 106},
#  {'patientid': 107,
#   'patientname': 'sARAHCalDweLL',
#   'age': 62,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 107},
#  {'patientid': 108,
#   'patientname': 'DAVidhiggInS',
#   'age': 49,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 108},
#  {'patientid': 109,
#   'patientname': 'bRADlEYcoMbS',
#   'age': 52,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 109},
#  {'patientid': 110,
#   'patientname': 'chrisTiNaSChMitt',
#   'age': 53,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 110},
#  {'patientid': 111,
#   'patientname': 'coLtoNstRONg',
#   'age': 55,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 111},
#  {'patientid': 112,
#   'patientname': 'MARKpriCE',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 112},
#  {'patientid': 113,
#   'patientname': 'sUZaNnESchNeIder',
#   'age': 52,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 113},
#  {'patientid': 114,
#   'patientname': 'MIchaELHUrLEY',
#   'age': 67,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Obesity',
#   '_id': 114},
#  {'patientid': 115,
#   'patientname': 'LIndsEylaMbErt',
#   'age': 82,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 115},
#  {'patientid': 116,
#   'patientname': 'reBEcCAPARsONs',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 116},
#  {'patientid': 117,
#   'patientname': 'jUdyjoHNsoN',
#   'age': 52,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 117},
#  {'patientid': 118,
#   'patientname': 'TOnyAcaMpbell',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 118},
#  {'patientid': 119,
#   'patientname': 'JAMEsRoss',
#   'age': 83,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 119},
#  {'patientid': 120,
#   'patientname': 'SaRACOOk',
#   'age': 33,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 120},
#  {'patientid': 121,
#   'patientname': 'annEhoweLl',
#   'age': 22,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 121},
#  {'patientid': 122,
#   'patientname': 'RENEEbAilEY',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 122},
#  {'patientid': 123,
#   'patientname': 'JeffreytuRNER',
#   'age': 85,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 123},
#  {'patientid': 124,
#   'patientname': 'DR.LaUreNClaRkDDs',
#   'age': 19,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 124},
#  {'patientid': 125,
#   'patientname': 'terRYTHoMaS',
#   'age': 50,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 125},
#  {'patientid': 126,
#   'patientname': 'JasOnbaKEr',
#   'age': 50,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 126},
#  {'patientid': 127,
#   'patientname': 'JEssicAgUtiERrEz',
#   'age': 40,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 127},
#  {'patientid': 128,
#   'patientname': 'COURTNeyHOdGes',
#   'age': 57,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Obesity',
#   '_id': 128},
#  {'patientid': 129,
#   'patientname': 'ANthONyreYEs',
#   'age': 82,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 129},
#  {'patientid': 130,
#   'patientname': 'LeaHcRoSsDds',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Diabetes',
#   '_id': 130},
#  {'patientid': 131,
#   'patientname': 'PaULMaRTinEz',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 131},
#  {'patientid': 132,
#   'patientname': 'DenisErOdRIGuEZ',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 132},
#  {'patientid': 133,
#   'patientname': 'ashLEyERIcKSoN',
#   'age': 32,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 133},
#  {'patientid': 134,
#   'patientname': 'SEaNcarDenaS',
#   'age': 55,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 134},
#  {'patientid': 135,
#   'patientname': 'aLaNAlVaREz',
#   'age': 81,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 135},
#  {'patientid': 136,
#   'patientname': 'JeSsICAphiLliPS',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 136},
#  {'patientid': 137,
#   'patientname': 'tiMOthYCoLemaN',
#   'age': 54,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 137},
#  {'patientid': 138,
#   'patientname': 'cHristinawooDS',
#   'age': 57,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 138},
#  {'patientid': 139,
#   'patientname': 'mELIssasCOtt',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 139},
#  {'patientid': 140,
#   'patientname': 'GaRyhoPkiNS',
#   'age': 54,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 140},
#  {'patientid': 141,
#   'patientname': 'aPRILVAleNCIA',
#   'age': 42,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 141},
#  {'patientid': 142,
#   'patientname': 'riTAarchER',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 142},
#  {'patientid': 143,
#   'patientname': 'kImPenA',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 143},
#  {'patientid': 144,
#   'patientname': 'jaSoNFOlEy',
#   'age': 54,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 144},
#  {'patientid': 145,
#   'patientname': 'ShAUNGuzmAn',
#   'age': 21,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 145},
#  {'patientid': 146,
#   'patientname': 'MATTHeWwHite',
#   'age': 45,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Diabetes',
#   '_id': 146},
#  {'patientid': 147,
#   'patientname': 'aLExiSwilsOn',
#   'age': 68,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Arthritis',
#   '_id': 147},
#  {'patientid': 148,
#   'patientname': 'JaCQueLiNEmaRshAll',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 148},
#  {'patientid': 149,
#   'patientname': 'RoBErthIGGInS',
#   'age': 42,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 149},
#  {'patientid': 150,
#   'patientname': 'SierRaMoRTON',
#   'age': 27,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 150},
#  {'patientid': 151,
#   'patientname': 'nATAliEsTANtoN',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 151},
#  {'patientid': 152,
#   'patientname': 'jEssicaaceveDo',
#   'age': 21,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 152},
#  {'patientid': 153,
#   'patientname': 'JENnIfErmCmillan',
#   'age': 84,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 153},
#  {'patientid': 154,
#   'patientname': 'ChRISTophermccLAiN',
#   'age': 67,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 154},
#  {'patientid': 155,
#   'patientname': 'kevInHiCKs',
#   'age': 66,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 155},
#  {'patientid': 156,
#   'patientname': 'MELIndArichARds',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 156},
#  {'patientid': 157,
#   'patientname': 'roBYnmiRaNDa',
#   'age': 30,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 157},
#  {'patientid': 158,
#   'patientname': 'scoTtcaSTillO',
#   'age': 78,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 158},
#  {'patientid': 159,
#   'patientname': 'jOHNGarciA',
#   'age': 39,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 159},
#  {'patientid': 160,
#   'patientname': 'miCHAeLTayloR',
#   'age': 29,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 160},
#  {'patientid': 161,
#   'patientname': 'jeFfReYWoOd',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 161},
#  {'patientid': 162,
#   'patientname': 'MiCHAElsmIth',
#   'age': 66,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Obesity',
#   '_id': 162},
#  {'patientid': 163,
#   'patientname': 'wiLLiamgrIFfItH',
#   'age': 65,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 163},
#  {'patientid': 164,
#   'patientname': 'CHrISTiNalAwReNCe',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 164},
#  {'patientid': 165,
#   'patientname': 'jeSsiCAHolmeS',
#   'age': 72,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 165},
#  {'patientid': 166,
#   'patientname': 'traCEYgrEenE',
#   'age': 85,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Cancer',
#   '_id': 166},
#  {'patientid': 167,
#   'patientname': 'aMAndalOpeZ',
#   'age': 68,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 167},
#  {'patientid': 168,
#   'patientname': 'LaurApEtErS',
#   'age': 56,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 168},
#  {'patientid': 169,
#   'patientname': 'LAUrEnANDErSOn',
#   'age': 53,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 169},
#  {'patientid': 170,
#   'patientname': 'wILliAmCAmpos',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 170},
#  {'patientid': 171,
#   'patientname': 'jEssiCaGoNzAleS',
#   'age': 57,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 171},
#  {'patientid': 172,
#   'patientname': 'brUcEgOnzaleS',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 172},
#  {'patientid': 173,
#   'patientname': 'rOBertWAlsH',
#   'age': 20,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 173},
#  {'patientid': 174,
#   'patientname': 'lIsALeWis',
#   'age': 83,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 174},
#  {'patientid': 175,
#   'patientname': 'WiLlIaMRUiZ',
#   'age': 79,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 175},
#  {'patientid': 176,
#   'patientname': 'StEvenBALdWIn',
#   'age': 62,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 176},
#  {'patientid': 177,
#   'patientname': 'meGAnCoLON',
#   'age': 38,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 177},
#  {'patientid': 178,
#   'patientname': 'kImbErlYbrOoks',
#   'age': 75,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 178},
#  {'patientid': 179,
#   'patientname': 'EdWARdSMiThjR.',
#   'age': 28,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 179},
#  {'patientid': 180,
#   'patientname': 'aLliSoNCorDoVA',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 180},
#  {'patientid': 181,
#   'patientname': 'lINdATHOMAs',
#   'age': 54,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 181},
#  {'patientid': 182,
#   'patientname': 'paRkErmoOrE',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 182},
#  {'patientid': 183,
#   'patientname': 'tanyaSOto',
#   'age': 56,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 183},
#  {'patientid': 184,
#   'patientname': 'mIChaELjOrdaN',
#   'age': 30,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 184},
#  {'patientid': 185,
#   'patientname': 'ChRiSTINAMArTin',
#   'age': 64,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 185},
#  {'patientid': 186,
#   'patientname': 'TrACyBUrke',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 186},
#  {'patientid': 187,
#   'patientname': 'daVIDSPeNCE',
#   'age': 21,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Diabetes',
#   '_id': 187},
#  {'patientid': 188,
#   'patientname': 'JOsEphfOstER',
#   'age': 59,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 188},
#  {'patientid': 189,
#   'patientname': 'NIcholAshaLl',
#   'age': 31,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 189},
#  {'patientid': 190,
#   'patientname': 'ChriSTiNAmaCiAS',
#   'age': 36,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 190},
#  {'patientid': 191,
#   'patientname': 'scoTTJoNes',
#   'age': 42,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 191},
#  {'patientid': 192,
#   'patientname': 'jaMEsAnDerSon',
#   'age': 18,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 192},
#  {'patientid': 193,
#   'patientname': 'sHaUNLonG',
#   'age': 62,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 193},
#  {'patientid': 194,
#   'patientname': 'krIStInAmorA',
#   'age': 53,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 194},
#  {'patientid': 195,
#   'patientname': 'joshUarIcHmOnd',
#   'age': 82,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 195},
#  {'patientid': 196,
#   'patientname': 'MarklAWrencE',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 196},
#  {'patientid': 197,
#   'patientname': 'JOhNeLlis',
#   'age': 83,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 197},
#  {'patientid': 198,
#   'patientname': 'MRs.TiFFAnyDeNnIs',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 198},
#  {'patientid': 199,
#   'patientname': 'cyNTHIaHuANG',
#   'age': 51,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 199},
#  {'patientid': 200,
#   'patientname': 'meLiSSALawRENcE',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 200},
#  {'patientid': 201,
#   'patientname': 'STEvEngoodwIN',
#   'age': 61,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 201},
#  {'patientid': 202,
#   'patientname': 'mARYHuNT',
#   'age': 44,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 202},
#  {'patientid': 203,
#   'patientname': 'ERicriveRa',
#   'age': 74,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 203},
#  {'patientid': 204,
#   'patientname': 'ALAntayLor',
#   'age': 82,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 204},
#  {'patientid': 205,
#   'patientname': 'mIcHaELcAMPbeLl',
#   'age': 83,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 205},
#  {'patientid': 206,
#   'patientname': 'asHLEYwebbddS',
#   'age': 62,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 206},
#  {'patientid': 207,
#   'patientname': 'SHaNNONbroWn',
#   'age': 62,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 207},
#  {'patientid': 208,
#   'patientname': 'LAwrenCEshEPherD',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 208},
#  {'patientid': 209,
#   'patientname': 'scoTtwADE',
#   'age': 66,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 209},
#  {'patientid': 210,
#   'patientname': 'heAthERcurTis',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 210},
#  {'patientid': 211,
#   'patientname': 'kEvINjEFFeRsON',
#   'age': 45,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 211},
#  {'patientid': 212,
#   'patientname': 'dAvIdgRifFIn',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 212},
#  {'patientid': 213,
#   'patientname': 'GRanTGeoRge',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 213},
#  {'patientid': 214,
#   'patientname': 'eRIcSteWART',
#   'age': 79,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 214},
#  {'patientid': 215,
#   'patientname': 'RoBErtpittmAn',
#   'age': 33,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 215},
#  {'patientid': 216,
#   'patientname': 'SYdNeyCross',
#   'age': 34,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 216},
#  {'patientid': 217,
#   'patientname': 'DaviDCrawfoRD',
#   'age': 76,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 217},
#  {'patientid': 218,
#   'patientname': 'LEAHDRaKE',
#   'age': 50,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 218},
#  {'patientid': 219,
#   'patientname': 'DiAnahALL',
#   'age': 44,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 219},
#  {'patientid': 220,
#   'patientname': 'JUsTINlE',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 220},
#  {'patientid': 221,
#   'patientname': 'KaREnpricEdDs',
#   'age': 43,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 221},
#  {'patientid': 222,
#   'patientname': 'CaROlYNsTEeLE',
#   'age': 27,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 222},
#  {'patientid': 223,
#   'patientname': 'LAURenRAMireZ',
#   'age': 78,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 223},
#  {'patientid': 224,
#   'patientname': 'jAcObnEWman',
#   'age': 40,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 224},
#  {'patientid': 225,
#   'patientname': 'KAThErInEBARnEtt',
#   'age': 25,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 225},
#  {'patientid': 226,
#   'patientname': 'JODImartiNeZ',
#   'age': 67,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 226},
#  {'patientid': 227,
#   'patientname': 'andrEaaLlEN',
#   'age': 47,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 227},
#  {'patientid': 228,
#   'patientname': 'nOahbaxtEr',
#   'age': 75,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 228},
#  {'patientid': 229,
#   'patientname': 'hECTORMAXweLL',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 229},
#  {'patientid': 230,
#   'patientname': 'holLyWALters',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 230},
#  {'patientid': 231,
#   'patientname': 'JOsepHSmIth',
#   'age': 22,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 231},
#  {'patientid': 232,
#   'patientname': 'albERttHOmAS',
#   'age': 29,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 232},
#  {'patientid': 233,
#   'patientname': 'jeFfErYWIlliaMSOn',
#   'age': 30,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 233},
#  {'patientid': 234,
#   'patientname': 'joNAthAnmeADOWS',
#   'age': 22,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 234},
#  {'patientid': 235,
#   'patientname': 'kRIStINBeNnETT',
#   'age': 34,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 235},
#  {'patientid': 236,
#   'patientname': 'miCHaElSmITh',
#   'age': 20,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 236},
#  {'patientid': 237,
#   'patientname': 'JOSepHcARpenteR',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 237},
#  {'patientid': 238,
#   'patientname': 'larRyMaYEr',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 238},
#  {'patientid': 239,
#   'patientname': 'CLaYTONPEterSon',
#   'age': 45,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 239},
#  {'patientid': 240,
#   'patientname': 'donaLDaLVArEZ',
#   'age': 18,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 240},
#  {'patientid': 241,
#   'patientname': 'SaRAhleE',
#   'age': 56,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 241},
#  {'patientid': 242,
#   'patientname': 'joHNpeReZ',
#   'age': 44,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 242},
#  {'patientid': 243,
#   'patientname': 'TimothyjAcobS',
#   'age': 34,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 243},
#  {'patientid': 244,
#   'patientname': 'nAThaNsMall',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 244},
#  {'patientid': 245,
#   'patientname': 'dUSTinWriGhT',
#   'age': 32,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 245},
#  {'patientid': 246,
#   'patientname': 'jacObwilLiAMS',
#   'age': 64,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Arthritis',
#   '_id': 246},
#  {'patientid': 247,
#   'patientname': 'wiLlIAmmcCOY',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 247},
#  {'patientid': 248,
#   'patientname': 'dr.MATthEWwilkinS',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 248},
#  {'patientid': 249,
#   'patientname': 'JosEpHgONZaLeZ',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 249},
#  {'patientid': 250,
#   'patientname': 'rObErtfiElDS',
#   'age': 52,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 250},
#  {'patientid': 251,
#   'patientname': 'lawrencEmIRAndA',
#   'age': 83,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 251},
#  {'patientid': 252,
#   'patientname': 'mitCheLlcaRrOlL',
#   'age': 28,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 252},
#  {'patientid': 253,
#   'patientname': 'COdYnIcHoLs',
#   'age': 63,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 253},
#  {'patientid': 254,
#   'patientname': 'KELlItHompSOn',
#   'age': 85,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 254},
#  {'patientid': 255,
#   'patientname': 'dAnIEllelOPeZ',
#   'age': 37,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 255},
#  {'patientid': 256,
#   'patientname': 'melINdaJONES',
#   'age': 22,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 256},
#  {'patientid': 257,
#   'patientname': 'KRiSTINsMith',
#   'age': 80,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 257},
#  {'patientid': 258,
#   'patientname': 'StEphaniEREYNolDs',
#   'age': 48,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 258},
#  {'patientid': 259,
#   'patientname': 'AnNANORMaN',
#   'age': 29,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 259},
#  {'patientid': 260,
#   'patientname': 'MAriahaYeS',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 260},
#  {'patientid': 261,
#   'patientname': 'toNyariLEymD',
#   'age': 23,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 261},
#  {'patientid': 262,
#   'patientname': 'REgiNaDUnn',
#   'age': 33,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 262},
#  {'patientid': 263,
#   'patientname': 'mIcHaelJACoBS',
#   'age': 34,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 263},
#  {'patientid': 264,
#   'patientname': 'jaSonmOOrEmd',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 264},
#  {'patientid': 265,
#   'patientname': 'eRiCHALl',
#   'age': 84,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Diabetes',
#   '_id': 265},
#  {'patientid': 266,
#   'patientname': 'MALIkMARtINeZ',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 266},
#  {'patientid': 267,
#   'patientname': 'LisAKENNEdY',
#   'age': 42,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 267},
#  {'patientid': 268,
#   'patientname': 'kRIstInocHOA',
#   'age': 57,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Arthritis',
#   '_id': 268},
#  {'patientid': 269,
#   'patientname': 'joSephZuNiGA',
#   'age': 75,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 269},
#  {'patientid': 270,
#   'patientname': 'kYLeTYlER',
#   'age': 24,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 270},
#  {'patientid': 271,
#   'patientname': 'ericduNCan',
#   'age': 43,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 271},
#  {'patientid': 272,
#   'patientname': 'raChelroMERo',
#   'age': 22,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 272},
#  {'patientid': 273,
#   'patientname': 'mIcHaelanDeRson',
#   'age': 64,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 273},
#  {'patientid': 274,
#   'patientname': 'emILYclARK',
#   'age': 66,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 274},
#  {'patientid': 275,
#   'patientname': 'danIeLmCKINnEy',
#   'age': 19,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 275},
#  {'patientid': 276,
#   'patientname': 'BOnnIeWILlIaMS',
#   'age': 79,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 276},
#  {'patientid': 277,
#   'patientname': 'MARcUshenry',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 277},
#  {'patientid': 278,
#   'patientname': 'katheRiNEHART',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 278},
#  {'patientid': 279,
#   'patientname': 'MIchellepIeRCE',
#   'age': 62,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 279},
#  {'patientid': 280,
#   'patientname': 'JulieMejia',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 280},
#  {'patientid': 281,
#   'patientname': 'cAMeRoNsAnChEz',
#   'age': 49,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 281},
#  {'patientid': 282,
#   'patientname': 'davIdVincent',
#   'age': 66,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 282},
#  {'patientid': 283,
#   'patientname': 'MeLiSSAgOMez',
#   'age': 50,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 283},
#  {'patientid': 284,
#   'patientname': 'AMAnDapONCe',
#   'age': 39,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 284},
#  {'patientid': 285,
#   'patientname': 'CArOlGOMEz',
#   'age': 31,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 285},
#  {'patientid': 286,
#   'patientname': 'cHRISTopHErPalmER',
#   'age': 84,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 286},
#  {'patientid': 287,
#   'patientname': 'PAULHahn',
#   'age': 71,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Cancer',
#   '_id': 287},
#  {'patientid': 288,
#   'patientname': 'aSHLeYMOORe',
#   'age': 79,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 288},
#  {'patientid': 289,
#   'patientname': 'lINDahaMiLTOn',
#   'age': 56,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 289},
#  {'patientid': 290,
#   'patientname': 'robiNcoX',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 290},
#  {'patientid': 291,
#   'patientname': 'AnthoNYHalL',
#   'age': 38,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 291},
#  {'patientid': 292,
#   'patientname': 'roberTsmitH',
#   'age': 21,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 292},
#  {'patientid': 293,
#   'patientname': 'dEREKCARTER',
#   'age': 55,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 293},
#  {'patientid': 294,
#   'patientname': 'HEAthERMAY',
#   'age': 79,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 294},
#  {'patientid': 295,
#   'patientname': 'pETergOnzAlEZ',
#   'age': 55,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 295},
#  {'patientid': 296,
#   'patientname': 'chrIsflEtCheR',
#   'age': 24,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 296},
#  {'patientid': 297,
#   'patientname': 'sHIRleywiLkinsoN',
#   'age': 39,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 297},
#  {'patientid': 298,
#   'patientname': 'COurtNeyFaRRelL',
#   'age': 63,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 298},
#  {'patientid': 299,
#   'patientname': 'aNDReAWiLliS',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 299},
#  {'patientid': 300,
#   'patientname': 'cHADhuFF',
#   'age': 76,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 300},
#  {'patientid': 301,
#   'patientname': 'dEvingiLBert',
#   'age': 69,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 301},
#  {'patientid': 302,
#   'patientname': 'DOnALDdavIS',
#   'age': 38,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 302},
#  {'patientid': 303,
#   'patientname': 'KUrTmurphy',
#   'age': 19,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Hypertension',
#   '_id': 303},
#  {'patientid': 304,
#   'patientname': 'SYlviawEsT',
#   'age': 61,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 304},
#  {'patientid': 305,
#   'patientname': 'DONaLdvAZQuEZ',
#   'age': 42,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 305},
#  {'patientid': 306,
#   'patientname': 'REbeCCArUsH',
#   'age': 57,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 306},
#  {'patientid': 307,
#   'patientname': 'ChrIstoPhERcurRY',
#   'age': 36,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 307},
#  {'patientid': 308,
#   'patientname': 'miCHaeLEdwARds',
#   'age': 68,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 308},
#  {'patientid': 309,
#   'patientname': 'cHriSTOPheRARnoLd',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 309},
#  {'patientid': 310,
#   'patientname': 'RAcheLhickmAn',
#   'age': 37,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 310},
#  {'patientid': 311,
#   'patientname': 'ashlEYgrAy',
#   'age': 68,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 311},
#  {'patientid': 312,
#   'patientname': 'eLiZaBeThPeREz',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 312},
#  {'patientid': 313,
#   'patientname': 'ANgeLRaNDOlPHddS',
#   'age': 74,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 313},
#  {'patientid': 314,
#   'patientname': 'maRkSaUNderS',
#   'age': 75,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 314},
#  {'patientid': 315,
#   'patientname': 'ChriSTiAnlAnG',
#   'age': 74,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 315},
#  {'patientid': 316,
#   'patientname': 'PamperKIns',
#   'age': 28,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 316},
#  {'patientid': 317,
#   'patientname': 'kAyLAGrEENe',
#   'age': 35,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 317},
#  {'patientid': 318,
#   'patientname': 'mIcHAEldaVId',
#   'age': 79,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 318},
#  {'patientid': 319,
#   'patientname': 'aLeXIsmCcALl',
#   'age': 59,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 319},
#  {'patientid': 320,
#   'patientname': 'mr.brandONperEzmd',
#   'age': 84,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 320},
#  {'patientid': 321,
#   'patientname': 'dr.jeffREyColE',
#   'age': 36,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 321},
#  {'patientid': 322,
#   'patientname': 'maTthEwbroWN',
#   'age': 69,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 322},
#  {'patientid': 323,
#   'patientname': 'RoBErTsExtON',
#   'age': 54,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 323},
#  {'patientid': 324,
#   'patientname': 'ashLEyvasQUEZ',
#   'age': 30,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 324},
#  {'patientid': 325,
# ...
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 893},
#  {'patientid': 894,
#   'patientname': 'JeSsicARodRiGUeZ',
#   'age': 72,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 894},
#  {'patientid': 895,
#   'patientname': 'tiNAPriCE',
#   'age': 70,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 895},
#  {'patientid': 896,
#   'patientname': 'mR.jaCkwIlliS',
#   'age': 46,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 896},
#  {'patientid': 897,
#   'patientname': 'GreGoRYaDAMS',
#   'age': 82,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 897},
#  {'patientid': 898,
#   'patientname': 'DAVIdRObErtS',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 898},
#  {'patientid': 899,
#   'patientname': 'COryPERry',
#   'age': 34,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 899},
#  {'patientid': 900,
#   'patientname': 'JeSsicaBarrY',
#   'age': 49,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 900},
#  {'patientid': 901,
#   'patientname': 'cyNthIAthOmAs',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Cancer',
#   '_id': 901},
#  {'patientid': 902,
#   'patientname': 'sHannOnJOHnSOn',
#   'age': 37,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 902},
#  {'patientid': 903,
#   'patientname': 'jUSTInwhITE',
#   'age': 37,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 903},
#  {'patientid': 904,
#   'patientname': 'reGINAsTewarT',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 904},
#  {'patientid': 905,
#   'patientname': 'chelsEaFInLeY',
#   'age': 20,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 905},
#  {'patientid': 906,
#   'patientname': 'emmAbeNNeTt',
#   'age': 43,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Obesity',
#   '_id': 906},
#  {'patientid': 907,
#   'patientname': 'AlaNlEe',
#   'age': 57,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 907},
#  {'patientid': 908,
#   'patientname': 'KatELYnMiLler',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 908},
#  {'patientid': 909,
#   'patientname': 'aMandamorriS',
#   'age': 53,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 909},
#  {'patientid': 910,
#   'patientname': 'dAvIDpRatt',
#   'age': 45,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 910},
#  {'patientid': 911,
#   'patientname': 'MAtTheWcunnINGHAm',
#   'age': 21,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 911},
#  {'patientid': 912,
#   'patientname': 'bObBYCarSoN',
#   'age': 64,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 912},
#  {'patientid': 913,
#   'patientname': 'meliNdaWIlSOn',
#   'age': 71,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 913},
#  {'patientid': 914,
#   'patientname': 'NancYHaNSEn',
#   'age': 28,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 914},
#  {'patientid': 915,
#   'patientname': 'gReGoRYwALlS',
#   'age': 79,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 915},
#  {'patientid': 916,
#   'patientname': 'aMBerNiXoN',
#   'age': 40,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 916},
#  {'patientid': 917,
#   'patientname': 'KriStInfRancO',
#   'age': 50,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 917},
#  {'patientid': 918,
#   'patientname': 'JEremIAHvAZQuEz',
#   'age': 64,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 918},
#  {'patientid': 919,
#   'patientname': 'AnthONySmITH',
#   'age': 81,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 919},
#  {'patientid': 920,
#   'patientname': 'vIcToRiAbrADy',
#   'age': 52,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Hypertension',
#   '_id': 920},
#  {'patientid': 921,
#   'patientname': 'erINcLaRk',
#   'age': 76,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 921},
#  {'patientid': 922,
#   'patientname': 'hEAtHerBOyLe',
#   'age': 52,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Obesity',
#   '_id': 922},
#  {'patientid': 923,
#   'patientname': 'eLiZAbeTHShEPPARd',
#   'age': 77,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Cancer',
#   '_id': 923},
#  {'patientid': 924,
#   'patientname': 'roBErTboOne',
#   'age': 81,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 924},
#  {'patientid': 925,
#   'patientname': 'geoFFrEyDANiELs',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 925},
#  {'patientid': 926,
#   'patientname': 'joHNkhAn',
#   'age': 72,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 926},
#  {'patientid': 927,
#   'patientname': 'ChrISTopheRaRmSTRoNg',
#   'age': 70,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Diabetes',
#   '_id': 927},
#  {'patientid': 928,
#   'patientname': 'JeNNiFERlopez',
#   'age': 44,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Arthritis',
#   '_id': 928},
#  {'patientid': 929,
#   'patientname': 'mELISSaROBerTson',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 929},
#  {'patientid': 930,
#   'patientname': 'KArenPriCE',
#   'age': 41,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 930},
#  {'patientid': 931,
#   'patientname': 'LiSafRanKLin',
#   'age': 32,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 931},
#  {'patientid': 932,
#   'patientname': 'KRisTINBURtoN',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 932},
#  {'patientid': 933,
#   'patientname': 'caiTLinaDAms',
#   'age': 33,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 933},
#  {'patientid': 934,
#   'patientname': 'EvaNHeRnANDez',
#   'age': 80,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 934},
#  {'patientid': 935,
#   'patientname': 'jEnNiFerKNiGht',
#   'age': 67,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 935},
#  {'patientid': 936,
#   'patientname': 'BOnnIEWiLSon',
#   'age': 39,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Diabetes',
#   '_id': 936},
#  {'patientid': 937,
#   'patientname': 'kEnnEThraMIREZ',
#   'age': 52,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 937},
#  {'patientid': 938,
#   'patientname': 'ELleNmCCuLloUgh',
#   'age': 49,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 938},
#  {'patientid': 939,
#   'patientname': 'THomASSToNe',
#   'age': 41,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 939},
#  {'patientid': 940,
#   'patientname': 'katHLEEnArMstrong',
#   'age': 81,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Hypertension',
#   '_id': 940},
#  {'patientid': 941,
#   'patientname': 'tErrYBEnnetT',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 941},
#  {'patientid': 942,
#   'patientname': 'kRISTINNGuYeN',
#   'age': 83,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Hypertension',
#   '_id': 942},
#  {'patientid': 943,
#   'patientname': 'aNgElarANdOLph',
#   'age': 36,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 943},
#  {'patientid': 944,
#   'patientname': 'chrIsTOpHErtAtE',
#   'age': 43,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 944},
#  {'patientid': 945,
#   'patientname': 'chrisTopHeRwALToN',
#   'age': 72,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 945},
#  {'patientid': 946,
#   'patientname': 'mEAGANMIranDA',
#   'age': 73,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Asthma',
#   '_id': 946},
#  {'patientid': 947,
#   'patientname': 'dAvIdBrOwn',
#   'age': 32,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Cancer',
#   '_id': 947},
#  {'patientid': 948,
#   'patientname': 'EriCMilleR',
#   'age': 39,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 948},
#  {'patientid': 949,
#   'patientname': 'JoeLBaRTlEtT',
#   'age': 72,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Asthma',
#   '_id': 949},
#  {'patientid': 950,
#   'patientname': 'stAcYGIlLEspiE',
#   'age': 24,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 950},
#  {'patientid': 951,
#   'patientname': 'cINdySHaW',
#   'age': 32,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 951},
#  {'patientid': 952,
#   'patientname': 'AndreweriCKsON',
#   'age': 57,
#   'gender': 'Female',
#   'bloodtype': 'AB+',
#   'disease': 'Asthma',
#   '_id': 952},
#  {'patientid': 953,
#   'patientname': 'aShleYroDrIguez',
#   'age': 56,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 953},
#  {'patientid': 954,
#   'patientname': 'dARrYlCruZ',
#   'age': 84,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Asthma',
#   '_id': 954},
#  {'patientid': 955,
#   'patientname': 'shEiLAcHurcH',
#   'age': 46,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 955},
#  {'patientid': 956,
#   'patientname': 'NANcYmunOZ',
#   'age': 55,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Obesity',
#   '_id': 956},
#  {'patientid': 957,
#   'patientname': 'REBeccAMarTinEZ',
#   'age': 19,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 957},
#  {'patientid': 958,
#   'patientname': 'johNSIMmOns',
#   'age': 69,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 958},
#  {'patientid': 959,
#   'patientname': 'LANceTORREs',
#   'age': 69,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Cancer',
#   '_id': 959},
#  {'patientid': 960,
#   'patientname': 'tImotHyTErrY',
#   'age': 56,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 960},
#  {'patientid': 961,
#   'patientname': 'joHnMOorE',
#   'age': 36,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 961},
#  {'patientid': 962,
#   'patientname': 'bRAdLeYRAMos',
#   'age': 44,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Arthritis',
#   '_id': 962},
#  {'patientid': 963,
#   'patientname': 'JIlLTayLOR',
#   'age': 32,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Obesity',
#   '_id': 963},
#  {'patientid': 964,
#   'patientname': 'kelLybrown',
#   'age': 61,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 964},
#  {'patientid': 965,
#   'patientname': 'jonATHanchAVEZ',
#   'age': 61,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Cancer',
#   '_id': 965},
#  {'patientid': 966,
#   'patientname': 'deniSeWall',
#   'age': 47,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 966},
#  {'patientid': 967,
#   'patientname': 'ToDdmartinez',
#   'age': 49,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 967},
#  {'patientid': 968,
#   'patientname': 'jEnnIFerfoRD',
#   'age': 83,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 968},
#  {'patientid': 969,
#   'patientname': 'RAYMOnDParkJR.',
#   'age': 63,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Asthma',
#   '_id': 969},
#  {'patientid': 970,
#   'patientname': 'jUliareYNOLDs',
#   'age': 26,
#   'gender': 'Female',
#   'bloodtype': 'O-',
#   'disease': 'Cancer',
#   '_id': 970},
#  {'patientid': 971,
#   'patientname': 'JOhNMcleAn',
#   'age': 20,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 971},
#  {'patientid': 972,
#   'patientname': 'KATiehOwARd',
#   'age': 69,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 972},
#  {'patientid': 973,
#   'patientname': 'AmandALAWSon',
#   'age': 26,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 973},
#  {'patientid': 974,
#   'patientname': 'PAULmuRRaY',
#   'age': 36,
#   'gender': 'Male',
#   'bloodtype': 'AB+',
#   'disease': 'Arthritis',
#   '_id': 974},
#  {'patientid': 975,
#   'patientname': 'JAmEsMorRis',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Diabetes',
#   '_id': 975},
#  {'patientid': 976,
#   'patientname': 'MaTTHewcOlliNs',
#   'age': 60,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Obesity',
#   '_id': 976},
#  {'patientid': 977,
#   'patientname': 'sharOncArPenTeR',
#   'age': 67,
#   'gender': 'Female',
#   'bloodtype': 'AB-',
#   'disease': 'Arthritis',
#   '_id': 977},
#  {'patientid': 978,
#   'patientname': 'maRcUSbRoWn',
#   'age': 41,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Cancer',
#   '_id': 978},
#  {'patientid': 979,
#   'patientname': 'mItcHElLDeCkeR',
#   'age': 45,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Hypertension',
#   '_id': 979},
#  {'patientid': 980,
#   'patientname': 'dONaldmURPhY',
#   'age': 37,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 980},
#  {'patientid': 981,
#   'patientname': 'JOSePhfaRlEy',
#   'age': 46,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Cancer',
#   '_id': 981},
#  {'patientid': 982,
#   'patientname': 'BReNdaNpaRKer',
#   'age': 71,
#   'gender': 'Female',
#   'bloodtype': 'A+',
#   'disease': 'Arthritis',
#   '_id': 982},
#  {'patientid': 983,
#   'patientname': 'SaMuELdAVis',
#   'age': 69,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 983},
#  {'patientid': 984,
#   'patientname': 'KeLseyPOrTeR',
#   'age': 65,
#   'gender': 'Male',
#   'bloodtype': 'O-',
#   'disease': 'Asthma',
#   '_id': 984},
#  {'patientid': 985,
#   'patientname': 'mArkbRYaNt',
#   'age': 75,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Arthritis',
#   '_id': 985},
#  {'patientid': 986,
#   'patientname': 'mARGAretZamoRa',
#   'age': 77,
#   'gender': 'Male',
#   'bloodtype': 'O+',
#   'disease': 'Diabetes',
#   '_id': 986},
#  {'patientid': 987,
#   'patientname': 'dAVidpAyne',
#   'age': 22,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Obesity',
#   '_id': 987},
#  {'patientid': 988,
#   'patientname': 'tonysalAspHD',
#   'age': 58,
#   'gender': 'Female',
#   'bloodtype': 'O+',
#   'disease': 'Obesity',
#   '_id': 988},
#  {'patientid': 989,
#   'patientname': 'AdRiaNbowMan',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'A-',
#   'disease': 'Cancer',
#   '_id': 989},
#  {'patientid': 990,
#   'patientname': 'MRS.laUrEnmorgaN',
#   'age': 83,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 990},
#  {'patientid': 991,
#   'patientname': 'joSHuAmuRRay',
#   'age': 27,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 991},
#  {'patientid': 992,
#   'patientname': 'JAsoNwebER',
#   'age': 32,
#   'gender': 'Male',
#   'bloodtype': 'B-',
#   'disease': 'Arthritis',
#   '_id': 992},
#  {'patientid': 993,
#   'patientname': 'reBeCcALeWis',
#   'age': 40,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Diabetes',
#   '_id': 993},
#  {'patientid': 994,
#   'patientname': 'JOAnaRcHeR',
#   'age': 25,
#   'gender': 'Male',
#   'bloodtype': 'AB-',
#   'disease': 'Asthma',
#   '_id': 994},
#  {'patientid': 995,
#   'patientname': 'brittAnYEDwarDs',
#   'age': 69,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Asthma',
#   '_id': 995},
#  {'patientid': 996,
#   'patientname': 'tiMotHydIAz',
#   'age': 25,
#   'gender': 'Female',
#   'bloodtype': 'B-',
#   'disease': 'Diabetes',
#   '_id': 996},
#  {'patientid': 997,
#   'patientname': 'DaniELBLaNKenShIP',
#   'age': 66,
#   'gender': 'Female',
#   'bloodtype': 'B+',
#   'disease': 'Arthritis',
#   '_id': 997},
#  {'patientid': 998,
#   'patientname': 'mArystEphenS',
#   'age': 62,
#   'gender': 'Male',
#   'bloodtype': 'A+',
#   'disease': 'Hypertension',
#   '_id': 998},
#  {'patientid': 999,
#   'patientname': 'BrIANFigUERoA',
#   'age': 30,
#   'gender': 'Male',
#   'bloodtype': 'A-',
#   'disease': 'Hypertension',
#   '_id': 999},
#  {'patientid': 1000,
#   'patientname': 'sTEphANIeanderSOn',
#   'age': 55,
#   'gender': 'Male',
#   'bloodtype': 'B+',
#   'disease': 'Hypertension',
#   '_id': 1000},
#  ...]

# %%
csv_to_json_mongo("hospitals_table.csv", "hospitals.json", "admissionid")
# Out:
# [{'admissionid': 2001,
#   'patientid': 1,
#   'insuranceid': 1001,
#   'doctor': 'MatthewSmith',
#   'hospitalname': 'SonsandMiller',
#   'intakedate': '01/31/2024',
#   'dischargedate': '02/02/2024',
#   'roomnumber': 328,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2001},
#  {'admissionid': 2002,
#   'patientid': 2,
#   'insuranceid': 1002,
#   'doctor': 'SamanthaDavies',
#   'hospitalname': 'KimInc',
#   'intakedate': '08/20/2019',
#   'dischargedate': '08/26/2019',
#   'roomnumber': 265,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2002},
#  {'admissionid': 2003,
#   'patientid': 3,
#   'insuranceid': 1003,
#   'doctor': 'TiffanyMitchell',
#   'hospitalname': 'CookPLC',
#   'intakedate': '09/22/2022',
#   'dischargedate': '10/07/2022',
#   'roomnumber': 205,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2003},
#  {'admissionid': 2004,
#   'patientid': 4,
#   'insuranceid': 1004,
#   'doctor': 'KevinWells',
#   'hospitalname': 'HernandezRogersandVang,',
#   'intakedate': '11/18/2020',
#   'dischargedate': '12/18/2020',
#   'roomnumber': 450,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2004},
#  {'admissionid': 2005,
#   'patientid': 5,
#   'insuranceid': 1005,
#   'doctor': 'KathleenHanna',
#   'hospitalname': 'White-White',
#   'intakedate': '09/19/2022',
#   'dischargedate': '10/09/2022',
#   'roomnumber': 458,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2005},
#  {'admissionid': 2006,
#   'patientid': 6,
#   'insuranceid': 1006,
#   'doctor': 'TaylorNewton',
#   'hospitalname': 'Nunez-Humphrey',
#   'intakedate': '12/20/2023',
#   'dischargedate': '12/24/2023',
#   'roomnumber': 389,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2006},
#  {'admissionid': 2007,
#   'patientid': 7,
#   'insuranceid': 1007,
#   'doctor': 'KellyOlson',
#   'hospitalname': 'GroupMiddleton',
#   'intakedate': '11/03/2020',
#   'dischargedate': '11/15/2020',
#   'roomnumber': 389,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2007},
#  {'admissionid': 2008,
#   'patientid': 8,
#   'insuranceid': 1008,
#   'doctor': 'SuzanneThomas',
#   'hospitalname': 'PowellRobinsonandValdez,',
#   'intakedate': '12/28/2021',
#   'dischargedate': '01/07/2022',
#   'roomnumber': 277,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2008},
#  {'admissionid': 2009,
#   'patientid': 9,
#   'insuranceid': 1009,
#   'doctor': 'DanielFerguson',
#   'hospitalname': 'SonsRichand',
#   'intakedate': '07/01/2020',
#   'dischargedate': '07/14/2020',
#   'roomnumber': 316,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2009},
#  {'admissionid': 2010,
#   'patientid': 10,
#   'insuranceid': 1010,
#   'doctor': 'HeatherDay',
#   'hospitalname': 'Padilla-Walker',
#   'intakedate': '05/23/2021',
#   'dischargedate': '06/22/2021',
#   'roomnumber': 249,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2010},
#  {'admissionid': 2011,
#   'patientid': 11,
#   'insuranceid': 1011,
#   'doctor': 'JohnDuncan',
#   'hospitalname': 'Schaefer-Porter',
#   'intakedate': '04/19/2020',
#   'dischargedate': '04/22/2020',
#   'roomnumber': 394,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2011},
#  {'admissionid': 2012,
#   'patientid': 12,
#   'insuranceid': 1012,
#   'doctor': 'DouglasMayo',
#   'hospitalname': 'Lyons-Blair',
#   'intakedate': '08/13/2023',
#   'dischargedate': '09/05/2023',
#   'roomnumber': 288,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2012},
#  {'admissionid': 2013,
#   'patientid': 13,
#   'insuranceid': 1013,
#   'doctor': 'KennethFletcher',
#   'hospitalname': 'PowersMiller,andFlores',
#   'intakedate': '12/12/2019',
#   'dischargedate': '12/28/2019',
#   'roomnumber': 134,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2013},
#  {'admissionid': 2014,
#   'patientid': 14,
#   'insuranceid': 1014,
#   'doctor': 'TheresaFreeman',
#   'hospitalname': 'Rivera-Gutierrez',
#   'intakedate': '05/22/2020',
#   'dischargedate': '06/19/2020',
#   'roomnumber': 309,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2014},
#  {'admissionid': 2015,
#   'patientid': 15,
#   'insuranceid': 1015,
#   'doctor': 'RobertaStewart',
#   'hospitalname': 'Morris-Arellano',
#   'intakedate': '10/08/2021',
#   'dischargedate': '10/13/2021',
#   'roomnumber': 182,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2015},
#  {'admissionid': 2016,
#   'patientid': 16,
#   'insuranceid': 1016,
#   'doctor': 'MariaDougherty',
#   'hospitalname': 'Cline-Williams',
#   'intakedate': '01/01/2023',
#   'dischargedate': '01/11/2023',
#   'roomnumber': 465,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2016},
#  {'admissionid': 2017,
#   'patientid': 17,
#   'insuranceid': 1017,
#   'doctor': 'EricaSpencer',
#   'hospitalname': 'Cervantes-Wells',
#   'intakedate': '06/23/2020',
#   'dischargedate': '07/14/2020',
#   'roomnumber': 114,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2017},
#  {'admissionid': 2018,
#   'patientid': 18,
#   'insuranceid': 1018,
#   'doctor': 'JustinKim',
#   'hospitalname': 'Torres,andHarrisonJones',
#   'intakedate': '03/08/2020',
#   'dischargedate': '04/02/2020',
#   'roomnumber': 449,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2018},
#  {'admissionid': 2019,
#   'patientid': 19,
#   'insuranceid': 1019,
#   'doctor': 'JustinMooreJr.',
#   'hospitalname': 'HoustonPLC',
#   'intakedate': '03/04/2021',
#   'dischargedate': '03/14/2021',
#   'roomnumber': 260,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2019},
#  {'admissionid': 2020,
#   'patientid': 20,
#   'insuranceid': 1020,
#   'doctor': 'DeniseGalloway',
#   'hospitalname': 'HammondLtd',
#   'intakedate': '11/15/2022',
#   'dischargedate': '11/22/2022',
#   'roomnumber': 465,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2020},
#  {'admissionid': 2021,
#   'patientid': 21,
#   'insuranceid': 1021,
#   'doctor': 'KristaSmith',
#   'hospitalname': 'JonesLLC',
#   'intakedate': '06/28/2023',
#   'dischargedate': '07/02/2023',
#   'roomnumber': 115,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2021},
#  {'admissionid': 2022,
#   'patientid': 22,
#   'insuranceid': 1022,
#   'doctor': 'GregorySmith',
#   'hospitalname': 'Williams-Davis',
#   'intakedate': '01/21/2020',
#   'dischargedate': '02/09/2020',
#   'roomnumber': 295,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2022},
#  {'admissionid': 2023,
#   'patientid': 23,
#   'insuranceid': 1023,
#   'doctor': 'VanessaNewton',
#   'hospitalname': 'Clark-Mayo',
#   'intakedate': '05/12/2022',
#   'dischargedate': '06/10/2022',
#   'roomnumber': 327,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2023},
#  {'admissionid': 2024,
#   'patientid': 24,
#   'insuranceid': 1024,
#   'doctor': 'DonnaMartinezMD',
#   'hospitalname': 'andSonsSmith',
#   'intakedate': '08/02/2021',
#   'dischargedate': '08/12/2021',
#   'roomnumber': 119,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2024},
#  {'admissionid': 2025,
#   'patientid': 25,
#   'insuranceid': 1025,
#   'doctor': 'StephanieKramer',
#   'hospitalname': 'WilsonGroup',
#   'intakedate': '05/15/2020',
#   'dischargedate': '06/08/2020',
#   'roomnumber': 109,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2025},
#  {'admissionid': 2026,
#   'patientid': 26,
#   'insuranceid': 1026,
#   'doctor': 'AngelaContreras',
#   'hospitalname': 'Garner-Bowman',
#   'intakedate': '05/15/2020',
#   'dischargedate': '05/20/2020',
#   'roomnumber': 162,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2026},
#  {'admissionid': 2027,
#   'patientid': 27,
#   'insuranceid': 1027,
#   'doctor': 'WendyGlenn',
#   'hospitalname': 'Brown,andJonesWeaver',
#   'intakedate': '12/23/2023',
#   'dischargedate': '01/19/2024',
#   'roomnumber': 401,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2027},
#  {'admissionid': 2028,
#   'patientid': 28,
#   'insuranceid': 1028,
#   'doctor': 'JamesEllis',
#   'hospitalname': 'Serrano-Dixon',
#   'intakedate': '06/21/2022',
#   'dischargedate': '06/30/2022',
#   'roomnumber': 157,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2028},
#  {'admissionid': 2029,
#   'patientid': 29,
#   'insuranceid': 1029,
#   'doctor': 'JaredBruceJr.',
#   'hospitalname': 'Gardner-Miller',
#   'intakedate': '01/03/2021',
#   'dischargedate': '01/16/2021',
#   'roomnumber': 223,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2029},
#  {'admissionid': 2030,
#   'patientid': 30,
#   'insuranceid': 1030,
#   'doctor': 'BrandyMitchell',
#   'hospitalname': 'Guerrero-Boone',
#   'intakedate': '10/03/2023',
#   'dischargedate': '10/12/2023',
#   'roomnumber': 293,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2030},
#  {'admissionid': 2031,
#   'patientid': 31,
#   'insuranceid': 1031,
#   'doctor': 'JacobHuynh',
#   'hospitalname': 'HartLtd',
#   'intakedate': '08/18/2019',
#   'dischargedate': '09/01/2019',
#   'roomnumber': 371,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2031},
#  {'admissionid': 2032,
#   'patientid': 32,
#   'insuranceid': 1032,
#   'doctor': 'KristinaFrazier',
#   'hospitalname': 'Cruz-Santiago',
#   'intakedate': '11/03/2019',
#   'dischargedate': '11/29/2019',
#   'roomnumber': 108,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2032},
#  {'admissionid': 2033,
#   'patientid': 33,
#   'insuranceid': 1033,
#   'doctor': 'JohnHartman',
#   'hospitalname': 'GroupDuncan',
#   'intakedate': '05/18/2023',
#   'dischargedate': '06/15/2023',
#   'roomnumber': 245,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2033},
#  {'admissionid': 2034,
#   'patientid': 34,
#   'insuranceid': 1034,
#   'doctor': 'HeatherGarcia',
#   'hospitalname': 'Lopez-Phillips',
#   'intakedate': '05/24/2023',
#   'dischargedate': '06/03/2023',
#   'roomnumber': 494,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2034},
#  {'admissionid': 2035,
#   'patientid': 35,
#   'insuranceid': 1035,
#   'doctor': 'LynnYoung',
#   'hospitalname': 'PooleInc',
#   'intakedate': '01/17/2020',
#   'dischargedate': '02/10/2020',
#   'roomnumber': 285,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2035},
#  {'admissionid': 2036,
#   'patientid': 36,
#   'insuranceid': 1036,
#   'doctor': 'EmmaAllison',
#   'hospitalname': 'SonsandCox',
#   'intakedate': '01/07/2021',
#   'dischargedate': '01/26/2021',
#   'roomnumber': 228,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2036},
#  {'admissionid': 2037,
#   'patientid': 37,
#   'insuranceid': 1037,
#   'doctor': 'LauraMyers',
#   'hospitalname': 'LLCMartin',
#   'intakedate': '10/14/2019',
#   'dischargedate': '10/19/2019',
#   'roomnumber': 481,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2037},
#  {'admissionid': 2038,
#   'patientid': 38,
#   'insuranceid': 1038,
#   'doctor': 'TravisParsons',
#   'hospitalname': 'Espinoza-Stone',
#   'intakedate': '12/19/2021',
#   'dischargedate': '01/16/2022',
#   'roomnumber': 212,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2038},
#  {'admissionid': 2039,
#   'patientid': 39,
#   'insuranceid': 1039,
#   'doctor': 'ChristineJohnson',
#   'hospitalname': 'andGarciaMorrisCunningham,',
#   'intakedate': '03/12/2022',
#   'dischargedate': '03/29/2022',
#   'roomnumber': 113,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2039},
#  {'admissionid': 2040,
#   'patientid': 40,
#   'insuranceid': 1040,
#   'doctor': 'EmilyTaylor',
#   'hospitalname': 'Walton-Meyer',
#   'intakedate': '01/17/2021',
#   'dischargedate': '01/29/2021',
#   'roomnumber': 272,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2040},
#  {'admissionid': 2041,
#   'patientid': 41,
#   'insuranceid': 1041,
#   'doctor': 'WilliamReynolds',
#   'hospitalname': 'PLCYoung',
#   'intakedate': '09/15/2021',
#   'dischargedate': '10/05/2021',
#   'roomnumber': 478,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2041},
#  {'admissionid': 2042,
#   'patientid': 42,
#   'insuranceid': 1042,
#   'doctor': 'JenniferCarter',
#   'hospitalname': 'MeadowsGroup',
#   'intakedate': '01/27/2020',
#   'dischargedate': '02/09/2020',
#   'roomnumber': 196,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2042},
#  {'admissionid': 2043,
#   'patientid': 43,
#   'insuranceid': 1043,
#   'doctor': 'MatthewThomas',
#   'hospitalname': 'andHowellBrooks,Rogers',
#   'intakedate': '06/24/2022',
#   'dischargedate': '07/18/2022',
#   'roomnumber': 418,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2043},
#  {'admissionid': 2044,
#   'patientid': 44,
#   'insuranceid': 1044,
#   'doctor': 'MaryLogan',
#   'hospitalname': 'andMcclureWhiteBoone,',
#   'intakedate': '06/09/2021',
#   'dischargedate': '07/01/2021',
#   'roomnumber': 410,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2044},
#  {'admissionid': 2045,
#   'patientid': 45,
#   'insuranceid': 1045,
#   'doctor': 'KristinMartinez',
#   'hospitalname': 'GatesBrown,andStuart',
#   'intakedate': '08/23/2020',
#   'dischargedate': '09/08/2020',
#   'roomnumber': 328,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2045},
#  {'admissionid': 2046,
#   'patientid': 46,
#   'insuranceid': 1046,
#   'doctor': 'DanielMurphy',
#   'hospitalname': 'GroupArmstrong',
#   'intakedate': '10/12/2022',
#   'dischargedate': '11/02/2022',
#   'roomnumber': 300,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2046},
#  {'admissionid': 2047,
#   'patientid': 47,
#   'insuranceid': 1047,
#   'doctor': 'EmilyPatterson',
#   'hospitalname': 'LtdSchwartz',
#   'intakedate': '12/01/2021',
#   'dischargedate': '12/09/2021',
#   'roomnumber': 211,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2047},
#  {'admissionid': 2048,
#   'patientid': 48,
#   'insuranceid': 1048,
#   'doctor': 'HeatherSmith',
#   'hospitalname': 'Nelson-Phillips',
#   'intakedate': '05/04/2020',
#   'dischargedate': '05/13/2020',
#   'roomnumber': 413,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2048},
#  {'admissionid': 2049,
#   'patientid': 49,
#   'insuranceid': 1049,
#   'doctor': 'JohnSmith',
#   'hospitalname': 'KnightandNguyen,Riggs',
#   'intakedate': '09/09/2023',
#   'dischargedate': '09/23/2023',
#   'roomnumber': 157,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2049},
#  {'admissionid': 2050,
#   'patientid': 50,
#   'insuranceid': 1050,
#   'doctor': 'CameronYoung',
#   'hospitalname': 'LopezPLC',
#   'intakedate': '07/19/2019',
#   'dischargedate': '07/29/2019',
#   'roomnumber': 138,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2050},
#  {'admissionid': 2051,
#   'patientid': 51,
#   'insuranceid': 1051,
#   'doctor': 'VickiNguyen',
#   'hospitalname': 'FernandezandPhillips,Singh',
#   'intakedate': '04/05/2024',
#   'dischargedate': '04/22/2024',
#   'roomnumber': 456,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2051},
#  {'admissionid': 2052,
#   'patientid': 52,
#   'insuranceid': 1052,
#   'doctor': 'MaryMoss',
#   'hospitalname': 'Beck-Galloway',
#   'intakedate': '06/15/2019',
#   'dischargedate': '07/05/2019',
#   'roomnumber': 234,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2052},
#  {'admissionid': 2053,
#   'patientid': 53,
#   'insuranceid': 1053,
#   'doctor': 'AlexanderGarcia',
#   'hospitalname': 'DeckerGlover,andChristensen',
#   'intakedate': '10/29/2022',
#   'dischargedate': '11/20/2022',
#   'roomnumber': 492,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2053},
#  {'admissionid': 2054,
#   'patientid': 54,
#   'insuranceid': 1054,
#   'doctor': 'PatrickBurns',
#   'hospitalname': 'NelsonWalkerMyers,and',
#   'intakedate': '04/08/2022',
#   'dischargedate': '04/13/2022',
#   'roomnumber': 180,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2054},
#  {'admissionid': 2055,
#   'patientid': 55,
#   'insuranceid': 1055,
#   'doctor': 'KaylaPowers',
#   'hospitalname': 'Mitchell-Navarro',
#   'intakedate': '08/17/2023',
#   'dischargedate': '09/11/2023',
#   'roomnumber': 250,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2055},
#  {'admissionid': 2056,
#   'patientid': 56,
#   'insuranceid': 1056,
#   'doctor': 'JuliaCox',
#   'hospitalname': 'GroupDelgado',
#   'intakedate': '11/05/2023',
#   'dischargedate': '11/07/2023',
#   'roomnumber': 296,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2056},
#  {'admissionid': 2057,
#   'patientid': 57,
#   'insuranceid': 1057,
#   'doctor': 'PennyPruitt',
#   'hospitalname': 'andMontesGraves,Thomas',
#   'intakedate': '04/09/2023',
#   'dischargedate': '04/21/2023',
#   'roomnumber': 330,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2057},
#  {'admissionid': 2058,
#   'patientid': 58,
#   'insuranceid': 1058,
#   'doctor': 'Mrs.LoriHurstPhD',
#   'hospitalname': 'Hall-Bentley',
#   'intakedate': '09/21/2022',
#   'dischargedate': '09/25/2022',
#   'roomnumber': 405,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2058},
#  {'admissionid': 2059,
#   'patientid': 59,
#   'insuranceid': 1059,
#   'doctor': 'StephenCarr',
#   'hospitalname': 'Taylor-Nguyen',
#   'intakedate': '01/21/2021',
#   'dischargedate': '02/06/2021',
#   'roomnumber': 300,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2059},
#  {'admissionid': 2060,
#   'patientid': 60,
#   'insuranceid': 1060,
#   'doctor': 'JacobDaniel',
#   'hospitalname': 'Hunter-Grant',
#   'intakedate': '07/10/2020',
#   'dischargedate': '07/20/2020',
#   'roomnumber': 306,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2060},
#  {'admissionid': 2061,
#   'patientid': 61,
#   'insuranceid': 1061,
#   'doctor': 'TylerBraun',
#   'hospitalname': 'Miller-Lawson',
#   'intakedate': '11/06/2019',
#   'dischargedate': '11/22/2019',
#   'roomnumber': 333,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2061},
#  {'admissionid': 2062,
#   'patientid': 62,
#   'insuranceid': 1062,
#   'doctor': 'CindyEllis',
#   'hospitalname': 'Scott-Kelly',
#   'intakedate': '04/07/2024',
#   'dischargedate': '05/04/2024',
#   'roomnumber': 244,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2062},
#  {'admissionid': 2063,
#   'patientid': 63,
#   'insuranceid': 1063,
#   'doctor': 'MeganHahn',
#   'hospitalname': 'MossandFerguson,Baker',
#   'intakedate': '07/06/2022',
#   'dischargedate': '07/18/2022',
#   'roomnumber': 325,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2063},
#  {'admissionid': 2064,
#   'patientid': 64,
#   'insuranceid': 1064,
#   'doctor': 'EricKelly',
#   'hospitalname': 'andMasonSmithChase,',
#   'intakedate': '08/03/2022',
#   'dischargedate': '08/10/2022',
#   'roomnumber': 113,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2064},
#  {'admissionid': 2065,
#   'patientid': 65,
#   'insuranceid': 1065,
#   'doctor': 'JenniferLarson',
#   'hospitalname': 'Khan,andRodriguezFischer',
#   'intakedate': '05/08/2020',
#   'dischargedate': '06/01/2020',
#   'roomnumber': 378,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2065},
#  {'admissionid': 2066,
#   'patientid': 66,
#   'insuranceid': 1066,
#   'doctor': 'WilliamHess',
#   'hospitalname': 'SonsWatsonand',
#   'intakedate': '12/09/2019',
#   'dischargedate': '12/21/2019',
#   'roomnumber': 468,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2066},
#  {'admissionid': 2067,
#   'patientid': 67,
#   'insuranceid': 1067,
#   'doctor': 'PatriciaDunn',
#   'hospitalname': 'Rhodes-Carey',
#   'intakedate': '11/21/2019',
#   'dischargedate': '12/08/2019',
#   'roomnumber': 368,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2067},
#  {'admissionid': 2068,
#   'patientid': 68,
#   'insuranceid': 1068,
#   'doctor': 'JackJackson',
#   'hospitalname': 'Bullock-Ramsey',
#   'intakedate': '01/07/2023',
#   'dischargedate': '01/27/2023',
#   'roomnumber': 263,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2068},
#  {'admissionid': 2069,
#   'patientid': 69,
#   'insuranceid': 1069,
#   'doctor': 'JonathanDrake',
#   'hospitalname': 'ClarkBrown,andMyers',
#   'intakedate': '02/06/2024',
#   'dischargedate': '02/10/2024',
#   'roomnumber': 489,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2069},
#  {'admissionid': 2070,
#   'patientid': 70,
#   'insuranceid': 1070,
#   'doctor': 'IanBenitez',
#   'hospitalname': 'JacksonandLane,Dillon',
#   'intakedate': '01/30/2020',
#   'dischargedate': '02/12/2020',
#   'roomnumber': 241,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2070},
#  {'admissionid': 2071,
#   'patientid': 71,
#   'insuranceid': 1071,
#   'doctor': 'JamieBaker',
#   'hospitalname': 'TurnerCook,Banksand',
#   'intakedate': '10/24/2022',
#   'dischargedate': '11/07/2022',
#   'roomnumber': 231,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2071},
#  {'admissionid': 2072,
#   'patientid': 72,
#   'insuranceid': 1072,
#   'doctor': 'ErikaJackson',
#   'hospitalname': 'Miles,andWeaverHudson',
#   'intakedate': '01/09/2022',
#   'dischargedate': '01/15/2022',
#   'roomnumber': 377,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2072},
#  {'admissionid': 2073,
#   'patientid': 73,
#   'insuranceid': 1073,
#   'doctor': 'AmandaGarcia',
#   'hospitalname': 'EvansLtd',
#   'intakedate': '12/28/2023',
#   'dischargedate': '01/02/2024',
#   'roomnumber': 407,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2073},
#  {'admissionid': 2074,
#   'patientid': 74,
#   'insuranceid': 1074,
#   'doctor': 'RavenWong',
#   'hospitalname': 'SonsandSchaefer',
#   'intakedate': '09/16/2021',
#   'dischargedate': '10/14/2021',
#   'roomnumber': 263,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2074},
#  {'admissionid': 2075,
#   'patientid': 75,
#   'insuranceid': 1075,
#   'doctor': 'CynthiaScott',
#   'hospitalname': 'SonsHodgesand',
#   'intakedate': '07/24/2023',
#   'dischargedate': '08/11/2023',
#   'roomnumber': 135,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2075},
#  {'admissionid': 2076,
#   'patientid': 76,
#   'insuranceid': 1076,
#   'doctor': 'MarkPadilla',
#   'hospitalname': 'Simpson-Mccall',
#   'intakedate': '11/13/2021',
#   'dischargedate': '12/07/2021',
#   'roomnumber': 131,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2076},
#  {'admissionid': 2077,
#   'patientid': 77,
#   'insuranceid': 1077,
#   'doctor': 'JulieRamirez',
#   'hospitalname': 'LinThompsonWells,and',
#   'intakedate': '10/11/2023',
#   'dischargedate': '10/27/2023',
#   'roomnumber': 102,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2077},
#  {'admissionid': 2078,
#   'patientid': 78,
#   'insuranceid': 1078,
#   'doctor': 'JacobRich',
#   'hospitalname': 'Jones-Scott',
#   'intakedate': '01/30/2021',
#   'dischargedate': '02/04/2021',
#   'roomnumber': 249,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2078},
#  {'admissionid': 2079,
#   'patientid': 79,
#   'insuranceid': 1079,
#   'doctor': 'MarkHartmanJr.',
#   'hospitalname': 'Howe-Kelly',
#   'intakedate': '11/21/2021',
#   'dischargedate': '12/05/2021',
#   'roomnumber': 255,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2079},
#  {'admissionid': 2080,
#   'patientid': 80,
#   'insuranceid': 1080,
#   'doctor': 'TimothyBaker',
#   'hospitalname': 'andSonsReyes',
#   'intakedate': '03/02/2024',
#   'dischargedate': '03/26/2024',
#   'roomnumber': 422,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2080},
#  {'admissionid': 2081,
#   'patientid': 81,
#   'insuranceid': 1081,
#   'doctor': 'LoriSanchez',
#   'hospitalname': 'Shaw-Young',
#   'intakedate': '12/04/2020',
#   'dischargedate': '12/08/2020',
#   'roomnumber': 320,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2081},
#  {'admissionid': 2082,
#   'patientid': 82,
#   'insuranceid': 1082,
#   'doctor': 'ConnieBoyd',
#   'hospitalname': 'IncSkinner',
#   'intakedate': '08/26/2020',
#   'dischargedate': '08/27/2020',
#   'roomnumber': 134,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2082},
#  {'admissionid': 2083,
#   'patientid': 83,
#   'insuranceid': 1083,
#   'doctor': 'JamesTucker',
#   'hospitalname': 'Clark-Johnson',
#   'intakedate': '11/12/2023',
#   'dischargedate': '12/12/2023',
#   'roomnumber': 255,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2083},
#  {'admissionid': 2084,
#   'patientid': 84,
#   'insuranceid': 1084,
#   'doctor': 'JuanAcevedo',
#   'hospitalname': 'PerezandSons',
#   'intakedate': '05/30/2020',
#   'dischargedate': '06/14/2020',
#   'roomnumber': 410,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2084},
#  {'admissionid': 2085,
#   'patientid': 85,
#   'insuranceid': 1085,
#   'doctor': 'JulieFinley',
#   'hospitalname': 'KempLLC',
#   'intakedate': '05/12/2023',
#   'dischargedate': '06/10/2023',
#   'roomnumber': 273,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2085},
#  {'admissionid': 2086,
#   'patientid': 86,
#   'insuranceid': 1086,
#   'doctor': 'MiguelParker',
#   'hospitalname': 'LLCDixon',
#   'intakedate': '07/07/2022',
#   'dischargedate': '07/23/2022',
#   'roomnumber': 395,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2086},
#  {'admissionid': 2087,
#   'patientid': 87,
#   'insuranceid': 1087,
#   'doctor': 'JermainePeters',
#   'hospitalname': 'andMoralesJenningsCook,',
#   'intakedate': '09/24/2020',
#   'dischargedate': '10/08/2020',
#   'roomnumber': 152,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2087},
#  {'admissionid': 2088,
#   'patientid': 88,
#   'insuranceid': 1088,
#   'doctor': 'LisaEdwards',
#   'hospitalname': 'GroupHood',
#   'intakedate': '08/19/2023',
#   'dischargedate': '08/25/2023',
#   'roomnumber': 321,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2088},
#  {'admissionid': 2089,
#   'patientid': 89,
#   'insuranceid': 1089,
#   'doctor': 'MatthewWalker',
#   'hospitalname': 'LindseyInc',
#   'intakedate': '05/16/2023',
#   'dischargedate': '06/01/2023',
#   'roomnumber': 428,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2089},
#  {'admissionid': 2090,
#   'patientid': 90,
#   'insuranceid': 1090,
#   'doctor': 'GregoryHansen',
#   'hospitalname': 'LtdWang',
#   'intakedate': '08/22/2022',
#   'dischargedate': '09/07/2022',
#   'roomnumber': 482,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2090},
#  {'admissionid': 2091,
#   'patientid': 91,
#   'insuranceid': 1091,
#   'doctor': 'JessicaCruz',
#   'hospitalname': 'IncFord',
#   'intakedate': '06/17/2022',
#   'dischargedate': '06/28/2022',
#   'roomnumber': 268,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2091},
#  {'admissionid': 2092,
#   'patientid': 92,
#   'insuranceid': 1092,
#   'doctor': 'RobertSalazar',
#   'hospitalname': 'Dean-Hawkins',
#   'intakedate': '11/05/2022',
#   'dischargedate': '11/25/2022',
#   'roomnumber': 120,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2092},
#  {'admissionid': 2093,
#   'patientid': 93,
#   'insuranceid': 1093,
#   'doctor': 'KylePatterson',
#   'hospitalname': 'WalterPLC',
#   'intakedate': '09/10/2021',
#   'dischargedate': '09/18/2021',
#   'roomnumber': 318,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2093},
#  {'admissionid': 2094,
#   'patientid': 94,
#   'insuranceid': 1094,
#   'doctor': 'JohnSummers',
#   'hospitalname': 'SonsHornand',
#   'intakedate': '09/06/2022',
#   'dischargedate': '09/27/2022',
#   'roomnumber': 162,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2094},
#  {'admissionid': 2095,
#   'patientid': 95,
#   'insuranceid': 1095,
#   'doctor': 'ScottGrant',
#   'hospitalname': 'PowellWard,andMercado',
#   'intakedate': '04/17/2021',
#   'dischargedate': '05/10/2021',
#   'roomnumber': 428,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2095},
#  {'admissionid': 2096,
#   'patientid': 96,
#   'insuranceid': 1096,
#   'doctor': 'DavidRuiz',
#   'hospitalname': 'JamesLtd',
#   'intakedate': '08/19/2019',
#   'dischargedate': '08/26/2019',
#   'roomnumber': 144,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2096},
#  {'admissionid': 2097,
#   'patientid': 97,
#   'insuranceid': 1097,
#   'doctor': 'KyleSmith',
#   'hospitalname': 'Kemp-Munoz',
#   'intakedate': '03/24/2024',
#   'dischargedate': '04/14/2024',
#   'roomnumber': 226,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2097},
#  {'admissionid': 2098,
#   'patientid': 98,
#   'insuranceid': 1098,
#   'doctor': 'JasonPrice',
#   'hospitalname': 'Henderson-Taylor',
#   'intakedate': '12/10/2022',
#   'dischargedate': '12/31/2022',
#   'roomnumber': 459,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2098},
#  {'admissionid': 2099,
#   'patientid': 99,
#   'insuranceid': 1099,
#   'doctor': 'StephanieClements',
#   'hospitalname': 'Parsons,HartmanMartinezand',
#   'intakedate': '09/14/2022',
#   'dischargedate': '09/18/2022',
#   'roomnumber': 208,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2099},
#  {'admissionid': 2100,
#   'patientid': 100,
#   'insuranceid': 1100,
#   'doctor': 'StevenJames',
#   'hospitalname': 'LunaInc',
#   'intakedate': '10/18/2022',
#   'dischargedate': '11/11/2022',
#   'roomnumber': 227,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2100},
#  {'admissionid': 2101,
#   'patientid': 101,
#   'insuranceid': 1101,
#   'doctor': 'JeremiahWolf',
#   'hospitalname': 'Hernandez,RitterandHuffman',
#   'intakedate': '11/13/2021',
#   'dischargedate': '11/21/2021',
#   'roomnumber': 115,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2101},
#  {'admissionid': 2102,
#   'patientid': 102,
#   'insuranceid': 1102,
#   'doctor': 'RobertoPetersen',
#   'hospitalname': 'ReedLLC',
#   'intakedate': '07/08/2022',
#   'dischargedate': '07/25/2022',
#   'roomnumber': 402,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2102},
#  {'admissionid': 2103,
#   'patientid': 103,
#   'insuranceid': 1103,
#   'doctor': 'ChristinaHammond',
#   'hospitalname': 'Thompson-Walker',
#   'intakedate': '06/25/2023',
#   'dischargedate': '07/11/2023',
#   'roomnumber': 442,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2103},
#  {'admissionid': 2104,
#   'patientid': 104,
#   'insuranceid': 1104,
#   'doctor': 'PatriciaColon',
#   'hospitalname': 'GroupNguyen',
#   'intakedate': '07/09/2019',
#   'dischargedate': '08/05/2019',
#   'roomnumber': 418,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2104},
#  {'admissionid': 2105,
#   'patientid': 105,
#   'insuranceid': 1105,
#   'doctor': 'DominicMitchell',
#   'hospitalname': 'Newton-White',
#   'intakedate': '05/14/2021',
#   'dischargedate': '06/03/2021',
#   'roomnumber': 425,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2105},
#  {'admissionid': 2106,
#   'patientid': 106,
#   'insuranceid': 1106,
#   'doctor': 'WendyDavis',
#   'hospitalname': 'LtdThomas',
#   'intakedate': '01/15/2024',
#   'dischargedate': '02/07/2024',
#   'roomnumber': 373,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2106},
#  {'admissionid': 2107,
#   'patientid': 107,
#   'insuranceid': 1107,
#   'doctor': 'DanielCarson',
#   'hospitalname': 'PierceWard,Torresand',
#   'intakedate': '09/30/2019',
#   'dischargedate': '10/15/2019',
#   'roomnumber': 290,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2107},
#  {'admissionid': 2108,
#   'patientid': 108,
#   'insuranceid': 1108,
#   'doctor': 'ErinHendersonMD',
#   'hospitalname': 'EvansandHallSchneider,',
#   'intakedate': '03/05/2021',
#   'dischargedate': '03/20/2021',
#   'roomnumber': 361,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2108},
#  {'admissionid': 2109,
#   'patientid': 109,
#   'insuranceid': 1109,
#   'doctor': 'ChristopherButler',
#   'hospitalname': 'Stout-Brown',
#   'intakedate': '05/14/2021',
#   'dischargedate': '06/06/2021',
#   'roomnumber': 251,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2109},
#  {'admissionid': 2110,
#   'patientid': 110,
#   'insuranceid': 1110,
#   'doctor': 'SamuelRobles',
#   'hospitalname': 'CruzLtd',
#   'intakedate': '06/08/2023',
#   'dischargedate': '07/05/2023',
#   'roomnumber': 231,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2110},
#  {'admissionid': 2111,
#   'patientid': 111,
#   'insuranceid': 1111,
#   'doctor': 'BenjaminWebb',
#   'hospitalname': 'StewartSonsand',
#   'intakedate': '05/13/2022',
#   'dischargedate': '05/20/2022',
#   'roomnumber': 212,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2111},
#  {'admissionid': 2112,
#   'patientid': 112,
#   'insuranceid': 1112,
#   'doctor': 'KrystalFox',
#   'hospitalname': 'HallRobertsandDuarte,',
#   'intakedate': '09/22/2022',
#   'dischargedate': '10/14/2022',
#   'roomnumber': 440,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2112},
#  {'admissionid': 2113,
#   'patientid': 113,
#   'insuranceid': 1113,
#   'doctor': 'BruceGarrett',
#   'hospitalname': 'Ramirez-Robinson',
#   'intakedate': '08/25/2023',
#   'dischargedate': '09/18/2023',
#   'roomnumber': 414,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2113},
#  {'admissionid': 2114,
#   'patientid': 114,
#   'insuranceid': 1114,
#   'doctor': 'JonathanWatson',
#   'hospitalname': 'Garcia,andBishopHernandez',
#   'intakedate': '06/02/2019',
#   'dischargedate': '06/04/2019',
#   'roomnumber': 424,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2114},
#  {'admissionid': 2115,
#   'patientid': 115,
#   'insuranceid': 1115,
#   'doctor': 'ChristopherGuerra',
#   'hospitalname': 'andBrownOneal,Shah',
#   'intakedate': '11/19/2021',
#   'dischargedate': '12/12/2021',
#   'roomnumber': 307,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2115},
#  {'admissionid': 2116,
#   'patientid': 116,
#   'insuranceid': 1116,
#   'doctor': 'StevenAdams',
#   'hospitalname': 'GroupWhite',
#   'intakedate': '12/02/2019',
#   'dischargedate': '12/13/2019',
#   'roomnumber': 476,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2116},
#  {'admissionid': 2117,
#   'patientid': 117,
#   'insuranceid': 1117,
#   'doctor': 'VictoriaPatel',
#   'hospitalname': 'HughesandErickson,Anderson',
#   'intakedate': '08/21/2020',
#   'dischargedate': '09/06/2020',
#   'roomnumber': 388,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2117},
#  {'admissionid': 2118,
#   'patientid': 118,
#   'insuranceid': 1118,
#   'doctor': 'LouisBell',
#   'hospitalname': 'Lane-Kelly',
#   'intakedate': '02/12/2021',
#   'dischargedate': '03/11/2021',
#   'roomnumber': 326,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2118},
#  {'admissionid': 2119,
#   'patientid': 119,
#   'insuranceid': 1119,
#   'doctor': 'MichaelBaker',
#   'hospitalname': 'Cox-Hester',
#   'intakedate': '01/13/2024',
#   'dischargedate': '01/22/2024',
#   'roomnumber': 394,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2119},
#  {'admissionid': 2120,
#   'patientid': 120,
#   'insuranceid': 1120,
#   'doctor': 'DouglasFleming',
#   'hospitalname': 'JarvisScott,Flemingand',
#   'intakedate': '12/26/2021',
#   'dischargedate': '01/12/2022',
#   'roomnumber': 138,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2120},
#  {'admissionid': 2121,
#   'patientid': 121,
#   'insuranceid': 1121,
#   'doctor': 'PatrickCarter',
#   'hospitalname': 'Cline-Carpenter',
#   'intakedate': '08/22/2022',
#   'dischargedate': '09/07/2022',
#   'roomnumber': 178,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2121},
#  {'admissionid': 2122,
#   'patientid': 122,
#   'insuranceid': 1122,
#   'doctor': 'SarahShaffer',
#   'hospitalname': 'Johnson,andRossHarris',
#   'intakedate': '07/03/2021',
#   'dischargedate': '07/31/2021',
#   'roomnumber': 177,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2122},
#  {'admissionid': 2123,
#   'patientid': 123,
#   'insuranceid': 1123,
#   'doctor': 'MatthewCarter',
#   'hospitalname': 'KimRosario,andHammond',
#   'intakedate': '05/31/2020',
#   'dischargedate': '06/01/2020',
#   'roomnumber': 211,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2123},
#  {'admissionid': 2124,
#   'patientid': 124,
#   'insuranceid': 1124,
#   'doctor': 'BrianWagner',
#   'hospitalname': 'PLCJimenez',
#   'intakedate': '10/26/2020',
#   'dischargedate': '11/17/2020',
#   'roomnumber': 302,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2124},
#  {'admissionid': 2125,
#   'patientid': 125,
#   'insuranceid': 1125,
#   'doctor': 'LucasCole',
#   'hospitalname': 'Cantu-Berry',
#   'intakedate': '06/03/2021',
#   'dischargedate': '07/01/2021',
#   'roomnumber': 368,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2125},
#  {'admissionid': 2126,
#   'patientid': 126,
#   'insuranceid': 1126,
#   'doctor': 'JuliaYoder',
#   'hospitalname': 'Wright-Alexander',
#   'intakedate': '10/24/2020',
#   'dischargedate': '11/13/2020',
#   'roomnumber': 130,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2126},
#  {'admissionid': 2127,
#   'patientid': 127,
#   'insuranceid': 1127,
#   'doctor': 'CrystalChavez',
#   'hospitalname': 'Guzman-Carlson',
#   'intakedate': '08/27/2019',
#   'dischargedate': '09/06/2019',
#   'roomnumber': 424,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2127},
#  {'admissionid': 2128,
#   'patientid': 128,
#   'insuranceid': 1128,
#   'doctor': 'BrendaLopez',
#   'hospitalname': 'Meyer-Hill',
#   'intakedate': '11/30/2021',
#   'dischargedate': '12/09/2021',
#   'roomnumber': 430,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2128},
#  {'admissionid': 2129,
#   'patientid': 129,
#   'insuranceid': 1129,
#   'doctor': 'MichaelCole',
#   'hospitalname': 'Dudley-Atkinson',
#   'intakedate': '10/15/2023',
#   'dischargedate': '11/08/2023',
#   'roomnumber': 133,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2129},
#  {'admissionid': 2130,
#   'patientid': 130,
#   'insuranceid': 1130,
#   'doctor': 'MichaelLarson',
#   'hospitalname': 'Kelly-Allen',
#   'intakedate': '03/17/2024',
#   'dischargedate': '03/28/2024',
#   'roomnumber': 430,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2130},
#  {'admissionid': 2131,
#   'patientid': 131,
#   'insuranceid': 1131,
#   'doctor': 'TraceySpence',
#   'hospitalname': 'LewisLivingston,Loweand',
#   'intakedate': '10/13/2019',
#   'dischargedate': '10/16/2019',
#   'roomnumber': 104,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2131},
#  {'admissionid': 2132,
#   'patientid': 132,
#   'insuranceid': 1132,
#   'doctor': 'SusanGibson',
#   'hospitalname': 'RodriguezLtd',
#   'intakedate': '03/02/2020',
#   'dischargedate': '03/07/2020',
#   'roomnumber': 408,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2132},
#  {'admissionid': 2133,
#   'patientid': 133,
#   'insuranceid': 1133,
#   'doctor': 'GeraldHooper',
#   'hospitalname': 'andJohnsonMoore,Branch',
#   'intakedate': '11/05/2019',
#   'dischargedate': '11/23/2019',
#   'roomnumber': 376,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2133},
#  {'admissionid': 2134,
#   'patientid': 134,
#   'insuranceid': 1134,
#   'doctor': 'ToddSanchez',
#   'hospitalname': 'HolmesandHughes,Phillips',
#   'intakedate': '02/07/2021',
#   'dischargedate': '03/05/2021',
#   'roomnumber': 331,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2134},
#  {'admissionid': 2135,
#   'patientid': 135,
#   'insuranceid': 1135,
#   'doctor': 'ElizabethMorales',
#   'hospitalname': 'andSmith,TuckerCross',
#   'intakedate': '10/25/2021',
#   'dischargedate': '11/22/2021',
#   'roomnumber': 275,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2135},
#  {'admissionid': 2136,
#   'patientid': 136,
#   'insuranceid': 1136,
#   'doctor': 'KimberlyPetersen',
#   'hospitalname': 'SonsandLozano',
#   'intakedate': '07/24/2022',
#   'dischargedate': '07/31/2022',
#   'roomnumber': 425,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2136},
#  {'admissionid': 2137,
#   'patientid': 137,
#   'insuranceid': 1137,
#   'doctor': 'MistyGarcia',
#   'hospitalname': 'RussellLtd',
#   'intakedate': '03/04/2020',
#   'dischargedate': '03/05/2020',
#   'roomnumber': 480,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2137},
#  {'admissionid': 2138,
#   'patientid': 138,
#   'insuranceid': 1138,
#   'doctor': 'MelissaFernandez',
#   'hospitalname': 'JonesLtd',
#   'intakedate': '08/01/2021',
#   'dischargedate': '08/19/2021',
#   'roomnumber': 233,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2138},
#  {'admissionid': 2139,
#   'patientid': 139,
#   'insuranceid': 1139,
#   'doctor': 'KariMoore',
#   'hospitalname': 'Gordon-Ward',
#   'intakedate': '01/24/2020',
#   'dischargedate': '02/12/2020',
#   'roomnumber': 384,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2139},
#  {'admissionid': 2140,
#   'patientid': 140,
#   'insuranceid': 1140,
#   'doctor': 'DavidHubbard',
#   'hospitalname': 'BarnesandSons',
#   'intakedate': '07/30/2021',
#   'dischargedate': '08/13/2021',
#   'roomnumber': 380,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2140},
#  {'admissionid': 2141,
#   'patientid': 141,
#   'insuranceid': 1141,
#   'doctor': 'LonnieMorgan',
#   'hospitalname': 'Levine-Miller',
#   'intakedate': '01/04/2024',
#   'dischargedate': '02/03/2024',
#   'roomnumber': 310,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2141},
#  {'admissionid': 2142,
#   'patientid': 142,
#   'insuranceid': 1142,
#   'doctor': 'VictoriaGonzales',
#   'hospitalname': 'andMarquezSilvaSmith,',
#   'intakedate': '01/05/2024',
#   'dischargedate': '02/04/2024',
#   'roomnumber': 406,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2142},
#  {'admissionid': 2143,
#   'patientid': 143,
#   'insuranceid': 1143,
#   'doctor': 'CindyWhite',
#   'hospitalname': 'Jackson-Copeland',
#   'intakedate': '08/11/2020',
#   'dischargedate': '09/04/2020',
#   'roomnumber': 213,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2143},
#  {'admissionid': 2144,
#   'patientid': 144,
#   'insuranceid': 1144,
#   'doctor': 'DouglasLi',
#   'hospitalname': 'PerezandOchoaWhite,',
#   'intakedate': '06/17/2022',
#   'dischargedate': '06/24/2022',
#   'roomnumber': 130,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2144},
#  {'admissionid': 2145,
#   'patientid': 145,
#   'insuranceid': 1145,
#   'doctor': 'LoriMendoza',
#   'hospitalname': 'LtdConrad',
#   'intakedate': '04/02/2022',
#   'dischargedate': '04/09/2022',
#   'roomnumber': 244,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2145},
#  {'admissionid': 2146,
#   'patientid': 146,
#   'insuranceid': 1146,
#   'doctor': 'RyanRoss',
#   'hospitalname': 'Hampton-Thomas',
#   'intakedate': '06/03/2020',
#   'dischargedate': '06/22/2020',
#   'roomnumber': 233,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2146},
#  {'admissionid': 2147,
#   'patientid': 147,
#   'insuranceid': 1147,
#   'doctor': 'BrianWalton',
#   'hospitalname': 'Thomas-Kelley',
#   'intakedate': '08/16/2019',
#   'dischargedate': '08/21/2019',
#   'roomnumber': 427,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2147},
#  {'admissionid': 2148,
#   'patientid': 148,
#   'insuranceid': 1148,
#   'doctor': 'MichaelBerg',
#   'hospitalname': 'Myers-Monroe',
#   'intakedate': '02/22/2024',
#   'dischargedate': '02/24/2024',
#   'roomnumber': 500,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2148},
#  {'admissionid': 2149,
#   'patientid': 149,
#   'insuranceid': 1149,
#   'doctor': 'ScottDavis',
#   'hospitalname': 'andFordLee,Rodriguez',
#   'intakedate': '05/06/2021',
#   'dischargedate': '05/29/2021',
#   'roomnumber': 451,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2149},
#  {'admissionid': 2150,
#   'patientid': 150,
#   'insuranceid': 1150,
#   'doctor': 'DanielShelton',
#   'hospitalname': 'SonsGarciaand',
#   'intakedate': '10/27/2021',
#   'dischargedate': '11/04/2021',
#   'roomnumber': 485,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2150},
#  {'admissionid': 2151,
#   'patientid': 151,
#   'insuranceid': 1151,
#   'doctor': 'TaraMoreno',
#   'hospitalname': 'PerryLittle,andMoore',
#   'intakedate': '09/01/2020',
#   'dischargedate': '09/17/2020',
#   'roomnumber': 208,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2151},
#  {'admissionid': 2152,
#   'patientid': 152,
#   'insuranceid': 1152,
#   'doctor': 'KristieMorgan',
#   'hospitalname': 'AndersonGroup',
#   'intakedate': '05/26/2021',
#   'dischargedate': '06/22/2021',
#   'roomnumber': 267,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2152},
#  {'admissionid': 2153,
#   'patientid': 153,
#   'insuranceid': 1153,
#   'doctor': 'JosephJones',
#   'hospitalname': 'RodriguezandSons',
#   'intakedate': '06/22/2022',
#   'dischargedate': '07/22/2022',
#   'roomnumber': 154,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2153},
#  {'admissionid': 2154,
#   'patientid': 154,
#   'insuranceid': 1154,
#   'doctor': 'MariaTran',
#   'hospitalname': 'Thomas-Huber',
#   'intakedate': '05/17/2023',
#   'dischargedate': '05/31/2023',
#   'roomnumber': 293,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2154},
#  {'admissionid': 2155,
#   'patientid': 155,
#   'insuranceid': 1155,
#   'doctor': 'KellyMurphy',
#   'hospitalname': 'RobinsonInc',
#   'intakedate': '06/23/2021',
#   'dischargedate': '07/09/2021',
#   'roomnumber': 196,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2155},
#  {'admissionid': 2156,
#   'patientid': 156,
#   'insuranceid': 1156,
#   'doctor': 'KatherineBrown',
#   'hospitalname': 'Wood-Mathews',
#   'intakedate': '11/17/2023',
#   'dischargedate': '11/25/2023',
#   'roomnumber': 466,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2156},
#  {'admissionid': 2157,
#   'patientid': 157,
#   'insuranceid': 1157,
#   'doctor': 'ElizabethFrank',
#   'hospitalname': 'WalkerandGardnerFernandez,',
#   'intakedate': '10/11/2020',
#   'dischargedate': '10/21/2020',
#   'roomnumber': 468,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2157},
#  {'admissionid': 2158,
#   'patientid': 158,
#   'insuranceid': 1158,
#   'doctor': 'AlyssaEdwards',
#   'hospitalname': 'SmithandJohnston,Collins',
#   'intakedate': '08/10/2021',
#   'dischargedate': '08/27/2021',
#   'roomnumber': 114,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2158},
#  {'admissionid': 2159,
#   'patientid': 159,
#   'insuranceid': 1159,
#   'doctor': 'JesseThomas',
#   'hospitalname': 'SonsMillerand',
#   'intakedate': '08/29/2023',
#   'dischargedate': '09/07/2023',
#   'roomnumber': 408,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2159},
#  {'admissionid': 2160,
#   'patientid': 160,
#   'insuranceid': 1160,
#   'doctor': 'EricaMccormick',
#   'hospitalname': 'Donaldson-Frey',
#   'intakedate': '02/27/2020',
#   'dischargedate': '03/26/2020',
#   'roomnumber': 453,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2160},
#  {'admissionid': 2161,
#   'patientid': 161,
#   'insuranceid': 1161,
#   'doctor': 'AmberHolmes',
#   'hospitalname': 'Brown-Yoder',
#   'intakedate': '07/07/2021',
#   'dischargedate': '07/15/2021',
#   'roomnumber': 261,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2161},
#  {'admissionid': 2162,
#   'patientid': 162,
#   'insuranceid': 1162,
#   'doctor': 'AustinJackson',
#   'hospitalname': 'MorganRiosandKeller,',
#   'intakedate': '06/03/2022',
#   'dischargedate': '06/27/2022',
#   'roomnumber': 115,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2162},
#  {'admissionid': 2163,
#   'patientid': 163,
#   'insuranceid': 1163,
#   'doctor': 'ShaneMorris',
#   'hospitalname': 'Gonzalez-King',
#   'intakedate': '02/20/2020',
#   'dischargedate': '03/01/2020',
#   'roomnumber': 167,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2163},
#  {'admissionid': 2164,
#   'patientid': 164,
#   'insuranceid': 1164,
#   'doctor': 'BrentSmith',
#   'hospitalname': 'WagnerLtd',
#   'intakedate': '02/05/2021',
#   'dischargedate': '03/05/2021',
#   'roomnumber': 179,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2164},
#  {'admissionid': 2165,
#   'patientid': 165,
#   'insuranceid': 1165,
#   'doctor': 'KaylaDavis',
#   'hospitalname': 'andBrownWhite,Jones',
#   'intakedate': '10/24/2020',
#   'dischargedate': '11/02/2020',
#   'roomnumber': 490,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2165},
#  {'admissionid': 2166,
#   'patientid': 166,
#   'insuranceid': 1166,
#   'doctor': 'RoseZuniga',
#   'hospitalname': 'James-Smith',
#   'intakedate': '12/06/2023',
#   'dischargedate': '12/19/2023',
#   'roomnumber': 258,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2166},
#  {'admissionid': 2167,
#   'patientid': 167,
#   'insuranceid': 1167,
#   'doctor': 'EthanWagner',
#   'hospitalname': 'HansonGroup',
#   'intakedate': '12/21/2021',
#   'dischargedate': '12/30/2021',
#   'roomnumber': 483,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2167},
#  {'admissionid': 2168,
#   'patientid': 168,
#   'insuranceid': 1168,
#   'doctor': 'PhillipWilliams',
#   'hospitalname': 'Mcclain-Reed',
#   'intakedate': '09/03/2023',
#   'dischargedate': '09/30/2023',
#   'roomnumber': 273,
# ...
#   'intakedate': '09/30/2019',
#   'dischargedate': '10/10/2019',
#   'roomnumber': 290,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2945},
#  {'admissionid': 2946,
#   'patientid': 946,
#   'insuranceid': 1946,
#   'doctor': 'DorothyGarcia',
#   'hospitalname': 'WilliamsReynoldsandRangel,',
#   'intakedate': '07/23/2022',
#   'dischargedate': '08/16/2022',
#   'roomnumber': 142,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2946},
#  {'admissionid': 2947,
#   'patientid': 947,
#   'insuranceid': 1947,
#   'doctor': 'JohnSanders',
#   'hospitalname': 'SheltonJohnson,andGreen',
#   'intakedate': '05/11/2020',
#   'dischargedate': '06/06/2020',
#   'roomnumber': 256,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2947},
#  {'admissionid': 2948,
#   'patientid': 948,
#   'insuranceid': 1948,
#   'doctor': 'AshleeCooper',
#   'hospitalname': 'Lopez,andHowardMorrison',
#   'intakedate': '08/01/2019',
#   'dischargedate': '08/08/2019',
#   'roomnumber': 194,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2948},
#  {'admissionid': 2949,
#   'patientid': 949,
#   'insuranceid': 1949,
#   'doctor': 'NicoleVance',
#   'hospitalname': 'SonsandCortez',
#   'intakedate': '09/06/2019',
#   'dischargedate': '09/15/2019',
#   'roomnumber': 203,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2949},
#  {'admissionid': 2950,
#   'patientid': 950,
#   'insuranceid': 1950,
#   'doctor': 'KarenLynn',
#   'hospitalname': 'RobertsLtd',
#   'intakedate': '01/28/2023',
#   'dischargedate': '02/26/2023',
#   'roomnumber': 383,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2950},
#  {'admissionid': 2951,
#   'patientid': 951,
#   'insuranceid': 1951,
#   'doctor': 'RachelLopez',
#   'hospitalname': 'Sellers-Shepard',
#   'intakedate': '09/11/2023',
#   'dischargedate': '10/11/2023',
#   'roomnumber': 454,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2951},
#  {'admissionid': 2952,
#   'patientid': 952,
#   'insuranceid': 1952,
#   'doctor': 'SamuelWilliams',
#   'hospitalname': 'LloydScott,andReese',
#   'intakedate': '03/11/2020',
#   'dischargedate': '03/18/2020',
#   'roomnumber': 384,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2952},
#  {'admissionid': 2953,
#   'patientid': 953,
#   'insuranceid': 1953,
#   'doctor': 'StevenRogers',
#   'hospitalname': 'Gibson-Osborne',
#   'intakedate': '03/07/2021',
#   'dischargedate': '03/21/2021',
#   'roomnumber': 124,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2953},
#  {'admissionid': 2954,
#   'patientid': 954,
#   'insuranceid': 1954,
#   'doctor': 'MelanieLloyd',
#   'hospitalname': 'Matthews-Morgan',
#   'intakedate': '04/03/2024',
#   'dischargedate': '04/10/2024',
#   'roomnumber': 238,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2954},
#  {'admissionid': 2955,
#   'patientid': 955,
#   'insuranceid': 1955,
#   'doctor': 'BobbyMayo',
#   'hospitalname': 'ScottandSons',
#   'intakedate': '12/25/2022',
#   'dischargedate': '01/10/2023',
#   'roomnumber': 437,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2955},
#  {'admissionid': 2956,
#   'patientid': 956,
#   'insuranceid': 1956,
#   'doctor': 'FernandoHodge',
#   'hospitalname': 'Diaz-Richards',
#   'intakedate': '04/01/2020',
#   'dischargedate': '04/26/2020',
#   'roomnumber': 187,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2956},
#  {'admissionid': 2957,
#   'patientid': 957,
#   'insuranceid': 1957,
#   'doctor': 'ValerieSimmons',
#   'hospitalname': 'LLCJohnson',
#   'intakedate': '01/23/2020',
#   'dischargedate': '02/20/2020',
#   'roomnumber': 354,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2957},
#  {'admissionid': 2958,
#   'patientid': 958,
#   'insuranceid': 1958,
#   'doctor': 'CherylHerrera',
#   'hospitalname': 'MurphyGroup',
#   'intakedate': '02/10/2023',
#   'dischargedate': '02/25/2023',
#   'roomnumber': 449,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2958},
#  {'admissionid': 2959,
#   'patientid': 959,
#   'insuranceid': 1959,
#   'doctor': 'JohnRodriguezMD',
#   'hospitalname': 'BarajasandByrd,Wolf',
#   'intakedate': '10/20/2023',
#   'dischargedate': '10/28/2023',
#   'roomnumber': 329,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2959},
#  {'admissionid': 2960,
#   'patientid': 960,
#   'insuranceid': 1960,
#   'doctor': 'AshleyJackson',
#   'hospitalname': 'SalazarNewmanWhite,and',
#   'intakedate': '07/15/2020',
#   'dischargedate': '08/11/2020',
#   'roomnumber': 472,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2960},
#  {'admissionid': 2961,
#   'patientid': 961,
#   'insuranceid': 1961,
#   'doctor': 'SamuelHebert',
#   'hospitalname': 'Hancock-Lewis',
#   'intakedate': '01/14/2023',
#   'dischargedate': '02/08/2023',
#   'roomnumber': 425,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2961},
#  {'admissionid': 2962,
#   'patientid': 962,
#   'insuranceid': 1962,
#   'doctor': 'RyanGarcia',
#   'hospitalname': 'Barrett-Wright',
#   'intakedate': '06/19/2021',
#   'dischargedate': '07/14/2021',
#   'roomnumber': 465,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2962},
#  {'admissionid': 2963,
#   'patientid': 963,
#   'insuranceid': 1963,
#   'doctor': 'KelliGutierrez',
#   'hospitalname': 'BowersBlankenshipJackson,and',
#   'intakedate': '05/18/2020',
#   'dischargedate': '05/19/2020',
#   'roomnumber': 169,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2963},
#  {'admissionid': 2964,
#   'patientid': 964,
#   'insuranceid': 1964,
#   'doctor': 'KennethWatson',
#   'hospitalname': 'Hahn-Wilson',
#   'intakedate': '05/16/2020',
#   'dischargedate': '06/15/2020',
#   'roomnumber': 493,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2964},
#  {'admissionid': 2965,
#   'patientid': 965,
#   'insuranceid': 1965,
#   'doctor': 'JoDonaldson',
#   'hospitalname': 'RamirezandNelson,Collins',
#   'intakedate': '03/11/2021',
#   'dischargedate': '04/02/2021',
#   'roomnumber': 304,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2965},
#  {'admissionid': 2966,
#   'patientid': 966,
#   'insuranceid': 1966,
#   'doctor': 'RonaldPatrick',
#   'hospitalname': 'Sosa-Jackson',
#   'intakedate': '02/05/2023',
#   'dischargedate': '02/12/2023',
#   'roomnumber': 462,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2966},
#  {'admissionid': 2967,
#   'patientid': 967,
#   'insuranceid': 1967,
#   'doctor': 'LonniePatton',
#   'hospitalname': 'Dillon-Richard',
#   'intakedate': '10/19/2021',
#   'dischargedate': '11/12/2021',
#   'roomnumber': 186,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2967},
#  {'admissionid': 2968,
#   'patientid': 968,
#   'insuranceid': 1968,
#   'doctor': 'GabrielleHendrix',
#   'hospitalname': 'StokesandSons',
#   'intakedate': '09/07/2019',
#   'dischargedate': '09/29/2019',
#   'roomnumber': 424,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2968},
#  {'admissionid': 2969,
#   'patientid': 969,
#   'insuranceid': 1969,
#   'doctor': 'BrandyParsons',
#   'hospitalname': 'IncNguyen',
#   'intakedate': '05/26/2021',
#   'dischargedate': '06/20/2021',
#   'roomnumber': 478,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2969},
#  {'admissionid': 2970,
#   'patientid': 970,
#   'insuranceid': 1970,
#   'doctor': 'AnthonyNorris',
#   'hospitalname': 'Gallagher-Hernandez',
#   'intakedate': '05/07/2021',
#   'dischargedate': '05/27/2021',
#   'roomnumber': 124,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2970},
#  {'admissionid': 2971,
#   'patientid': 971,
#   'insuranceid': 1971,
#   'doctor': 'KristinaMendezMD',
#   'hospitalname': 'JohnsonDavidCarpenter,and',
#   'intakedate': '01/17/2023',
#   'dischargedate': '01/29/2023',
#   'roomnumber': 294,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2971},
#  {'admissionid': 2972,
#   'patientid': 972,
#   'insuranceid': 1972,
#   'doctor': 'JustinClark',
#   'hospitalname': 'andMontesMarshallValdez,',
#   'intakedate': '03/05/2020',
#   'dischargedate': '03/06/2020',
#   'roomnumber': 282,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2972},
#  {'admissionid': 2973,
#   'patientid': 973,
#   'insuranceid': 1973,
#   'doctor': 'CharlesSchmidt',
#   'hospitalname': 'PLCKelly',
#   'intakedate': '09/16/2022',
#   'dischargedate': '10/16/2022',
#   'roomnumber': 408,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2973},
#  {'admissionid': 2974,
#   'patientid': 974,
#   'insuranceid': 1974,
#   'doctor': 'JohnnyAlvarado',
#   'hospitalname': 'Wilson-Sherman',
#   'intakedate': '06/03/2022',
#   'dischargedate': '06/28/2022',
#   'roomnumber': 229,
#   'carelevel': 'Elective',
#   'testresults': 'Abnormal',
#   '_id': 2974},
#  {'admissionid': 2975,
#   'patientid': 975,
#   'insuranceid': 1975,
#   'doctor': 'PatriciaKidd',
#   'hospitalname': 'PetersonGroup',
#   'intakedate': '12/30/2020',
#   'dischargedate': '01/26/2021',
#   'roomnumber': 493,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2975},
#  {'admissionid': 2976,
#   'patientid': 976,
#   'insuranceid': 1976,
#   'doctor': 'ChristopherFleming',
#   'hospitalname': 'Hall-Taylor',
#   'intakedate': '08/09/2020',
#   'dischargedate': '08/15/2020',
#   'roomnumber': 142,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2976},
#  {'admissionid': 2977,
#   'patientid': 977,
#   'insuranceid': 1977,
#   'doctor': 'RobertHiggins',
#   'hospitalname': 'RiosPLC',
#   'intakedate': '03/10/2021',
#   'dischargedate': '03/29/2021',
#   'roomnumber': 187,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2977},
#  {'admissionid': 2978,
#   'patientid': 978,
#   'insuranceid': 1978,
#   'doctor': 'AdrianPowell',
#   'hospitalname': 'Lutz,LesterandKelly',
#   'intakedate': '03/15/2021',
#   'dischargedate': '03/26/2021',
#   'roomnumber': 178,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2978},
#  {'admissionid': 2979,
#   'patientid': 979,
#   'insuranceid': 1979,
#   'doctor': 'AlexanderRivera',
#   'hospitalname': 'Scott,MooreandBrewer',
#   'intakedate': '08/23/2021',
#   'dischargedate': '08/24/2021',
#   'roomnumber': 132,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2979},
#  {'admissionid': 2980,
#   'patientid': 980,
#   'insuranceid': 1980,
#   'doctor': 'PamJohnson',
#   'hospitalname': 'SullivanHendersonLloyd,and',
#   'intakedate': '11/11/2023',
#   'dischargedate': '11/28/2023',
#   'roomnumber': 406,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2980},
#  {'admissionid': 2981,
#   'patientid': 981,
#   'insuranceid': 1981,
#   'doctor': 'TracyHoward',
#   'hospitalname': 'andRhodesTrujillo,Booth',
#   'intakedate': '12/31/2023',
#   'dischargedate': '01/27/2024',
#   'roomnumber': 326,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2981},
#  {'admissionid': 2982,
#   'patientid': 982,
#   'insuranceid': 1982,
#   'doctor': 'MatthewTaylor',
#   'hospitalname': 'Bailey-White',
#   'intakedate': '09/21/2019',
#   'dischargedate': '10/20/2019',
#   'roomnumber': 406,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2982},
#  {'admissionid': 2983,
#   'patientid': 983,
#   'insuranceid': 1983,
#   'doctor': 'SharonHarding',
#   'hospitalname': 'BridgesInc',
#   'intakedate': '11/04/2022',
#   'dischargedate': '11/13/2022',
#   'roomnumber': 334,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 2983},
#  {'admissionid': 2984,
#   'patientid': 984,
#   'insuranceid': 1984,
#   'doctor': 'KristineBrowning',
#   'hospitalname': 'JacksonCarr,Garciaand',
#   'intakedate': '08/08/2019',
#   'dischargedate': '08/19/2019',
#   'roomnumber': 286,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2984},
#  {'admissionid': 2985,
#   'patientid': 985,
#   'insuranceid': 1985,
#   'doctor': 'TimothyKim',
#   'hospitalname': 'Richardson-Griffin',
#   'intakedate': '10/05/2023',
#   'dischargedate': '10/08/2023',
#   'roomnumber': 346,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2985},
#  {'admissionid': 2986,
#   'patientid': 986,
#   'insuranceid': 1986,
#   'doctor': 'JoshuaRoss',
#   'hospitalname': 'Allen-Campbell',
#   'intakedate': '08/28/2020',
#   'dischargedate': '09/04/2020',
#   'roomnumber': 159,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2986},
#  {'admissionid': 2987,
#   'patientid': 987,
#   'insuranceid': 1987,
#   'doctor': 'LindaAdams',
#   'hospitalname': 'Ferguson-Liu',
#   'intakedate': '07/08/2020',
#   'dischargedate': '07/13/2020',
#   'roomnumber': 311,
#   'carelevel': 'Emergency',
#   'testresults': 'Abnormal',
#   '_id': 2987},
#  {'admissionid': 2988,
#   'patientid': 988,
#   'insuranceid': 1988,
#   'doctor': 'RichardAndrews',
#   'hospitalname': 'LeeLtd',
#   'intakedate': '10/06/2023',
#   'dischargedate': '10/09/2023',
#   'roomnumber': 438,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2988},
#  {'admissionid': 2989,
#   'patientid': 989,
#   'insuranceid': 1989,
#   'doctor': 'JulieWarren',
#   'hospitalname': 'Baldwin-Marshall',
#   'intakedate': '07/01/2023',
#   'dischargedate': '07/05/2023',
#   'roomnumber': 103,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2989},
#  {'admissionid': 2990,
#   'patientid': 990,
#   'insuranceid': 1990,
#   'doctor': 'AngelaMathis',
#   'hospitalname': 'NormanPLC',
#   'intakedate': '08/07/2021',
#   'dischargedate': '08/20/2021',
#   'roomnumber': 101,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2990},
#  {'admissionid': 2991,
#   'patientid': 991,
#   'insuranceid': 1991,
#   'doctor': 'BethWilliams',
#   'hospitalname': 'Boyd-Fisher',
#   'intakedate': '05/13/2020',
#   'dischargedate': '05/26/2020',
#   'roomnumber': 291,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2991},
#  {'admissionid': 2992,
#   'patientid': 992,
#   'insuranceid': 1992,
#   'doctor': 'AlejandraWilliams',
#   'hospitalname': 'IncDavis',
#   'intakedate': '09/26/2023',
#   'dischargedate': '09/29/2023',
#   'roomnumber': 313,
#   'carelevel': 'Urgent',
#   'testresults': 'Normal',
#   '_id': 2992},
#  {'admissionid': 2993,
#   'patientid': 993,
#   'insuranceid': 1993,
#   'doctor': 'JenniferMitchell',
#   'hospitalname': 'PerryInc',
#   'intakedate': '06/14/2023',
#   'dischargedate': '06/15/2023',
#   'roomnumber': 228,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2993},
#  {'admissionid': 2994,
#   'patientid': 994,
#   'insuranceid': 1994,
#   'doctor': 'BradleyHunter',
#   'hospitalname': 'andBrownLarsonMoyer,',
#   'intakedate': '05/05/2024',
#   'dischargedate': '05/07/2024',
#   'roomnumber': 415,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2994},
#  {'admissionid': 2995,
#   'patientid': 995,
#   'insuranceid': 1995,
#   'doctor': 'ToddHouston',
#   'hospitalname': 'Soto-Boyle',
#   'intakedate': '04/03/2023',
#   'dischargedate': '04/11/2023',
#   'roomnumber': 431,
#   'carelevel': 'Elective',
#   'testresults': 'Normal',
#   '_id': 2995},
#  {'admissionid': 2996,
#   'patientid': 996,
#   'insuranceid': 1996,
#   'doctor': 'MichaelGrant',
#   'hospitalname': 'Jones-Ellis',
#   'intakedate': '10/24/2021',
#   'dischargedate': '11/13/2021',
#   'roomnumber': 454,
#   'carelevel': 'Emergency',
#   'testresults': 'Normal',
#   '_id': 2996},
#  {'admissionid': 2997,
#   'patientid': 997,
#   'insuranceid': 1997,
#   'doctor': 'DebraCarpenter',
#   'hospitalname': 'Jenkins,MathewsandHo',
#   'intakedate': '05/24/2023',
#   'dischargedate': '06/09/2023',
#   'roomnumber': 445,
#   'carelevel': 'Urgent',
#   'testresults': 'Abnormal',
#   '_id': 2997},
#  {'admissionid': 2998,
#   'patientid': 998,
#   'insuranceid': 1998,
#   'doctor': 'AmandaJohnson',
#   'hospitalname': 'VillaInc',
#   'intakedate': '12/20/2019',
#   'dischargedate': '01/17/2020',
#   'roomnumber': 174,
#   'carelevel': 'Urgent',
#   'testresults': 'Inconclusive',
#   '_id': 2998},
#  {'admissionid': 2999,
#   'patientid': 999,
#   'insuranceid': 1999,
#   'doctor': 'JosephFlores',
#   'hospitalname': 'CastroPLC',
#   'intakedate': '04/27/2022',
#   'dischargedate': '05/04/2022',
#   'roomnumber': 341,
#   'carelevel': 'Elective',
#   'testresults': 'Inconclusive',
#   '_id': 2999},
#  {'admissionid': 3000,
#   'patientid': 1000,
#   'insuranceid': 2000,
#   'doctor': 'KyleGray',
#   'hospitalname': 'Ortiz-Martin',
#   'intakedate': '11/14/2019',
#   'dischargedate': '11/16/2019',
#   'roomnumber': 161,
#   'carelevel': 'Emergency',
#   'testresults': 'Inconclusive',
#   '_id': 3000},
#  ...]

# %%
csv_to_json_mongo("insurance_table.csv", "insurance.json", "insuranceid")
# Out:
# [{'insuranceid': 1001,
#   'patientid': 1,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 18856.28131,
#   'benefit': 'Senior',
#   '_id': 1001},
#  {'insuranceid': 1002,
#   'patientid': 2,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 33643.32729,
#   'benefit': 'Standard',
#   '_id': 1002},
#  {'insuranceid': 1003,
#   'patientid': 3,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 27955.09608,
#   'benefit': 'Standard',
#   '_id': 1003},
#  {'insuranceid': 1004,
#   'patientid': 4,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 37909.78241,
#   'benefit': 'Premium',
#   '_id': 1004},
#  {'insuranceid': 1005,
#   'patientid': 5,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 14238.31781,
#   'benefit': 'Premium',
#   '_id': 1005},
#  {'insuranceid': 1006,
#   'patientid': 6,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 48145.11095,
#   'benefit': 'Premium',
#   '_id': 1006},
#  {'insuranceid': 1007,
#   'patientid': 7,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 19580.87234,
#   'benefit': 'Premium',
#   '_id': 1007},
#  {'insuranceid': 1008,
#   'patientid': 8,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 45820.46272,
#   'benefit': 'Premium',
#   '_id': 1008},
#  {'insuranceid': 1009,
#   'patientid': 9,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 50119.22279,
#   'benefit': 'Family',
#   '_id': 1009},
#  {'insuranceid': 1010,
#   'patientid': 10,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 19784.63106,
#   'benefit': 'Senior',
#   '_id': 1010},
#  {'insuranceid': 1011,
#   'patientid': 11,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 12576.79561,
#   'benefit': 'Standard',
#   '_id': 1011},
#  {'insuranceid': 1012,
#   'patientid': 12,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 7999.58688,
#   'benefit': 'Senior',
#   '_id': 1012},
#  {'insuranceid': 1013,
#   'patientid': 13,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 43282.28336,
#   'benefit': 'Family',
#   '_id': 1013},
#  {'insuranceid': 1014,
#   'patientid': 14,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 33207.70663,
#   'benefit': 'Standard',
#   '_id': 1014},
#  {'insuranceid': 1015,
#   'patientid': 15,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 40701.59923,
#   'benefit': 'Standard',
#   '_id': 1015},
#  {'insuranceid': 1016,
#   'patientid': 16,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 12263.35743,
#   'benefit': 'Senior',
#   '_id': 1016},
#  {'insuranceid': 1017,
#   'patientid': 17,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 24499.8479,
#   'benefit': 'Senior',
#   '_id': 1017},
#  {'insuranceid': 1018,
#   'patientid': 18,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 17440.46544,
#   'benefit': 'Family',
#   '_id': 1018},
#  {'insuranceid': 1019,
#   'patientid': 19,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 18843.02302,
#   'benefit': 'Premium',
#   '_id': 1019},
#  {'insuranceid': 1020,
#   'patientid': 20,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 23762.20358,
#   'benefit': 'Premium',
#   '_id': 1020},
#  {'insuranceid': 1021,
#   'patientid': 21,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 42.51458855,
#   'benefit': 'Senior',
#   '_id': 1021},
#  {'insuranceid': 1022,
#   'patientid': 22,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 17695.91162,
#   'benefit': 'Premium',
#   '_id': 1022},
#  {'insuranceid': 1023,
#   'patientid': 23,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 5998.102908,
#   'benefit': 'Family',
#   '_id': 1023},
#  {'insuranceid': 1024,
#   'patientid': 24,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 25250.05243,
#   'benefit': 'Standard',
#   '_id': 1024},
#  {'insuranceid': 1025,
#   'patientid': 25,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 33211.29542,
#   'benefit': 'Premium',
#   '_id': 1025},
#  {'insuranceid': 1026,
#   'patientid': 26,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 19746.83201,
#   'benefit': 'Standard',
#   '_id': 1026},
#  {'insuranceid': 1027,
#   'patientid': 27,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 26786.52956,
#   'benefit': 'Family',
#   '_id': 1027},
#  {'insuranceid': 1028,
#   'patientid': 28,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 18834.80134,
#   'benefit': 'Family',
#   '_id': 1028},
#  {'insuranceid': 1029,
#   'patientid': 29,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 32643.29935,
#   'benefit': 'Family',
#   '_id': 1029},
#  {'insuranceid': 1030,
#   'patientid': 30,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 5767.011054,
#   'benefit': 'Senior',
#   '_id': 1030},
#  {'insuranceid': 1031,
#   'patientid': 31,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 47909.12881,
#   'benefit': 'Senior',
#   '_id': 1031},
#  {'insuranceid': 1032,
#   'patientid': 32,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25835.32359,
#   'benefit': 'Senior',
#   '_id': 1032},
#  {'insuranceid': 1033,
#   'patientid': 33,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 17993.2262,
#   'benefit': 'Senior',
#   '_id': 1033},
#  {'insuranceid': 1034,
#   'patientid': 34,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 21185.95353,
#   'benefit': 'Family',
#   '_id': 1034},
#  {'insuranceid': 1035,
#   'patientid': 35,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 8408.949354,
#   'benefit': 'Standard',
#   '_id': 1035},
#  {'insuranceid': 1036,
#   'patientid': 36,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 45453.41855,
#   'benefit': 'Standard',
#   '_id': 1036},
#  {'insuranceid': 1037,
#   'patientid': 37,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 4397.776995,
#   'benefit': 'Senior',
#   '_id': 1037},
#  {'insuranceid': 1038,
#   'patientid': 38,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 9380.325968,
#   'benefit': 'Family',
#   '_id': 1038},
#  {'insuranceid': 1039,
#   'patientid': 39,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 48290.69341,
#   'benefit': 'Senior',
#   '_id': 1039},
#  {'insuranceid': 1040,
#   'patientid': 40,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 32973.94083,
#   'benefit': 'Family',
#   '_id': 1040},
#  {'insuranceid': 1041,
#   'patientid': 41,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 49943.2785,
#   'benefit': 'Standard',
#   '_id': 1041},
#  {'insuranceid': 1042,
#   'patientid': 42,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 35633.95545,
#   'benefit': 'Standard',
#   '_id': 1042},
#  {'insuranceid': 1043,
#   'patientid': 43,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 25966.32861,
#   'benefit': 'Standard',
#   '_id': 1043},
#  {'insuranceid': 1044,
#   'patientid': 44,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 21784.44507,
#   'benefit': 'Standard',
#   '_id': 1044},
#  {'insuranceid': 1045,
#   'patientid': 45,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 42684.55888,
#   'benefit': 'Standard',
#   '_id': 1045},
#  {'insuranceid': 1046,
#   'patientid': 46,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 45585.88656,
#   'benefit': 'Premium',
#   '_id': 1046},
#  {'insuranceid': 1047,
#   'patientid': 47,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 29615.44186,
#   'benefit': 'Senior',
#   '_id': 1047},
#  {'insuranceid': 1048,
#   'patientid': 48,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 36992.27369,
#   'benefit': 'Premium',
#   '_id': 1048},
#  {'insuranceid': 1049,
#   'patientid': 49,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 28051.49948,
#   'benefit': 'Family',
#   '_id': 1049},
#  {'insuranceid': 1050,
#   'patientid': 50,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 16320.23245,
#   'benefit': 'Standard',
#   '_id': 1050},
#  {'insuranceid': 1051,
#   'patientid': 51,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 30590.54181,
#   'benefit': 'Standard',
#   '_id': 1051},
#  {'insuranceid': 1052,
#   'patientid': 52,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 14681.01636,
#   'benefit': 'Premium',
#   '_id': 1052},
#  {'insuranceid': 1053,
#   'patientid': 53,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 21879.53191,
#   'benefit': 'Standard',
#   '_id': 1053},
#  {'insuranceid': 1054,
#   'patientid': 54,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 6767.634397,
#   'benefit': 'Senior',
#   '_id': 1054},
#  {'insuranceid': 1055,
#   'patientid': 55,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 19973.46293,
#   'benefit': 'Senior',
#   '_id': 1055},
#  {'insuranceid': 1056,
#   'patientid': 56,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 14362.31449,
#   'benefit': 'Family',
#   '_id': 1056},
#  {'insuranceid': 1057,
#   'patientid': 57,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 10300.65731,
#   'benefit': 'Premium',
#   '_id': 1057},
#  {'insuranceid': 1058,
#   'patientid': 58,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 37951.66491,
#   'benefit': 'Family',
#   '_id': 1058},
#  {'insuranceid': 1059,
#   'patientid': 59,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 6733.990947,
#   'benefit': 'Standard',
#   '_id': 1059},
#  {'insuranceid': 1060,
#   'patientid': 60,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 17839.74565,
#   'benefit': 'Family',
#   '_id': 1060},
#  {'insuranceid': 1061,
#   'patientid': 61,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 24637.09006,
#   'benefit': 'Premium',
#   '_id': 1061},
#  {'insuranceid': 1062,
#   'patientid': 62,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 39723.16605,
#   'benefit': 'Senior',
#   '_id': 1062},
#  {'insuranceid': 1063,
#   'patientid': 63,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 48407.38629,
#   'benefit': 'Premium',
#   '_id': 1063},
#  {'insuranceid': 1064,
#   'patientid': 64,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 5517.393642,
#   'benefit': 'Family',
#   '_id': 1064},
#  {'insuranceid': 1065,
#   'patientid': 65,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 19183.16889,
#   'benefit': 'Premium',
#   '_id': 1065},
#  {'insuranceid': 1066,
#   'patientid': 66,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 8320.660803,
#   'benefit': 'Senior',
#   '_id': 1066},
#  {'insuranceid': 1067,
#   'patientid': 67,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 10107.18765,
#   'benefit': 'Family',
#   '_id': 1067},
#  {'insuranceid': 1068,
#   'patientid': 68,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 49402.29837,
#   'benefit': 'Family',
#   '_id': 1068},
#  {'insuranceid': 1069,
#   'patientid': 69,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 35776.81511,
#   'benefit': 'Family',
#   '_id': 1069},
#  {'insuranceid': 1070,
#   'patientid': 70,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 20227.86373,
#   'benefit': 'Senior',
#   '_id': 1070},
#  {'insuranceid': 1071,
#   'patientid': 71,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 19328.11858,
#   'benefit': 'Premium',
#   '_id': 1071},
#  {'insuranceid': 1072,
#   'patientid': 72,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 46956.54573,
#   'benefit': 'Standard',
#   '_id': 1072},
#  {'insuranceid': 1073,
#   'patientid': 73,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 10709.69039,
#   'benefit': 'Family',
#   '_id': 1073},
#  {'insuranceid': 1074,
#   'patientid': 74,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 45353.99078,
#   'benefit': 'Standard',
#   '_id': 1074},
#  {'insuranceid': 1075,
#   'patientid': 75,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 8451.001758,
#   'benefit': 'Standard',
#   '_id': 1075},
#  {'insuranceid': 1076,
#   'patientid': 76,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 29850.87973,
#   'benefit': 'Family',
#   '_id': 1076},
#  {'insuranceid': 1077,
#   'patientid': 77,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 42696.52116,
#   'benefit': 'Premium',
#   '_id': 1077},
#  {'insuranceid': 1078,
#   'patientid': 78,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 2305.13914,
#   'benefit': 'Standard',
#   '_id': 1078},
#  {'insuranceid': 1079,
#   'patientid': 79,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 44437.47067,
#   'benefit': 'Premium',
#   '_id': 1079},
#  {'insuranceid': 1080,
#   'patientid': 80,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 29504.38744,
#   'benefit': 'Senior',
#   '_id': 1080},
#  {'insuranceid': 1081,
#   'patientid': 81,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 34617.78834,
#   'benefit': 'Family',
#   '_id': 1081},
#  {'insuranceid': 1082,
#   'patientid': 82,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 46814.0112,
#   'benefit': 'Standard',
#   '_id': 1082},
#  {'insuranceid': 1083,
#   'patientid': 83,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 20257.54428,
#   'benefit': 'Senior',
#   '_id': 1083},
#  {'insuranceid': 1084,
#   'patientid': 84,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 22841.36388,
#   'benefit': 'Premium',
#   '_id': 1084},
#  {'insuranceid': 1085,
#   'patientid': 85,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 10283.71686,
#   'benefit': 'Standard',
#   '_id': 1085},
#  {'insuranceid': 1086,
#   'patientid': 86,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 1586.476601,
#   'benefit': 'Family',
#   '_id': 1086},
#  {'insuranceid': 1087,
#   'patientid': 87,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 34774.35113,
#   'benefit': 'Standard',
#   '_id': 1087},
#  {'insuranceid': 1088,
#   'patientid': 88,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 24870.10366,
#   'benefit': 'Standard',
#   '_id': 1088},
#  {'insuranceid': 1089,
#   'patientid': 89,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 39476.94751,
#   'benefit': 'Standard',
#   '_id': 1089},
#  {'insuranceid': 1090,
#   'patientid': 90,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 26062.43432,
#   'benefit': 'Standard',
#   '_id': 1090},
#  {'insuranceid': 1091,
#   'patientid': 91,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 25302.11263,
#   'benefit': 'Family',
#   '_id': 1091},
#  {'insuranceid': 1092,
#   'patientid': 92,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 10661.51065,
#   'benefit': 'Senior',
#   '_id': 1092},
#  {'insuranceid': 1093,
#   'patientid': 93,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 30358.19458,
#   'benefit': 'Standard',
#   '_id': 1093},
#  {'insuranceid': 1094,
#   'patientid': 94,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 23684.52547,
#   'benefit': 'Premium',
#   '_id': 1094},
#  {'insuranceid': 1095,
#   'patientid': 95,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 3908.946568,
#   'benefit': 'Senior',
#   '_id': 1095},
#  {'insuranceid': 1096,
#   'patientid': 96,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 25503.67381,
#   'benefit': 'Standard',
#   '_id': 1096},
#  {'insuranceid': 1097,
#   'patientid': 97,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 6312.607691,
#   'benefit': 'Standard',
#   '_id': 1097},
#  {'insuranceid': 1098,
#   'patientid': 98,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 21772.3414,
#   'benefit': 'Senior',
#   '_id': 1098},
#  {'insuranceid': 1099,
#   'patientid': 99,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 30437.00179,
#   'benefit': 'Family',
#   '_id': 1099},
#  {'insuranceid': 1100,
#   'patientid': 100,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 28837.67705,
#   'benefit': 'Standard',
#   '_id': 1100},
#  {'insuranceid': 1101,
#   'patientid': 101,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 25425.72786,
#   'benefit': 'Senior',
#   '_id': 1101},
#  {'insuranceid': 1102,
#   'patientid': 102,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 7187.272346,
#   'benefit': 'Standard',
#   '_id': 1102},
#  {'insuranceid': 1103,
#   'patientid': 103,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 3125.736477,
#   'benefit': 'Premium',
#   '_id': 1103},
#  {'insuranceid': 1104,
#   'patientid': 104,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 31516.10073,
#   'benefit': 'Family',
#   '_id': 1104},
#  {'insuranceid': 1105,
#   'patientid': 105,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 40014.76235,
#   'benefit': 'Standard',
#   '_id': 1105},
#  {'insuranceid': 1106,
#   'patientid': 106,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 40782.92781,
#   'benefit': 'Standard',
#   '_id': 1106},
#  {'insuranceid': 1107,
#   'patientid': 107,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 3879.084602,
#   'benefit': 'Family',
#   '_id': 1107},
#  {'insuranceid': 1108,
#   'patientid': 108,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 24948.47782,
#   'benefit': 'Family',
#   '_id': 1108},
#  {'insuranceid': 1109,
#   'patientid': 109,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 37734.74218,
#   'benefit': 'Senior',
#   '_id': 1109},
#  {'insuranceid': 1110,
#   'patientid': 110,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 27360.46189,
#   'benefit': 'Family',
#   '_id': 1110},
#  {'insuranceid': 1111,
#   'patientid': 111,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 37405.69653,
#   'benefit': 'Premium',
#   '_id': 1111},
#  {'insuranceid': 1112,
#   'patientid': 112,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 31485.97316,
#   'benefit': 'Standard',
#   '_id': 1112},
#  {'insuranceid': 1113,
#   'patientid': 113,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 23737.39932,
#   'benefit': 'Standard',
#   '_id': 1113},
#  {'insuranceid': 1114,
#   'patientid': 114,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 3326.382675,
#   'benefit': 'Standard',
#   '_id': 1114},
#  {'insuranceid': 1115,
#   'patientid': 115,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 23067.67217,
#   'benefit': 'Family',
#   '_id': 1115},
#  {'insuranceid': 1116,
#   'patientid': 116,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 8521.214253,
#   'benefit': 'Senior',
#   '_id': 1116},
#  {'insuranceid': 1117,
#   'patientid': 117,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 47985.16734,
#   'benefit': 'Standard',
#   '_id': 1117},
#  {'insuranceid': 1118,
#   'patientid': 118,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25230.24688,
#   'benefit': 'Family',
#   '_id': 1118},
#  {'insuranceid': 1119,
#   'patientid': 119,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 10352.20849,
#   'benefit': 'Premium',
#   '_id': 1119},
#  {'insuranceid': 1120,
#   'patientid': 120,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 6175.867249,
#   'benefit': 'Senior',
#   '_id': 1120},
#  {'insuranceid': 1121,
#   'patientid': 121,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 23499.93625,
#   'benefit': 'Family',
#   '_id': 1121},
#  {'insuranceid': 1122,
#   'patientid': 122,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 33681.57264,
#   'benefit': 'Standard',
#   '_id': 1122},
#  {'insuranceid': 1123,
#   'patientid': 123,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 39957.94062,
#   'benefit': 'Premium',
#   '_id': 1123},
#  {'insuranceid': 1124,
#   'patientid': 124,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 49833.70772,
#   'benefit': 'Family',
#   '_id': 1124},
#  {'insuranceid': 1125,
#   'patientid': 125,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 48175.46612,
#   'benefit': 'Family',
#   '_id': 1125},
#  {'insuranceid': 1126,
#   'patientid': 126,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 40133.96739,
#   'benefit': 'Family',
#   '_id': 1126},
#  {'insuranceid': 1127,
#   'patientid': 127,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 9585.952128,
#   'benefit': 'Family',
#   '_id': 1127},
#  {'insuranceid': 1128,
#   'patientid': 128,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 40693.35422,
#   'benefit': 'Standard',
#   '_id': 1128},
#  {'insuranceid': 1129,
#   'patientid': 129,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 16399.26576,
#   'benefit': 'Premium',
#   '_id': 1129},
#  {'insuranceid': 1130,
#   'patientid': 130,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 44939.56552,
#   'benefit': 'Family',
#   '_id': 1130},
#  {'insuranceid': 1131,
#   'patientid': 131,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 10663.91001,
#   'benefit': 'Premium',
#   '_id': 1131},
#  {'insuranceid': 1132,
#   'patientid': 132,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 22564.78798,
#   'benefit': 'Premium',
#   '_id': 1132},
#  {'insuranceid': 1133,
#   'patientid': 133,
#   'insuranceprovider': 'Aetna',
#   'billingcost': -502.5078127,
#   'benefit': 'Family',
#   '_id': 1133},
#  {'insuranceid': 1134,
#   'patientid': 134,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 34758.25675,
#   'benefit': 'Premium',
#   '_id': 1134},
#  {'insuranceid': 1135,
#   'patientid': 135,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 46377.86515,
#   'benefit': 'Standard',
#   '_id': 1135},
#  {'insuranceid': 1136,
#   'patientid': 136,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 7555.772965,
#   'benefit': 'Standard',
#   '_id': 1136},
#  {'insuranceid': 1137,
#   'patientid': 137,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 14299.99345,
#   'benefit': 'Premium',
#   '_id': 1137},
#  {'insuranceid': 1138,
#   'patientid': 138,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 46429.5082,
#   'benefit': 'Family',
#   '_id': 1138},
#  {'insuranceid': 1139,
#   'patientid': 139,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 17978.95074,
#   'benefit': 'Standard',
#   '_id': 1139},
#  {'insuranceid': 1140,
#   'patientid': 140,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 32629.06775,
#   'benefit': 'Senior',
#   '_id': 1140},
#  {'insuranceid': 1141,
#   'patientid': 141,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 22356.22649,
#   'benefit': 'Senior',
#   '_id': 1141},
#  {'insuranceid': 1142,
#   'patientid': 142,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 48995.98059,
#   'benefit': 'Family',
#   '_id': 1142},
#  {'insuranceid': 1143,
#   'patientid': 143,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 4532.483554,
#   'benefit': 'Family',
#   '_id': 1143},
#  {'insuranceid': 1144,
#   'patientid': 144,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 35521.58215,
#   'benefit': 'Premium',
#   '_id': 1144},
#  {'insuranceid': 1145,
#   'patientid': 145,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 1589.503523,
#   'benefit': 'Senior',
#   '_id': 1145},
#  {'insuranceid': 1146,
#   'patientid': 146,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 22950.65114,
#   'benefit': 'Senior',
#   '_id': 1146},
#  {'insuranceid': 1147,
#   'patientid': 147,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 2678.953936,
#   'benefit': 'Senior',
#   '_id': 1147},
#  {'insuranceid': 1148,
#   'patientid': 148,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 39615.60066,
#   'benefit': 'Family',
#   '_id': 1148},
#  {'insuranceid': 1149,
#   'patientid': 149,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 13355.78209,
#   'benefit': 'Family',
#   '_id': 1149},
#  {'insuranceid': 1150,
#   'patientid': 150,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 32561.53041,
#   'benefit': 'Premium',
#   '_id': 1150},
#  {'insuranceid': 1151,
#   'patientid': 151,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 29221.34021,
#   'benefit': 'Family',
#   '_id': 1151},
#  {'insuranceid': 1152,
#   'patientid': 152,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 12880.65241,
#   'benefit': 'Standard',
#   '_id': 1152},
#  {'insuranceid': 1153,
#   'patientid': 153,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 15475.40324,
#   'benefit': 'Premium',
#   '_id': 1153},
#  {'insuranceid': 1154,
#   'patientid': 154,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 27309.43676,
#   'benefit': 'Family',
#   '_id': 1154},
#  {'insuranceid': 1155,
#   'patientid': 155,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 1897.891727,
#   'benefit': 'Senior',
#   '_id': 1155},
#  {'insuranceid': 1156,
#   'patientid': 156,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 31308.20601,
#   'benefit': 'Family',
#   '_id': 1156},
#  {'insuranceid': 1157,
#   'patientid': 157,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 42792.24128,
#   'benefit': 'Standard',
#   '_id': 1157},
#  {'insuranceid': 1158,
#   'patientid': 158,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 14377.33432,
#   'benefit': 'Senior',
#   '_id': 1158},
#  {'insuranceid': 1159,
#   'patientid': 159,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 1150.874986,
#   'benefit': 'Standard',
#   '_id': 1159},
#  {'insuranceid': 1160,
#   'patientid': 160,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 41939.11994,
#   'benefit': 'Premium',
#   '_id': 1160},
#  {'insuranceid': 1161,
#   'patientid': 161,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 41982.3744,
#   'benefit': 'Senior',
#   '_id': 1161},
#  {'insuranceid': 1162,
#   'patientid': 162,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 33861.01863,
#   'benefit': 'Premium',
#   '_id': 1162},
#  {'insuranceid': 1163,
#   'patientid': 163,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 49321.15763,
#   'benefit': 'Premium',
#   '_id': 1163},
#  {'insuranceid': 1164,
#   'patientid': 164,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 47433.27865,
#   'benefit': 'Senior',
#   '_id': 1164},
#  {'insuranceid': 1165,
#   'patientid': 165,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 19065.06089,
#   'benefit': 'Senior',
#   '_id': 1165},
#  {'insuranceid': 1166,
#   'patientid': 166,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 50142.02695,
#   'benefit': 'Senior',
#   '_id': 1166},
#  {'insuranceid': 1167,
#   'patientid': 167,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 12081.67903,
#   'benefit': 'Family',
#   '_id': 1167},
#  {'insuranceid': 1168,
#   'patientid': 168,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 18030.79078,
#   'benefit': 'Family',
#   '_id': 1168},
#  {'insuranceid': 1169,
#   'patientid': 169,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 5142.163763,
#   'benefit': 'Senior',
#   '_id': 1169},
#  {'insuranceid': 1170,
#   'patientid': 170,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 19851.24293,
#   'benefit': 'Standard',
#   '_id': 1170},
#  {'insuranceid': 1171,
#   'patientid': 171,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 20545.87176,
#   'benefit': 'Standard',
#   '_id': 1171},
#  {'insuranceid': 1172,
#   'patientid': 172,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 36869.72574,
#   'benefit': 'Standard',
#   '_id': 1172},
#  {'insuranceid': 1173,
#   'patientid': 173,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 40598.42257,
#   'benefit': 'Senior',
#   '_id': 1173},
#  {'insuranceid': 1174,
#   'patientid': 174,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 18198.05852,
#   'benefit': 'Senior',
#   '_id': 1174},
#  {'insuranceid': 1175,
#   'patientid': 175,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 4920.041189,
#   'benefit': 'Premium',
#   '_id': 1175},
#  {'insuranceid': 1176,
#   'patientid': 176,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 3864.139499,
#   'benefit': 'Premium',
#   '_id': 1176},
#  {'insuranceid': 1177,
#   'patientid': 177,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 21562.86105,
#   'benefit': 'Premium',
#   '_id': 1177},
#  {'insuranceid': 1178,
#   'patientid': 178,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 11815.20274,
#   'benefit': 'Standard',
#   '_id': 1178},
#  {'insuranceid': 1179,
#   'patientid': 179,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 25796.86967,
#   'benefit': 'Family',
#   '_id': 1179},
#  {'insuranceid': 1180,
#   'patientid': 180,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 4266.784307,
#   'benefit': 'Family',
#   '_id': 1180},
#  {'insuranceid': 1181,
#   'patientid': 181,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 4751.162741,
#   'benefit': 'Senior',
#   '_id': 1181},
#  {'insuranceid': 1182,
#   'patientid': 182,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 17968.49599,
#   'benefit': 'Standard',
#   '_id': 1182},
#  {'insuranceid': 1183,
#   'patientid': 183,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 11311.32735,
#   'benefit': 'Senior',
#   '_id': 1183},
#  {'insuranceid': 1184,
#   'patientid': 184,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 47242.2243,
#   'benefit': 'Family',
#   '_id': 1184},
#  {'insuranceid': 1185,
#   'patientid': 185,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 17670.50522,
#   'benefit': 'Standard',
#   '_id': 1185},
#  {'insuranceid': 1186,
#   'patientid': 186,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 5714.748018,
#   'benefit': 'Family',
#   '_id': 1186},
#  {'insuranceid': 1187,
#   'patientid': 187,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 5985.978487,
#   'benefit': 'Senior',
#   '_id': 1187},
#  {'insuranceid': 1188,
#   'patientid': 188,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 27385.73623,
#   'benefit': 'Family',
#   '_id': 1188},
#  {'insuranceid': 1189,
#   'patientid': 189,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 3730.002191,
#   'benefit': 'Family',
#   '_id': 1189},
#  {'insuranceid': 1190,
#   'patientid': 190,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 22480.96593,
#   'benefit': 'Family',
#   '_id': 1190},
#  {'insuranceid': 1191,
#   'patientid': 191,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 35022.31671,
#   'benefit': 'Family',
#   '_id': 1191},
#  {'insuranceid': 1192,
#   'patientid': 192,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 45072.41826,
#   'benefit': 'Family',
#   '_id': 1192},
#  {'insuranceid': 1193,
#   'patientid': 193,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 45902.70764,
#   'benefit': 'Family',
#   '_id': 1193},
#  {'insuranceid': 1194,
#   'patientid': 194,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 28899.18576,
#   'benefit': 'Family',
#   '_id': 1194},
#  {'insuranceid': 1195,
#   'patientid': 195,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 39003.18144,
#   'benefit': 'Standard',
#   '_id': 1195},
#  {'insuranceid': 1196,
#   'patientid': 196,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 10348.81852,
#   'benefit': 'Senior',
#   '_id': 1196},
#  {'insuranceid': 1197,
#   'patientid': 197,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 14371.5397,
#   'benefit': 'Family',
#   '_id': 1197},
#  {'insuranceid': 1198,
#   'patientid': 198,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 13769.40313,
#   'benefit': 'Family',
#   '_id': 1198},
#  {'insuranceid': 1199,
#   'patientid': 199,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 35868.53864,
#   'benefit': 'Senior',
#   '_id': 1199},
#  {'insuranceid': 1200,
#   'patientid': 200,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 35205.2846,
#   'benefit': 'Senior',
#   '_id': 1200},
#  {'insuranceid': 1201,
#   'patientid': 201,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 21576.50235,
#   'benefit': 'Standard',
#   '_id': 1201},
#  {'insuranceid': 1202,
#   'patientid': 202,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 18771.01069,
#   'benefit': 'Family',
#   '_id': 1202},
#  {'insuranceid': 1203,
#   'patientid': 203,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 21668.56451,
#   'benefit': 'Premium',
#   '_id': 1203},
#  {'insuranceid': 1204,
#   'patientid': 204,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 36339.81908,
#   'benefit': 'Senior',
#   '_id': 1204},
#  {'insuranceid': 1205,
#   'patientid': 205,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 40825.18442,
#   'benefit': 'Senior',
#   '_id': 1205},
#  {'insuranceid': 1206,
#   'patientid': 206,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 40469.56626,
#   'benefit': 'Premium',
#   '_id': 1206},
#  {'insuranceid': 1207,
#   'patientid': 207,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 25749.52084,
#   'benefit': 'Standard',
#   '_id': 1207},
#  {'insuranceid': 1208,
#   'patientid': 208,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 15841.20168,
#   'benefit': 'Senior',
#   '_id': 1208},
#  {'insuranceid': 1209,
#   'patientid': 209,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 36086.57208,
#   'benefit': 'Family',
#   '_id': 1209},
#  {'insuranceid': 1210,
#   'patientid': 210,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 32085.22765,
#   'benefit': 'Family',
#   '_id': 1210},
#  {'insuranceid': 1211,
#   'patientid': 211,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 12356.56065,
#   'benefit': 'Standard',
#   '_id': 1211},
#  {'insuranceid': 1212,
#   'patientid': 212,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 15367.41132,
#   'benefit': 'Standard',
#   '_id': 1212},
#  {'insuranceid': 1213,
#   'patientid': 213,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 40190.20292,
#   'benefit': 'Standard',
#   '_id': 1213},
#  {'insuranceid': 1214,
#   'patientid': 214,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 3872.096985,
#   'benefit': 'Family',
#   '_id': 1214},
#  {'insuranceid': 1215,
#   'patientid': 215,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 3311.589106,
#   'benefit': 'Family',
#   '_id': 1215},
#  {'insuranceid': 1216,
#   'patientid': 216,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 18524.86664,
#   'benefit': 'Family',
#   '_id': 1216},
#  {'insuranceid': 1217,
#   'patientid': 217,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 30107.48704,
#   'benefit': 'Premium',
#   '_id': 1217},
#  {'insuranceid': 1218,
#   'patientid': 218,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 15826.10128,
#   'benefit': 'Premium',
#   '_id': 1218},
#  {'insuranceid': 1219,
#   'patientid': 219,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 26437.77463,
#   'benefit': 'Premium',
#   '_id': 1219},
#  {'insuranceid': 1220,
#   'patientid': 220,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 49663.45287,
#   'benefit': 'Standard',
#   '_id': 1220},
#  {'insuranceid': 1221,
#   'patientid': 221,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 27278.23689,
#   'benefit': 'Family',
#   '_id': 1221},
#  {'insuranceid': 1222,
#   'patientid': 222,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 33170.43674,
#   'benefit': 'Standard',
#   '_id': 1222},
#  {'insuranceid': 1223,
#   'patientid': 223,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 1791.389001,
#   'benefit': 'Senior',
#   '_id': 1223},
#  {'insuranceid': 1224,
#   'patientid': 224,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 31188.04149,
#   'benefit': 'Senior',
#   '_id': 1224},
#  {'insuranceid': 1225,
#   'patientid': 225,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 13854.64576,
#   'benefit': 'Standard',
#   '_id': 1225},
#  {'insuranceid': 1226,
#   'patientid': 226,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 11870.90838,
#   'benefit': 'Premium',
#   '_id': 1226},
#  {'insuranceid': 1227,
#   'patientid': 227,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25574.12762,
#   'benefit': 'Standard',
#   '_id': 1227},
#  {'insuranceid': 1228,
#   'patientid': 228,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 6132.404095,
#   'benefit': 'Standard',
#   '_id': 1228},
#  {'insuranceid': 1229,
#   'patientid': 229,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 33343.90249,
#   'benefit': 'Family',
#   '_id': 1229},
#  {'insuranceid': 1230,
#   'patientid': 230,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 43484.24975,
#   'benefit': 'Family',
#   '_id': 1230},
#  {'insuranceid': 1231,
#   'patientid': 231,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 7858.92686,
#   'benefit': 'Standard',
#   '_id': 1231},
#  {'insuranceid': 1232,
#   'patientid': 232,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 33161.9384,
#   'benefit': 'Standard',
#   '_id': 1232},
#  {'insuranceid': 1233,
#   'patientid': 233,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 2879.460532,
#   'benefit': 'Standard',
#   '_id': 1233},
#  {'insuranceid': 1234,
#   'patientid': 234,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 46492.86177,
#   'benefit': 'Standard',
#   '_id': 1234},
#  {'insuranceid': 1235,
#   'patientid': 235,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 5259.27305,
#   'benefit': 'Family',
#   '_id': 1235},
#  {'insuranceid': 1236,
#   'patientid': 236,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 2784.58249,
#   'benefit': 'Senior',
#   '_id': 1236},
#  {'insuranceid': 1237,
#   'patientid': 237,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 13418.21637,
#   'benefit': 'Premium',
#   '_id': 1237},
#  {'insuranceid': 1238,
#   'patientid': 238,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 36990.45578,
#   'benefit': 'Family',
#   '_id': 1238},
#  {'insuranceid': 1239,
#   'patientid': 239,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 43567.14416,
#   'benefit': 'Standard',
#   '_id': 1239},
#  {'insuranceid': 1240,
#   'patientid': 240,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 35570.07656,
#   'benefit': 'Premium',
#   '_id': 1240},
#  {'insuranceid': 1241,
#   'patientid': 241,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 6848.130427,
#   'benefit': 'Family',
#   '_id': 1241},
#  {'insuranceid': 1242,
#   'patientid': 242,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 4677.595847,
#   'benefit': 'Family',
#   '_id': 1242},
#  {'insuranceid': 1243,
#   'patientid': 243,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 35157.17027,
#   'benefit': 'Premium',
#   '_id': 1243},
#  {'insuranceid': 1244,
#   'patientid': 244,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 34719.17385,
#   'benefit': 'Family',
#   '_id': 1244},
#  {'insuranceid': 1245,
#   'patientid': 245,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 23775.44901,
#   'benefit': 'Standard',
#   '_id': 1245},
#  {'insuranceid': 1246,
#   'patientid': 246,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 17732.46937,
#   'benefit': 'Premium',
#   '_id': 1246},
#  {'insuranceid': 1247,
#   'patientid': 247,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 3845.397496,
#   'benefit': 'Family',
#   '_id': 1247},
#  {'insuranceid': 1248,
#   'patientid': 248,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 22401.55035,
#   'benefit': 'Standard',
#   '_id': 1248},
#  {'insuranceid': 1249,
#   'patientid': 249,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 23340.30472,
#   'benefit': 'Family',
#   '_id': 1249},
#  {'insuranceid': 1250,
#   'patientid': 250,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 3042.409184,
#   'benefit': 'Premium',
#   '_id': 1250},
#  {'insuranceid': 1251,
#   'patientid': 251,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 41817.67918,
#   'benefit': 'Family',
#   '_id': 1251},
#  {'insuranceid': 1252,
#   'patientid': 252,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 49700.32421,
#   'benefit': 'Standard',
#   '_id': 1252},
#  {'insuranceid': 1253,
#   'patientid': 253,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 45157.47112,
#   'benefit': 'Senior',
#   '_id': 1253},
#  {'insuranceid': 1254,
#   'patientid': 254,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 18832.10034,
#   'benefit': 'Family',
#   '_id': 1254},
#  {'insuranceid': 1255,
#   'patientid': 255,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 31732.13008,
#   'benefit': 'Senior',
#   '_id': 1255},
#  {'insuranceid': 1256,
#   'patientid': 256,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 42214.9797,
#   'benefit': 'Premium',
#   '_id': 1256},
#  {'insuranceid': 1257,
#   'patientid': 257,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 12400.2051,
#   'benefit': 'Standard',
#   '_id': 1257},
#  {'insuranceid': 1258,
#   'patientid': 258,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 1133.586476,
#   'benefit': 'Standard',
#   '_id': 1258},
#  {'insuranceid': 1259,
#   'patientid': 259,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 24340.32286,
#   'benefit': 'Premium',
#   '_id': 1259},
#  {'insuranceid': 1260,
#   'patientid': 260,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 39390.93555,
#   'benefit': 'Senior',
#   '_id': 1260},
#  {'insuranceid': 1261,
#   'patientid': 261,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 17012.5074,
#   'benefit': 'Family',
#   '_id': 1261},
#  {'insuranceid': 1262,
#   'patientid': 262,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 14493.6139,
#   'benefit': 'Family',
#   '_id': 1262},
#  {'insuranceid': 1263,
#   'patientid': 263,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 32679.26859,
#   'benefit': 'Senior',
#   '_id': 1263},
#  {'insuranceid': 1264,
#   'patientid': 264,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 6232.001787,
#   'benefit': 'Family',
#   '_id': 1264},
#  {'insuranceid': 1265,
#   'patientid': 265,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 22982.25212,
#   'benefit': 'Senior',
#   '_id': 1265},
#  {'insuranceid': 1266,
#   'patientid': 266,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 28213.81547,
#   'benefit': 'Family',
#   '_id': 1266},
#  {'insuranceid': 1267,
#   'patientid': 267,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 10645.56585,
#   'benefit': 'Standard',
#   '_id': 1267},
#  {'insuranceid': 1268,
#   'patientid': 268,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 35041.03097,
#   'benefit': 'Senior',
#   '_id': 1268},
#  {'insuranceid': 1269,
#   'patientid': 269,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 45980.29229,
#   'benefit': 'Standard',
#   '_id': 1269},
#  {'insuranceid': 1270,
#   'patientid': 270,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25163.82248,
#   'benefit': 'Premium',
#   '_id': 1270},
#  {'insuranceid': 1271,
#   'patientid': 271,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 43670.37819,
#   'benefit': 'Family',
#   '_id': 1271},
#  {'insuranceid': 1272,
#   'patientid': 272,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 33706.59767,
#   'benefit': 'Premium',
#   '_id': 1272},
#  {'insuranceid': 1273,
#   'patientid': 273,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 5549.785436,
#   'benefit': 'Standard',
#   '_id': 1273},
#  {'insuranceid': 1274,
#   'patientid': 274,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 49078.46901,
#   'benefit': 'Standard',
#   '_id': 1274},
#  {'insuranceid': 1275,
#   'patientid': 275,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 23687.99364,
#   'benefit': 'Premium',
#   '_id': 1275},
#  {'insuranceid': 1276,
#   'patientid': 276,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 17720.31873,
#   'benefit': 'Senior',
#   '_id': 1276},
#  {'insuranceid': 1277,
#   'patientid': 277,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 27361.24968,
#   'benefit': 'Standard',
#   '_id': 1277},
#  {'insuranceid': 1278,
#   'patientid': 278,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 39265.64605,
#   'benefit': 'Standard',
#   '_id': 1278},
#  {'insuranceid': 1279,
#   'patientid': 279,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 32868.08277,
#   'benefit': 'Senior',
#   '_id': 1279},
#  {'insuranceid': 1280,
#   'patientid': 280,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 22032.38959,
#   'benefit': 'Senior',
#   '_id': 1280},
#  {'insuranceid': 1281,
#   'patientid': 281,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 43165.69409,
#   'benefit': 'Premium',
#   '_id': 1281},
#  {'insuranceid': 1282,
#   'patientid': 282,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 1870.60844,
#   'benefit': 'Premium',
#   '_id': 1282},
#  {'insuranceid': 1283,
#   'patientid': 283,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 50254.20183,
#   'benefit': 'Premium',
#   '_id': 1283},
#  {'insuranceid': 1284,
#   'patientid': 284,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 23159.66303,
#   'benefit': 'Standard',
#   '_id': 1284},
#  {'insuranceid': 1285,
#   'patientid': 285,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 11469.39059,
#   'benefit': 'Senior',
#   '_id': 1285},
#  {'insuranceid': 1286,
#   'patientid': 286,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 35435.17015,
#   'benefit': 'Standard',
#   '_id': 1286},
#  {'insuranceid': 1287,
#   'patientid': 287,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 26139.78595,
#   'benefit': 'Senior',
#   '_id': 1287},
#  {'insuranceid': 1288,
#   'patientid': 288,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 21296.51873,
#   'benefit': 'Premium',
#   '_id': 1288},
#  {'insuranceid': 1289,
#   'patientid': 289,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 8421.915385,
#   'benefit': 'Premium',
#   '_id': 1289},
#  {'insuranceid': 1290,
#   'patientid': 290,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 23892.55267,
#   'benefit': 'Standard',
#   '_id': 1290},
#  {'insuranceid': 1291,
#   'patientid': 291,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 8171.462615,
#   'benefit': 'Standard',
#   '_id': 1291},
#  {'insuranceid': 1292,
#   'patientid': 292,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 23457.30929,
#   'benefit': 'Senior',
#   '_id': 1292},
#  {'insuranceid': 1293,
#   'patientid': 293,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 25787.43914,
#   'benefit': 'Family',
#   '_id': 1293},
#  {'insuranceid': 1294,
#   'patientid': 294,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 28525.52477,
#   'benefit': 'Senior',
#   '_id': 1294},
#  {'insuranceid': 1295,
#   'patientid': 295,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 17182.86981,
#   'benefit': 'Standard',
#   '_id': 1295},
#  {'insuranceid': 1296,
#   'patientid': 296,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 20980.30306,
#   'benefit': 'Senior',
#   '_id': 1296},
#  {'insuranceid': 1297,
#   'patientid': 297,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 4243.202644,
#   'benefit': 'Premium',
#   '_id': 1297},
#  {'insuranceid': 1298,
#   'patientid': 298,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 40137.78917,
#   'benefit': 'Senior',
#   '_id': 1298},
#  {'insuranceid': 1299,
#   'patientid': 299,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 30676.44176,
#   'benefit': 'Standard',
#   '_id': 1299},
#  {'insuranceid': 1300,
#   'patientid': 300,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 45594.88907,
#   'benefit': 'Senior',
#   '_id': 1300},
#  {'insuranceid': 1301,
#   'patientid': 301,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 29076.62961,
#   'benefit': 'Family',
#   '_id': 1301},
#  {'insuranceid': 1302,
#   'patientid': 302,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 5223.502081,
#   'benefit': 'Standard',
#   '_id': 1302},
#  {'insuranceid': 1303,
#   'patientid': 303,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 41840.65803,
#   'benefit': 'Standard',
#   '_id': 1303},
#  {'insuranceid': 1304,
#   'patientid': 304,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 26504.86591,
#   'benefit': 'Premium',
#   '_id': 1304},
#  {'insuranceid': 1305,
#   'patientid': 305,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 7946.129113,
#   'benefit': 'Premium',
#   '_id': 1305},
#  {'insuranceid': 1306,
#   'patientid': 306,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 18689.13845,
#   'benefit': 'Family',
#   '_id': 1306},
#  {'insuranceid': 1307,
#   'patientid': 307,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 30051.97507,
#   'benefit': 'Family',
#   '_id': 1307},
#  {'insuranceid': 1308,
#   'patientid': 308,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 22913.55425,
#   'benefit': 'Standard',
#   '_id': 1308},
#  {'insuranceid': 1309,
#   'patientid': 309,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 36238.57685,
#   'benefit': 'Senior',
#   '_id': 1309},
#  {'insuranceid': 1310,
#   'patientid': 310,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 25217.45618,
#   'benefit': 'Standard',
#   '_id': 1310},
#  {'insuranceid': 1311,
#   'patientid': 311,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 41548.40831,
#   'benefit': 'Senior',
#   '_id': 1311},
#  {'insuranceid': 1312,
#   'patientid': 312,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 7562.39438,
#   'benefit': 'Premium',
#   '_id': 1312},
#  {'insuranceid': 1313,
#   'patientid': 313,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 386.0540547,
#   'benefit': 'Senior',
#   '_id': 1313},
#  {'insuranceid': 1314,
#   'patientid': 314,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 31491.61471,
#   'benefit': 'Standard',
#   '_id': 1314},
#  {'insuranceid': 1315,
#   'patientid': 315,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 34224.34834,
#   'benefit': 'Premium',
#   '_id': 1315},
#  {'insuranceid': 1316,
#   'patientid': 316,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 23673.72174,
#   'benefit': 'Senior',
#   '_id': 1316},
#  {'insuranceid': 1317,
#   'patientid': 317,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 40301.99731,
#   'benefit': 'Standard',
#   '_id': 1317},
#  {'insuranceid': 1318,
#   'patientid': 318,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 37116.16381,
#   'benefit': 'Senior',
#   '_id': 1318},
#  {'insuranceid': 1319,
#   'patientid': 319,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 38606.9638,
#   'benefit': 'Premium',
#   '_id': 1319},
#  {'insuranceid': 1320,
#   'patientid': 320,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 17813.9305,
#   'benefit': 'Family',
#   '_id': 1320},
#  {'insuranceid': 1321,
#   'patientid': 321,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 20773.02332,
#   'benefit': 'Senior',
#   '_id': 1321},
#  {'insuranceid': 1322,
#   'patientid': 322,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 9609.522307,
#   'benefit': 'Standard',
#   '_id': 1322},
#  {'insuranceid': 1323,
#   'patientid': 323,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 3771.237166,
#   'benefit': 'Premium',
#   '_id': 1323},
#  {'insuranceid': 1324,
#   'patientid': 324,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 51587.93682,
#   'benefit': 'Premium',
#   '_id': 1324},
#  {'insuranceid': 1325,
# ...
#   '_id': 1892},
#  {'insuranceid': 1893,
#   'patientid': 893,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 15072.57093,
#   'benefit': 'Senior',
#   '_id': 1893},
#  {'insuranceid': 1894,
#   'patientid': 894,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 7380.731298,
#   'benefit': 'Premium',
#   '_id': 1894},
#  {'insuranceid': 1895,
#   'patientid': 895,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 5936.363411,
#   'benefit': 'Premium',
#   '_id': 1895},
#  {'insuranceid': 1896,
#   'patientid': 896,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 7704.300991,
#   'benefit': 'Premium',
#   '_id': 1896},
#  {'insuranceid': 1897,
#   'patientid': 897,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 12099.7931,
#   'benefit': 'Senior',
#   '_id': 1897},
#  {'insuranceid': 1898,
#   'patientid': 898,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 17202.89964,
#   'benefit': 'Senior',
#   '_id': 1898},
#  {'insuranceid': 1899,
#   'patientid': 899,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25275.94423,
#   'benefit': 'Premium',
#   '_id': 1899},
#  {'insuranceid': 1900,
#   'patientid': 900,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 17002.30327,
#   'benefit': 'Standard',
#   '_id': 1900},
#  {'insuranceid': 1901,
#   'patientid': 901,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 4794.751355,
#   'benefit': 'Family',
#   '_id': 1901},
#  {'insuranceid': 1902,
#   'patientid': 902,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 7241.195989,
#   'benefit': 'Senior',
#   '_id': 1902},
#  {'insuranceid': 1903,
#   'patientid': 903,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 45218.74105,
#   'benefit': 'Senior',
#   '_id': 1903},
#  {'insuranceid': 1904,
#   'patientid': 904,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 32052.05646,
#   'benefit': 'Premium',
#   '_id': 1904},
#  {'insuranceid': 1905,
#   'patientid': 905,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 30718.54628,
#   'benefit': 'Senior',
#   '_id': 1905},
#  {'insuranceid': 1906,
#   'patientid': 906,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 51441.72905,
#   'benefit': 'Family',
#   '_id': 1906},
#  {'insuranceid': 1907,
#   'patientid': 907,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 1821.347946,
#   'benefit': 'Senior',
#   '_id': 1907},
#  {'insuranceid': 1908,
#   'patientid': 908,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 23857.49948,
#   'benefit': 'Premium',
#   '_id': 1908},
#  {'insuranceid': 1909,
#   'patientid': 909,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 4795.513439,
#   'benefit': 'Senior',
#   '_id': 1909},
#  {'insuranceid': 1910,
#   'patientid': 910,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 25500.707,
#   'benefit': 'Premium',
#   '_id': 1910},
#  {'insuranceid': 1911,
#   'patientid': 911,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 10837.61458,
#   'benefit': 'Senior',
#   '_id': 1911},
#  {'insuranceid': 1912,
#   'patientid': 912,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 46836.7059,
#   'benefit': 'Family',
#   '_id': 1912},
#  {'insuranceid': 1913,
#   'patientid': 913,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 11426.01213,
#   'benefit': 'Family',
#   '_id': 1913},
#  {'insuranceid': 1914,
#   'patientid': 914,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 20590.5154,
#   'benefit': 'Family',
#   '_id': 1914},
#  {'insuranceid': 1915,
#   'patientid': 915,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 28100.09253,
#   'benefit': 'Premium',
#   '_id': 1915},
#  {'insuranceid': 1916,
#   'patientid': 916,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 33188.92655,
#   'benefit': 'Senior',
#   '_id': 1916},
#  {'insuranceid': 1917,
#   'patientid': 917,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 47130.0256,
#   'benefit': 'Senior',
#   '_id': 1917},
#  {'insuranceid': 1918,
#   'patientid': 918,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 20361.86552,
#   'benefit': 'Premium',
#   '_id': 1918},
#  {'insuranceid': 1919,
#   'patientid': 919,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 11229.75549,
#   'benefit': 'Premium',
#   '_id': 1919},
#  {'insuranceid': 1920,
#   'patientid': 920,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 6969.091522,
#   'benefit': 'Standard',
#   '_id': 1920},
#  {'insuranceid': 1921,
#   'patientid': 921,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 31405.58063,
#   'benefit': 'Family',
#   '_id': 1921},
#  {'insuranceid': 1922,
#   'patientid': 922,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 22976.90758,
#   'benefit': 'Family',
#   '_id': 1922},
#  {'insuranceid': 1923,
#   'patientid': 923,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 32136.51041,
#   'benefit': 'Premium',
#   '_id': 1923},
#  {'insuranceid': 1924,
#   'patientid': 924,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 39313.88983,
#   'benefit': 'Senior',
#   '_id': 1924},
#  {'insuranceid': 1925,
#   'patientid': 925,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 5624.288669,
#   'benefit': 'Family',
#   '_id': 1925},
#  {'insuranceid': 1926,
#   'patientid': 926,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 5823.048061,
#   'benefit': 'Senior',
#   '_id': 1926},
#  {'insuranceid': 1927,
#   'patientid': 927,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 11628.61734,
#   'benefit': 'Standard',
#   '_id': 1927},
#  {'insuranceid': 1928,
#   'patientid': 928,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 8104.667977,
#   'benefit': 'Family',
#   '_id': 1928},
#  {'insuranceid': 1929,
#   'patientid': 929,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 12093.08681,
#   'benefit': 'Standard',
#   '_id': 1929},
#  {'insuranceid': 1930,
#   'patientid': 930,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 29465.81709,
#   'benefit': 'Senior',
#   '_id': 1930},
#  {'insuranceid': 1931,
#   'patientid': 931,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 22545.92923,
#   'benefit': 'Family',
#   '_id': 1931},
#  {'insuranceid': 1932,
#   'patientid': 932,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 2641.016179,
#   'benefit': 'Senior',
#   '_id': 1932},
#  {'insuranceid': 1933,
#   'patientid': 933,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 16527.25787,
#   'benefit': 'Family',
#   '_id': 1933},
#  {'insuranceid': 1934,
#   'patientid': 934,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 13624.82928,
#   'benefit': 'Premium',
#   '_id': 1934},
#  {'insuranceid': 1935,
#   'patientid': 935,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 39570.06896,
#   'benefit': 'Senior',
#   '_id': 1935},
#  {'insuranceid': 1936,
#   'patientid': 936,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 13256.41456,
#   'benefit': 'Senior',
#   '_id': 1936},
#  {'insuranceid': 1937,
#   'patientid': 937,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 32633.20307,
#   'benefit': 'Standard',
#   '_id': 1937},
#  {'insuranceid': 1938,
#   'patientid': 938,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 19720.0359,
#   'benefit': 'Standard',
#   '_id': 1938},
#  {'insuranceid': 1939,
#   'patientid': 939,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 46421.26125,
#   'benefit': 'Senior',
#   '_id': 1939},
#  {'insuranceid': 1940,
#   'patientid': 940,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 10767.37667,
#   'benefit': 'Premium',
#   '_id': 1940},
#  {'insuranceid': 1941,
#   'patientid': 941,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 47656.51701,
#   'benefit': 'Senior',
#   '_id': 1941},
#  {'insuranceid': 1942,
#   'patientid': 942,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 46186.16325,
#   'benefit': 'Premium',
#   '_id': 1942},
#  {'insuranceid': 1943,
#   'patientid': 943,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 44148.54288,
#   'benefit': 'Family',
#   '_id': 1943},
#  {'insuranceid': 1944,
#   'patientid': 944,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 12447.26512,
#   'benefit': 'Family',
#   '_id': 1944},
#  {'insuranceid': 1945,
#   'patientid': 945,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 43298.4337,
#   'benefit': 'Family',
#   '_id': 1945},
#  {'insuranceid': 1946,
#   'patientid': 946,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 33379.54547,
#   'benefit': 'Senior',
#   '_id': 1946},
#  {'insuranceid': 1947,
#   'patientid': 947,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 37553.16097,
#   'benefit': 'Premium',
#   '_id': 1947},
#  {'insuranceid': 1948,
#   'patientid': 948,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 44931.12877,
#   'benefit': 'Premium',
#   '_id': 1948},
#  {'insuranceid': 1949,
#   'patientid': 949,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 44595.97086,
#   'benefit': 'Premium',
#   '_id': 1949},
#  {'insuranceid': 1950,
#   'patientid': 950,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 10243.97206,
#   'benefit': 'Family',
#   '_id': 1950},
#  {'insuranceid': 1951,
#   'patientid': 951,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 8762.503072,
#   'benefit': 'Standard',
#   '_id': 1951},
#  {'insuranceid': 1952,
#   'patientid': 952,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 10363.66893,
#   'benefit': 'Premium',
#   '_id': 1952},
#  {'insuranceid': 1953,
#   'patientid': 953,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 22827.8109,
#   'benefit': 'Senior',
#   '_id': 1953},
#  {'insuranceid': 1954,
#   'patientid': 954,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 22913.34873,
#   'benefit': 'Family',
#   '_id': 1954},
#  {'insuranceid': 1955,
#   'patientid': 955,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 33800.90849,
#   'benefit': 'Standard',
#   '_id': 1955},
#  {'insuranceid': 1956,
#   'patientid': 956,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 23713.92381,
#   'benefit': 'Senior',
#   '_id': 1956},
#  {'insuranceid': 1957,
#   'patientid': 957,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 41794.35543,
#   'benefit': 'Standard',
#   '_id': 1957},
#  {'insuranceid': 1958,
#   'patientid': 958,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 40304.38007,
#   'benefit': 'Senior',
#   '_id': 1958},
#  {'insuranceid': 1959,
#   'patientid': 959,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 43825.05667,
#   'benefit': 'Standard',
#   '_id': 1959},
#  {'insuranceid': 1960,
#   'patientid': 960,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 16509.89323,
#   'benefit': 'Premium',
#   '_id': 1960},
#  {'insuranceid': 1961,
#   'patientid': 961,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 46268.72904,
#   'benefit': 'Family',
#   '_id': 1961},
#  {'insuranceid': 1962,
#   'patientid': 962,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 36272.75182,
#   'benefit': 'Family',
#   '_id': 1962},
#  {'insuranceid': 1963,
#   'patientid': 963,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 5614.518227,
#   'benefit': 'Standard',
#   '_id': 1963},
#  {'insuranceid': 1964,
#   'patientid': 964,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 21429.67391,
#   'benefit': 'Senior',
#   '_id': 1964},
#  {'insuranceid': 1965,
#   'patientid': 965,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 24057.47093,
#   'benefit': 'Senior',
#   '_id': 1965},
#  {'insuranceid': 1966,
#   'patientid': 966,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 22775.47094,
#   'benefit': 'Standard',
#   '_id': 1966},
#  {'insuranceid': 1967,
#   'patientid': 967,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 30953.78226,
#   'benefit': 'Senior',
#   '_id': 1967},
#  {'insuranceid': 1968,
#   'patientid': 968,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 12101.13066,
#   'benefit': 'Senior',
#   '_id': 1968},
#  {'insuranceid': 1969,
#   'patientid': 969,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 1478.181139,
#   'benefit': 'Standard',
#   '_id': 1969},
#  {'insuranceid': 1970,
#   'patientid': 970,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 37197.85565,
#   'benefit': 'Standard',
#   '_id': 1970},
#  {'insuranceid': 1971,
#   'patientid': 971,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 5407.728755,
#   'benefit': 'Senior',
#   '_id': 1971},
#  {'insuranceid': 1972,
#   'patientid': 972,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 6035.458069,
#   'benefit': 'Premium',
#   '_id': 1972},
#  {'insuranceid': 1973,
#   'patientid': 973,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 5778.245819,
#   'benefit': 'Standard',
#   '_id': 1973},
#  {'insuranceid': 1974,
#   'patientid': 974,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 46602.69268,
#   'benefit': 'Family',
#   '_id': 1974},
#  {'insuranceid': 1975,
#   'patientid': 975,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 47789.82597,
#   'benefit': 'Family',
#   '_id': 1975},
#  {'insuranceid': 1976,
#   'patientid': 976,
#   'insuranceprovider': 'Aetna',
#   'billingcost': 46608.39289,
#   'benefit': 'Senior',
#   '_id': 1976},
#  {'insuranceid': 1977,
#   'patientid': 977,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 8709.035963,
#   'benefit': 'Family',
#   '_id': 1977},
#  {'insuranceid': 1978,
#   'patientid': 978,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 18270.99527,
#   'benefit': 'Premium',
#   '_id': 1978},
#  {'insuranceid': 1979,
#   'patientid': 979,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 17679.02668,
#   'benefit': 'Premium',
#   '_id': 1979},
#  {'insuranceid': 1980,
#   'patientid': 980,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 21965.1474,
#   'benefit': 'Family',
#   '_id': 1980},
#  {'insuranceid': 1981,
#   'patientid': 981,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 27309.70788,
#   'benefit': 'Premium',
#   '_id': 1981},
#  {'insuranceid': 1982,
#   'patientid': 982,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 4437.95635,
#   'benefit': 'Standard',
#   '_id': 1982},
#  {'insuranceid': 1983,
#   'patientid': 983,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 15704.08922,
#   'benefit': 'Senior',
#   '_id': 1983},
#  {'insuranceid': 1984,
#   'patientid': 984,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 16528.80182,
#   'benefit': 'Family',
#   '_id': 1984},
#  {'insuranceid': 1985,
#   'patientid': 985,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 3621.161691,
#   'benefit': 'Senior',
#   '_id': 1985},
#  {'insuranceid': 1986,
#   'patientid': 986,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 47863.02392,
#   'benefit': 'Premium',
#   '_id': 1986},
#  {'insuranceid': 1987,
#   'patientid': 987,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 46772.5812,
#   'benefit': 'Premium',
#   '_id': 1987},
#  {'insuranceid': 1988,
#   'patientid': 988,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 18479.74328,
#   'benefit': 'Family',
#   '_id': 1988},
#  {'insuranceid': 1989,
#   'patientid': 989,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 7285.489592,
#   'benefit': 'Premium',
#   '_id': 1989},
#  {'insuranceid': 1990,
#   'patientid': 990,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 6818.72448,
#   'benefit': 'Senior',
#   '_id': 1990},
#  {'insuranceid': 1991,
#   'patientid': 991,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 14374.313,
#   'benefit': 'Family',
#   '_id': 1991},
#  {'insuranceid': 1992,
#   'patientid': 992,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 5936.177145,
#   'benefit': 'Family',
#   '_id': 1992},
#  {'insuranceid': 1993,
#   'patientid': 993,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 32897.26731,
#   'benefit': 'Premium',
#   '_id': 1993},
#  {'insuranceid': 1994,
#   'patientid': 994,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 3963.121128,
#   'benefit': 'Senior',
#   '_id': 1994},
#  {'insuranceid': 1995,
#   'patientid': 995,
#   'insuranceprovider': 'BlueCross',
#   'billingcost': 16057.82016,
#   'benefit': 'Senior',
#   '_id': 1995},
#  {'insuranceid': 1996,
#   'patientid': 996,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 44041.57374,
#   'benefit': 'Premium',
#   '_id': 1996},
#  {'insuranceid': 1997,
#   'patientid': 997,
#   'insuranceprovider': 'Medicare',
#   'billingcost': 15086.15878,
#   'benefit': 'Standard',
#   '_id': 1997},
#  {'insuranceid': 1998,
#   'patientid': 998,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 16377.52313,
#   'benefit': 'Family',
#   '_id': 1998},
#  {'insuranceid': 1999,
#   'patientid': 999,
#   'insuranceprovider': 'UnitedHealthcare',
#   'billingcost': 43488.83863,
#   'benefit': 'Standard',
#   '_id': 1999},
#  {'insuranceid': 2000,
#   'patientid': 1000,
#   'insuranceprovider': 'Cigna',
#   'billingcost': 43108.88806,
#   'benefit': 'Senior',
#   '_id': 2000},
#  ...]

# %%
csv_to_json_mongo("prescriptions_table.csv", "prescriptions.json", "prescriptionid")
# Out:
# [{'prescriptionid': 'P0001',
#   'patientid': 1,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0001'},
#  {'prescriptionid': 'P0002',
#   'patientid': 2,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0002'},
#  {'prescriptionid': 'P0003',
#   'patientid': 3,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0003'},
#  {'prescriptionid': 'P0004',
#   'patientid': 4,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0004'},
#  {'prescriptionid': 'P0005',
#   'patientid': 5,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0005'},
#  {'prescriptionid': 'P0006',
#   'patientid': 6,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0006'},
#  {'prescriptionid': 'P0007',
#   'patientid': 7,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0007'},
#  {'prescriptionid': 'P0008',
#   'patientid': 8,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0008'},
#  {'prescriptionid': 'P0009',
#   'patientid': 9,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0009'},
#  {'prescriptionid': 'P0010',
#   'patientid': 10,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0010'},
#  {'prescriptionid': 'P0011',
#   'patientid': 11,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0011'},
#  {'prescriptionid': 'P0012',
#   'patientid': 12,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0012'},
#  {'prescriptionid': 'P0013',
#   'patientid': 13,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0013'},
#  {'prescriptionid': 'P0014',
#   'patientid': 14,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0014'},
#  {'prescriptionid': 'P0015',
#   'patientid': 15,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0015'},
#  {'prescriptionid': 'P0016',
#   'patientid': 16,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0016'},
#  {'prescriptionid': 'P0017',
#   'patientid': 17,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0017'},
#  {'prescriptionid': 'P0018',
#   'patientid': 18,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0018'},
#  {'prescriptionid': 'P0019',
#   'patientid': 19,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0019'},
#  {'prescriptionid': 'P0020',
#   'patientid': 20,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0020'},
#  {'prescriptionid': 'P0021',
#   'patientid': 21,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0021'},
#  {'prescriptionid': 'P0022',
#   'patientid': 22,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0022'},
#  {'prescriptionid': 'P0023',
#   'patientid': 23,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0023'},
#  {'prescriptionid': 'P0024',
#   'patientid': 24,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0024'},
#  {'prescriptionid': 'P0025',
#   'patientid': 25,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0025'},
#  {'prescriptionid': 'P0026',
#   'patientid': 26,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0026'},
#  {'prescriptionid': 'P0027',
#   'patientid': 27,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0027'},
#  {'prescriptionid': 'P0028',
#   'patientid': 28,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0028'},
#  {'prescriptionid': 'P0029',
#   'patientid': 29,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0029'},
#  {'prescriptionid': 'P0030',
#   'patientid': 30,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0030'},
#  {'prescriptionid': 'P0031',
#   'patientid': 31,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0031'},
#  {'prescriptionid': 'P0032',
#   'patientid': 32,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0032'},
#  {'prescriptionid': 'P0033',
#   'patientid': 33,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0033'},
#  {'prescriptionid': 'P0034',
#   'patientid': 34,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0034'},
#  {'prescriptionid': 'P0035',
#   'patientid': 35,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0035'},
#  {'prescriptionid': 'P0036',
#   'patientid': 36,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0036'},
#  {'prescriptionid': 'P0037',
#   'patientid': 37,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0037'},
#  {'prescriptionid': 'P0038',
#   'patientid': 38,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0038'},
#  {'prescriptionid': 'P0039',
#   'patientid': 39,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0039'},
#  {'prescriptionid': 'P0040',
#   'patientid': 40,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0040'},
#  {'prescriptionid': 'P0041',
#   'patientid': 41,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0041'},
#  {'prescriptionid': 'P0042',
#   'patientid': 42,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0042'},
#  {'prescriptionid': 'P0043',
#   'patientid': 43,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0043'},
#  {'prescriptionid': 'P0044',
#   'patientid': 44,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0044'},
#  {'prescriptionid': 'P0045',
#   'patientid': 45,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0045'},
#  {'prescriptionid': 'P0046',
#   'patientid': 46,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0046'},
#  {'prescriptionid': 'P0047',
#   'patientid': 47,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0047'},
#  {'prescriptionid': 'P0048',
#   'patientid': 48,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0048'},
#  {'prescriptionid': 'P0049',
#   'patientid': 49,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0049'},
#  {'prescriptionid': 'P0050',
#   'patientid': 50,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0050'},
#  {'prescriptionid': 'P0051',
#   'patientid': 51,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0051'},
#  {'prescriptionid': 'P0052',
#   'patientid': 52,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0052'},
#  {'prescriptionid': 'P0053',
#   'patientid': 53,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0053'},
#  {'prescriptionid': 'P0054',
#   'patientid': 54,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0054'},
#  {'prescriptionid': 'P0055',
#   'patientid': 55,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0055'},
#  {'prescriptionid': 'P0056',
#   'patientid': 56,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0056'},
#  {'prescriptionid': 'P0057',
#   'patientid': 57,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0057'},
#  {'prescriptionid': 'P0058',
#   'patientid': 58,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0058'},
#  {'prescriptionid': 'P0059',
#   'patientid': 59,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0059'},
#  {'prescriptionid': 'P0060',
#   'patientid': 60,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0060'},
#  {'prescriptionid': 'P0061',
#   'patientid': 61,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0061'},
#  {'prescriptionid': 'P0062',
#   'patientid': 62,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0062'},
#  {'prescriptionid': 'P0063',
#   'patientid': 63,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0063'},
#  {'prescriptionid': 'P0064',
#   'patientid': 64,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0064'},
#  {'prescriptionid': 'P0065',
#   'patientid': 65,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0065'},
#  {'prescriptionid': 'P0066',
#   'patientid': 66,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0066'},
#  {'prescriptionid': 'P0067',
#   'patientid': 67,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0067'},
#  {'prescriptionid': 'P0068',
#   'patientid': 68,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0068'},
#  {'prescriptionid': 'P0069',
#   'patientid': 69,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0069'},
#  {'prescriptionid': 'P0070',
#   'patientid': 70,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0070'},
#  {'prescriptionid': 'P0071',
#   'patientid': 71,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0071'},
#  {'prescriptionid': 'P0072',
#   'patientid': 72,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0072'},
#  {'prescriptionid': 'P0073',
#   'patientid': 73,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0073'},
#  {'prescriptionid': 'P0074',
#   'patientid': 74,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0074'},
#  {'prescriptionid': 'P0075',
#   'patientid': 75,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0075'},
#  {'prescriptionid': 'P0076',
#   'patientid': 76,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0076'},
#  {'prescriptionid': 'P0077',
#   'patientid': 77,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0077'},
#  {'prescriptionid': 'P0078',
#   'patientid': 78,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0078'},
#  {'prescriptionid': 'P0079',
#   'patientid': 79,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0079'},
#  {'prescriptionid': 'P0080',
#   'patientid': 80,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0080'},
#  {'prescriptionid': 'P0081',
#   'patientid': 81,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0081'},
#  {'prescriptionid': 'P0082',
#   'patientid': 82,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0082'},
#  {'prescriptionid': 'P0083',
#   'patientid': 83,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0083'},
#  {'prescriptionid': 'P0084',
#   'patientid': 84,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0084'},
#  {'prescriptionid': 'P0085',
#   'patientid': 85,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0085'},
#  {'prescriptionid': 'P0086',
#   'patientid': 86,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0086'},
#  {'prescriptionid': 'P0087',
#   'patientid': 87,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0087'},
#  {'prescriptionid': 'P0088',
#   'patientid': 88,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0088'},
#  {'prescriptionid': 'P0089',
#   'patientid': 89,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0089'},
#  {'prescriptionid': 'P0090',
#   'patientid': 90,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0090'},
#  {'prescriptionid': 'P0091',
#   'patientid': 91,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0091'},
#  {'prescriptionid': 'P0092',
#   'patientid': 92,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0092'},
#  {'prescriptionid': 'P0093',
#   'patientid': 93,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0093'},
#  {'prescriptionid': 'P0094',
#   'patientid': 94,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0094'},
#  {'prescriptionid': 'P0095',
#   'patientid': 95,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0095'},
#  {'prescriptionid': 'P0096',
#   'patientid': 96,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0096'},
#  {'prescriptionid': 'P0097',
#   'patientid': 97,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0097'},
#  {'prescriptionid': 'P0098',
#   'patientid': 98,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0098'},
#  {'prescriptionid': 'P0099',
#   'patientid': 99,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0099'},
#  {'prescriptionid': 'P0100',
#   'patientid': 100,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0100'},
#  {'prescriptionid': 'P0101',
#   'patientid': 101,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0101'},
#  {'prescriptionid': 'P0102',
#   'patientid': 102,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0102'},
#  {'prescriptionid': 'P0103',
#   'patientid': 103,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0103'},
#  {'prescriptionid': 'P0104',
#   'patientid': 104,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0104'},
#  {'prescriptionid': 'P0105',
#   'patientid': 105,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0105'},
#  {'prescriptionid': 'P0106',
#   'patientid': 106,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0106'},
#  {'prescriptionid': 'P0107',
#   'patientid': 107,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0107'},
#  {'prescriptionid': 'P0108',
#   'patientid': 108,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0108'},
#  {'prescriptionid': 'P0109',
#   'patientid': 109,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0109'},
#  {'prescriptionid': 'P0110',
#   'patientid': 110,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0110'},
#  {'prescriptionid': 'P0111',
#   'patientid': 111,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0111'},
#  {'prescriptionid': 'P0112',
#   'patientid': 112,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0112'},
#  {'prescriptionid': 'P0113',
#   'patientid': 113,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0113'},
#  {'prescriptionid': 'P0114',
#   'patientid': 114,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0114'},
#  {'prescriptionid': 'P0115',
#   'patientid': 115,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0115'},
#  {'prescriptionid': 'P0116',
#   'patientid': 116,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0116'},
#  {'prescriptionid': 'P0117',
#   'patientid': 117,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0117'},
#  {'prescriptionid': 'P0118',
#   'patientid': 118,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0118'},
#  {'prescriptionid': 'P0119',
#   'patientid': 119,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0119'},
#  {'prescriptionid': 'P0120',
#   'patientid': 120,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0120'},
#  {'prescriptionid': 'P0121',
#   'patientid': 121,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0121'},
#  {'prescriptionid': 'P0122',
#   'patientid': 122,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0122'},
#  {'prescriptionid': 'P0123',
#   'patientid': 123,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0123'},
#  {'prescriptionid': 'P0124',
#   'patientid': 124,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0124'},
#  {'prescriptionid': 'P0125',
#   'patientid': 125,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0125'},
#  {'prescriptionid': 'P0126',
#   'patientid': 126,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0126'},
#  {'prescriptionid': 'P0127',
#   'patientid': 127,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0127'},
#  {'prescriptionid': 'P0128',
#   'patientid': 128,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0128'},
#  {'prescriptionid': 'P0129',
#   'patientid': 129,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0129'},
#  {'prescriptionid': 'P0130',
#   'patientid': 130,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0130'},
#  {'prescriptionid': 'P0131',
#   'patientid': 131,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0131'},
#  {'prescriptionid': 'P0132',
#   'patientid': 132,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0132'},
#  {'prescriptionid': 'P0133',
#   'patientid': 133,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0133'},
#  {'prescriptionid': 'P0134',
#   'patientid': 134,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0134'},
#  {'prescriptionid': 'P0135',
#   'patientid': 135,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0135'},
#  {'prescriptionid': 'P0136',
#   'patientid': 136,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0136'},
#  {'prescriptionid': 'P0137',
#   'patientid': 137,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0137'},
#  {'prescriptionid': 'P0138',
#   'patientid': 138,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0138'},
#  {'prescriptionid': 'P0139',
#   'patientid': 139,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0139'},
#  {'prescriptionid': 'P0140',
#   'patientid': 140,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0140'},
#  {'prescriptionid': 'P0141',
#   'patientid': 141,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0141'},
#  {'prescriptionid': 'P0142',
#   'patientid': 142,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0142'},
#  {'prescriptionid': 'P0143',
#   'patientid': 143,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0143'},
#  {'prescriptionid': 'P0144',
#   'patientid': 144,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0144'},
#  {'prescriptionid': 'P0145',
#   'patientid': 145,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0145'},
#  {'prescriptionid': 'P0146',
#   'patientid': 146,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0146'},
#  {'prescriptionid': 'P0147',
#   'patientid': 147,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0147'},
#  {'prescriptionid': 'P0148',
#   'patientid': 148,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0148'},
#  {'prescriptionid': 'P0149',
#   'patientid': 149,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0149'},
#  {'prescriptionid': 'P0150',
#   'patientid': 150,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0150'},
#  {'prescriptionid': 'P0151',
#   'patientid': 151,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0151'},
#  {'prescriptionid': 'P0152',
#   'patientid': 152,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0152'},
#  {'prescriptionid': 'P0153',
#   'patientid': 153,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0153'},
#  {'prescriptionid': 'P0154',
#   'patientid': 154,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0154'},
#  {'prescriptionid': 'P0155',
#   'patientid': 155,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0155'},
#  {'prescriptionid': 'P0156',
#   'patientid': 156,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0156'},
#  {'prescriptionid': 'P0157',
#   'patientid': 157,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0157'},
#  {'prescriptionid': 'P0158',
#   'patientid': 158,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0158'},
#  {'prescriptionid': 'P0159',
#   'patientid': 159,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0159'},
#  {'prescriptionid': 'P0160',
#   'patientid': 160,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0160'},
#  {'prescriptionid': 'P0161',
#   'patientid': 161,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0161'},
#  {'prescriptionid': 'P0162',
#   'patientid': 162,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0162'},
#  {'prescriptionid': 'P0163',
#   'patientid': 163,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0163'},
#  {'prescriptionid': 'P0164',
#   'patientid': 164,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0164'},
#  {'prescriptionid': 'P0165',
#   'patientid': 165,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0165'},
#  {'prescriptionid': 'P0166',
#   'patientid': 166,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0166'},
#  {'prescriptionid': 'P0167',
#   'patientid': 167,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0167'},
#  {'prescriptionid': 'P0168',
#   'patientid': 168,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0168'},
#  {'prescriptionid': 'P0169',
#   'patientid': 169,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0169'},
#  {'prescriptionid': 'P0170',
#   'patientid': 170,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0170'},
#  {'prescriptionid': 'P0171',
#   'patientid': 171,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0171'},
#  {'prescriptionid': 'P0172',
#   'patientid': 172,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0172'},
#  {'prescriptionid': 'P0173',
#   'patientid': 173,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0173'},
#  {'prescriptionid': 'P0174',
#   'patientid': 174,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0174'},
#  {'prescriptionid': 'P0175',
#   'patientid': 175,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0175'},
#  {'prescriptionid': 'P0176',
#   'patientid': 176,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0176'},
#  {'prescriptionid': 'P0177',
#   'patientid': 177,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0177'},
#  {'prescriptionid': 'P0178',
#   'patientid': 178,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0178'},
#  {'prescriptionid': 'P0179',
#   'patientid': 179,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0179'},
#  {'prescriptionid': 'P0180',
#   'patientid': 180,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0180'},
#  {'prescriptionid': 'P0181',
#   'patientid': 181,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0181'},
#  {'prescriptionid': 'P0182',
#   'patientid': 182,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0182'},
#  {'prescriptionid': 'P0183',
#   'patientid': 183,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0183'},
#  {'prescriptionid': 'P0184',
#   'patientid': 184,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0184'},
#  {'prescriptionid': 'P0185',
#   'patientid': 185,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0185'},
#  {'prescriptionid': 'P0186',
#   'patientid': 186,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0186'},
#  {'prescriptionid': 'P0187',
#   'patientid': 187,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0187'},
#  {'prescriptionid': 'P0188',
#   'patientid': 188,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0188'},
#  {'prescriptionid': 'P0189',
#   'patientid': 189,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0189'},
#  {'prescriptionid': 'P0190',
#   'patientid': 190,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0190'},
#  {'prescriptionid': 'P0191',
#   'patientid': 191,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0191'},
#  {'prescriptionid': 'P0192',
#   'patientid': 192,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0192'},
#  {'prescriptionid': 'P0193',
#   'patientid': 193,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0193'},
#  {'prescriptionid': 'P0194',
#   'patientid': 194,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0194'},
#  {'prescriptionid': 'P0195',
#   'patientid': 195,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0195'},
#  {'prescriptionid': 'P0196',
#   'patientid': 196,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0196'},
#  {'prescriptionid': 'P0197',
#   'patientid': 197,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0197'},
#  {'prescriptionid': 'P0198',
#   'patientid': 198,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0198'},
#  {'prescriptionid': 'P0199',
#   'patientid': 199,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0199'},
#  {'prescriptionid': 'P0200',
#   'patientid': 200,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0200'},
#  {'prescriptionid': 'P0201',
#   'patientid': 201,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0201'},
#  {'prescriptionid': 'P0202',
#   'patientid': 202,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0202'},
#  {'prescriptionid': 'P0203',
#   'patientid': 203,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0203'},
#  {'prescriptionid': 'P0204',
#   'patientid': 204,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0204'},
#  {'prescriptionid': 'P0205',
#   'patientid': 205,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0205'},
#  {'prescriptionid': 'P0206',
#   'patientid': 206,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0206'},
#  {'prescriptionid': 'P0207',
#   'patientid': 207,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0207'},
#  {'prescriptionid': 'P0208',
#   'patientid': 208,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0208'},
#  {'prescriptionid': 'P0209',
#   'patientid': 209,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0209'},
#  {'prescriptionid': 'P0210',
#   'patientid': 210,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0210'},
#  {'prescriptionid': 'P0211',
#   'patientid': 211,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0211'},
#  {'prescriptionid': 'P0212',
#   'patientid': 212,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0212'},
#  {'prescriptionid': 'P0213',
#   'patientid': 213,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0213'},
#  {'prescriptionid': 'P0214',
#   'patientid': 214,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0214'},
#  {'prescriptionid': 'P0215',
#   'patientid': 215,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0215'},
#  {'prescriptionid': 'P0216',
#   'patientid': 216,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0216'},
#  {'prescriptionid': 'P0217',
#   'patientid': 217,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0217'},
#  {'prescriptionid': 'P0218',
#   'patientid': 218,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0218'},
#  {'prescriptionid': 'P0219',
#   'patientid': 219,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0219'},
#  {'prescriptionid': 'P0220',
#   'patientid': 220,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0220'},
#  {'prescriptionid': 'P0221',
#   'patientid': 221,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0221'},
#  {'prescriptionid': 'P0222',
#   'patientid': 222,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0222'},
#  {'prescriptionid': 'P0223',
#   'patientid': 223,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0223'},
#  {'prescriptionid': 'P0224',
#   'patientid': 224,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0224'},
#  {'prescriptionid': 'P0225',
#   'patientid': 225,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0225'},
#  {'prescriptionid': 'P0226',
#   'patientid': 226,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0226'},
#  {'prescriptionid': 'P0227',
#   'patientid': 227,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0227'},
#  {'prescriptionid': 'P0228',
#   'patientid': 228,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0228'},
#  {'prescriptionid': 'P0229',
#   'patientid': 229,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0229'},
#  {'prescriptionid': 'P0230',
#   'patientid': 230,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0230'},
#  {'prescriptionid': 'P0231',
#   'patientid': 231,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0231'},
#  {'prescriptionid': 'P0232',
#   'patientid': 232,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0232'},
#  {'prescriptionid': 'P0233',
#   'patientid': 233,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0233'},
#  {'prescriptionid': 'P0234',
#   'patientid': 234,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0234'},
#  {'prescriptionid': 'P0235',
#   'patientid': 235,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0235'},
#  {'prescriptionid': 'P0236',
#   'patientid': 236,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0236'},
#  {'prescriptionid': 'P0237',
#   'patientid': 237,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0237'},
#  {'prescriptionid': 'P0238',
#   'patientid': 238,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0238'},
#  {'prescriptionid': 'P0239',
#   'patientid': 239,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0239'},
#  {'prescriptionid': 'P0240',
#   'patientid': 240,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0240'},
#  {'prescriptionid': 'P0241',
#   'patientid': 241,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0241'},
#  {'prescriptionid': 'P0242',
#   'patientid': 242,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0242'},
#  {'prescriptionid': 'P0243',
#   'patientid': 243,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0243'},
#  {'prescriptionid': 'P0244',
#   'patientid': 244,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0244'},
#  {'prescriptionid': 'P0245',
#   'patientid': 245,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0245'},
#  {'prescriptionid': 'P0246',
#   'patientid': 246,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0246'},
#  {'prescriptionid': 'P0247',
#   'patientid': 247,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0247'},
#  {'prescriptionid': 'P0248',
#   'patientid': 248,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0248'},
#  {'prescriptionid': 'P0249',
#   'patientid': 249,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0249'},
#  {'prescriptionid': 'P0250',
#   'patientid': 250,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0250'},
#  {'prescriptionid': 'P0251',
#   'patientid': 251,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0251'},
#  {'prescriptionid': 'P0252',
#   'patientid': 252,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0252'},
#  {'prescriptionid': 'P0253',
#   'patientid': 253,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0253'},
#  {'prescriptionid': 'P0254',
#   'patientid': 254,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0254'},
#  {'prescriptionid': 'P0255',
#   'patientid': 255,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0255'},
#  {'prescriptionid': 'P0256',
#   'patientid': 256,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0256'},
#  {'prescriptionid': 'P0257',
#   'patientid': 257,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0257'},
#  {'prescriptionid': 'P0258',
#   'patientid': 258,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0258'},
#  {'prescriptionid': 'P0259',
#   'patientid': 259,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0259'},
#  {'prescriptionid': 'P0260',
#   'patientid': 260,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0260'},
#  {'prescriptionid': 'P0261',
#   'patientid': 261,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0261'},
#  {'prescriptionid': 'P0262',
#   'patientid': 262,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0262'},
#  {'prescriptionid': 'P0263',
#   'patientid': 263,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0263'},
#  {'prescriptionid': 'P0264',
#   'patientid': 264,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0264'},
#  {'prescriptionid': 'P0265',
#   'patientid': 265,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0265'},
#  {'prescriptionid': 'P0266',
#   'patientid': 266,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0266'},
#  {'prescriptionid': 'P0267',
#   'patientid': 267,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0267'},
#  {'prescriptionid': 'P0268',
#   'patientid': 268,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0268'},
#  {'prescriptionid': 'P0269',
#   'patientid': 269,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0269'},
#  {'prescriptionid': 'P0270',
#   'patientid': 270,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0270'},
#  {'prescriptionid': 'P0271',
#   'patientid': 271,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0271'},
#  {'prescriptionid': 'P0272',
#   'patientid': 272,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0272'},
#  {'prescriptionid': 'P0273',
#   'patientid': 273,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0273'},
#  {'prescriptionid': 'P0274',
#   'patientid': 274,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0274'},
#  {'prescriptionid': 'P0275',
#   'patientid': 275,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0275'},
#  {'prescriptionid': 'P0276',
#   'patientid': 276,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0276'},
#  {'prescriptionid': 'P0277',
#   'patientid': 277,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0277'},
#  {'prescriptionid': 'P0278',
#   'patientid': 278,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0278'},
#  {'prescriptionid': 'P0279',
#   'patientid': 279,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0279'},
#  {'prescriptionid': 'P0280',
#   'patientid': 280,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0280'},
#  {'prescriptionid': 'P0281',
#   'patientid': 281,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0281'},
#  {'prescriptionid': 'P0282',
#   'patientid': 282,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0282'},
#  {'prescriptionid': 'P0283',
#   'patientid': 283,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0283'},
#  {'prescriptionid': 'P0284',
#   'patientid': 284,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0284'},
#  {'prescriptionid': 'P0285',
#   'patientid': 285,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0285'},
#  {'prescriptionid': 'P0286',
#   'patientid': 286,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0286'},
#  {'prescriptionid': 'P0287',
#   'patientid': 287,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0287'},
#  {'prescriptionid': 'P0288',
#   'patientid': 288,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0288'},
#  {'prescriptionid': 'P0289',
#   'patientid': 289,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0289'},
#  {'prescriptionid': 'P0290',
#   'patientid': 290,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0290'},
#  {'prescriptionid': 'P0291',
#   'patientid': 291,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0291'},
#  {'prescriptionid': 'P0292',
#   'patientid': 292,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0292'},
#  {'prescriptionid': 'P0293',
#   'patientid': 293,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0293'},
#  {'prescriptionid': 'P0294',
#   'patientid': 294,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0294'},
#  {'prescriptionid': 'P0295',
#   'patientid': 295,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0295'},
#  {'prescriptionid': 'P0296',
#   'patientid': 296,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0296'},
#  {'prescriptionid': 'P0297',
#   'patientid': 297,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0297'},
#  {'prescriptionid': 'P0298',
#   'patientid': 298,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0298'},
#  {'prescriptionid': 'P0299',
#   'patientid': 299,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0299'},
#  {'prescriptionid': 'P0300',
#   'patientid': 300,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0300'},
#  {'prescriptionid': 'P0301',
#   'patientid': 301,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0301'},
#  {'prescriptionid': 'P0302',
#   'patientid': 302,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0302'},
#  {'prescriptionid': 'P0303',
#   'patientid': 303,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0303'},
#  {'prescriptionid': 'P0304',
#   'patientid': 304,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0304'},
#  {'prescriptionid': 'P0305',
#   'patientid': 305,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0305'},
#  {'prescriptionid': 'P0306',
#   'patientid': 306,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0306'},
#  {'prescriptionid': 'P0307',
#   'patientid': 307,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0307'},
#  {'prescriptionid': 'P0308',
#   'patientid': 308,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0308'},
#  {'prescriptionid': 'P0309',
#   'patientid': 309,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0309'},
#  {'prescriptionid': 'P0310',
#   'patientid': 310,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0310'},
#  {'prescriptionid': 'P0311',
#   'patientid': 311,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0311'},
#  {'prescriptionid': 'P0312',
#   'patientid': 312,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0312'},
#  {'prescriptionid': 'P0313',
#   'patientid': 313,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0313'},
#  {'prescriptionid': 'P0314',
#   'patientid': 314,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0314'},
#  {'prescriptionid': 'P0315',
#   'patientid': 315,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0315'},
#  {'prescriptionid': 'P0316',
#   'patientid': 316,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0316'},
#  {'prescriptionid': 'P0317',
#   'patientid': 317,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0317'},
#  {'prescriptionid': 'P0318',
#   'patientid': 318,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0318'},
#  {'prescriptionid': 'P0319',
#   'patientid': 319,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0319'},
#  {'prescriptionid': 'P0320',
#   'patientid': 320,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0320'},
#  {'prescriptionid': 'P0321',
#   'patientid': 321,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0321'},
#  {'prescriptionid': 'P0322',
#   'patientid': 322,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0322'},
#  {'prescriptionid': 'P0323',
#   'patientid': 323,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0323'},
#  {'prescriptionid': 'P0324',
#   'patientid': 324,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0324'},
#  {'prescriptionid': 'P0325',
#   'patientid': 325,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0325'},
#  {'prescriptionid': 'P0326',
#   'patientid': 326,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0326'},
#  {'prescriptionid': 'P0327',
#   'patientid': 327,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0327'},
#  {'prescriptionid': 'P0328',
#   'patientid': 328,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0328'},
#  {'prescriptionid': 'P0329',
#   'patientid': 329,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0329'},
#  {'prescriptionid': 'P0330',
#   'patientid': 330,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0330'},
#  {'prescriptionid': 'P0331',
#   'patientid': 331,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0331'},
#  {'prescriptionid': 'P0332',
#   'patientid': 332,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0332'},
#  {'prescriptionid': 'P0333',
#   'patientid': 333,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0333'},
#  {'prescriptionid': 'P0334',
#   'patientid': 334,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0334'},
#  {'prescriptionid': 'P0335',
#   'patientid': 335,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0335'},
#  {'prescriptionid': 'P0336',
#   'patientid': 336,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0336'},
#  {'prescriptionid': 'P0337',
#   'patientid': 337,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0337'},
#  {'prescriptionid': 'P0338',
#   'patientid': 338,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0338'},
#  {'prescriptionid': 'P0339',
#   'patientid': 339,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0339'},
#  {'prescriptionid': 'P0340',
#   'patientid': 340,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0340'},
#  {'prescriptionid': 'P0341',
#   'patientid': 341,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0341'},
#  {'prescriptionid': 'P0342',
#   'patientid': 342,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0342'},
#  {'prescriptionid': 'P0343',
#   'patientid': 343,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0343'},
#  {'prescriptionid': 'P0344',
#   'patientid': 344,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0344'},
#  {'prescriptionid': 'P0345',
#   'patientid': 345,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0345'},
#  {'prescriptionid': 'P0346',
#   'patientid': 346,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0346'},
#  {'prescriptionid': 'P0347',
#   'patientid': 347,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0347'},
#  {'prescriptionid': 'P0348',
#   'patientid': 348,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0348'},
#  {'prescriptionid': 'P0349',
#   'patientid': 349,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0349'},
#  {'prescriptionid': 'P0350',
#   'patientid': 350,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0350'},
#  {'prescriptionid': 'P0351',
#   'patientid': 351,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0351'},
#  {'prescriptionid': 'P0352',
#   'patientid': 352,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0352'},
#  {'prescriptionid': 'P0353',
#   'patientid': 353,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0353'},
#  {'prescriptionid': 'P0354',
#   'patientid': 354,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0354'},
#  {'prescriptionid': 'P0355',
#   'patientid': 355,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0355'},
#  {'prescriptionid': 'P0356',
#   'patientid': 356,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0356'},
#  {'prescriptionid': 'P0357',
#   'patientid': 357,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0357'},
#  {'prescriptionid': 'P0358',
#   'patientid': 358,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0358'},
#  {'prescriptionid': 'P0359',
#   'patientid': 359,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0359'},
#  {'prescriptionid': 'P0360',
#   'patientid': 360,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0360'},
#  {'prescriptionid': 'P0361',
#   'patientid': 361,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0361'},
#  {'prescriptionid': 'P0362',
#   'patientid': 362,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0362'},
#  {'prescriptionid': 'P0363',
#   'patientid': 363,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0363'},
#  {'prescriptionid': 'P0364',
#   'patientid': 364,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0364'},
#  {'prescriptionid': 'P0365',
#   'patientid': 365,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0365'},
#  {'prescriptionid': 'P0366',
#   'patientid': 366,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0366'},
#  {'prescriptionid': 'P0367',
#   'patientid': 367,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0367'},
#  {'prescriptionid': 'P0368',
#   'patientid': 368,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0368'},
#  {'prescriptionid': 'P0369',
#   'patientid': 369,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0369'},
#  {'prescriptionid': 'P0370',
#   'patientid': 370,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0370'},
#  {'prescriptionid': 'P0371',
#   'patientid': 371,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0371'},
#  {'prescriptionid': 'P0372',
#   'patientid': 372,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0372'},
#  {'prescriptionid': 'P0373',
#   'patientid': 373,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0373'},
#  {'prescriptionid': 'P0374',
#   'patientid': 374,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0374'},
#  {'prescriptionid': 'P0375',
#   'patientid': 375,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0375'},
#  {'prescriptionid': 'P0376',
#   'patientid': 376,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0376'},
#  {'prescriptionid': 'P0377',
#   'patientid': 377,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0377'},
#  {'prescriptionid': 'P0378',
#   'patientid': 378,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0378'},
#  {'prescriptionid': 'P0379',
#   'patientid': 379,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0379'},
#  {'prescriptionid': 'P0380',
#   'patientid': 380,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0380'},
#  {'prescriptionid': 'P0381',
#   'patientid': 381,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0381'},
#  {'prescriptionid': 'P0382',
#   'patientid': 382,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0382'},
#  {'prescriptionid': 'P0383',
#   'patientid': 383,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0383'},
#  {'prescriptionid': 'P0384',
#   'patientid': 384,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0384'},
#  {'prescriptionid': 'P0385',
#   'patientid': 385,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0385'},
#  {'prescriptionid': 'P0386',
#   'patientid': 386,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0386'},
#  {'prescriptionid': 'P0387',
#   'patientid': 387,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0387'},
#  {'prescriptionid': 'P0388',
#   'patientid': 388,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0388'},
#  {'prescriptionid': 'P0389',
#   'patientid': 389,
# ...
#   'patientid': 872,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0872'},
#  {'prescriptionid': 'P0873',
#   'patientid': 873,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0873'},
#  {'prescriptionid': 'P0874',
#   'patientid': 874,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0874'},
#  {'prescriptionid': 'P0875',
#   'patientid': 875,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0875'},
#  {'prescriptionid': 'P0876',
#   'patientid': 876,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0876'},
#  {'prescriptionid': 'P0877',
#   'patientid': 877,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0877'},
#  {'prescriptionid': 'P0878',
#   'patientid': 878,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0878'},
#  {'prescriptionid': 'P0879',
#   'patientid': 879,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0879'},
#  {'prescriptionid': 'P0880',
#   'patientid': 880,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0880'},
#  {'prescriptionid': 'P0881',
#   'patientid': 881,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0881'},
#  {'prescriptionid': 'P0882',
#   'patientid': 882,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0882'},
#  {'prescriptionid': 'P0883',
#   'patientid': 883,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0883'},
#  {'prescriptionid': 'P0884',
#   'patientid': 884,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0884'},
#  {'prescriptionid': 'P0885',
#   'patientid': 885,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0885'},
#  {'prescriptionid': 'P0886',
#   'patientid': 886,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0886'},
#  {'prescriptionid': 'P0887',
#   'patientid': 887,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0887'},
#  {'prescriptionid': 'P0888',
#   'patientid': 888,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0888'},
#  {'prescriptionid': 'P0889',
#   'patientid': 889,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0889'},
#  {'prescriptionid': 'P0890',
#   'patientid': 890,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0890'},
#  {'prescriptionid': 'P0891',
#   'patientid': 891,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0891'},
#  {'prescriptionid': 'P0892',
#   'patientid': 892,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0892'},
#  {'prescriptionid': 'P0893',
#   'patientid': 893,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0893'},
#  {'prescriptionid': 'P0894',
#   'patientid': 894,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0894'},
#  {'prescriptionid': 'P0895',
#   'patientid': 895,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0895'},
#  {'prescriptionid': 'P0896',
#   'patientid': 896,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0896'},
#  {'prescriptionid': 'P0897',
#   'patientid': 897,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0897'},
#  {'prescriptionid': 'P0898',
#   'patientid': 898,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0898'},
#  {'prescriptionid': 'P0899',
#   'patientid': 899,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0899'},
#  {'prescriptionid': 'P0900',
#   'patientid': 900,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0900'},
#  {'prescriptionid': 'P0901',
#   'patientid': 901,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0901'},
#  {'prescriptionid': 'P0902',
#   'patientid': 902,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0902'},
#  {'prescriptionid': 'P0903',
#   'patientid': 903,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0903'},
#  {'prescriptionid': 'P0904',
#   'patientid': 904,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0904'},
#  {'prescriptionid': 'P0905',
#   'patientid': 905,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0905'},
#  {'prescriptionid': 'P0906',
#   'patientid': 906,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0906'},
#  {'prescriptionid': 'P0907',
#   'patientid': 907,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0907'},
#  {'prescriptionid': 'P0908',
#   'patientid': 908,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0908'},
#  {'prescriptionid': 'P0909',
#   'patientid': 909,
#   'medication': 'Penicillin',
#   'drug_quantity': '5ml',
#   '_id': 'P0909'},
#  {'prescriptionid': 'P0910',
#   'patientid': 910,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '2ml',
#   '_id': 'P0910'},
#  {'prescriptionid': 'P0911',
#   'patientid': 911,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0911'},
#  {'prescriptionid': 'P0912',
#   'patientid': 912,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0912'},
#  {'prescriptionid': 'P0913',
#   'patientid': 913,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0913'},
#  {'prescriptionid': 'P0914',
#   'patientid': 914,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0914'},
#  {'prescriptionid': 'P0915',
#   'patientid': 915,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0915'},
#  {'prescriptionid': 'P0916',
#   'patientid': 916,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0916'},
#  {'prescriptionid': 'P0917',
#   'patientid': 917,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0917'},
#  {'prescriptionid': 'P0918',
#   'patientid': 918,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0918'},
#  {'prescriptionid': 'P0919',
#   'patientid': 919,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0919'},
#  {'prescriptionid': 'P0920',
#   'patientid': 920,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0920'},
#  {'prescriptionid': 'P0921',
#   'patientid': 921,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0921'},
#  {'prescriptionid': 'P0922',
#   'patientid': 922,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0922'},
#  {'prescriptionid': 'P0923',
#   'patientid': 923,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0923'},
#  {'prescriptionid': 'P0924',
#   'patientid': 924,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0924'},
#  {'prescriptionid': 'P0925',
#   'patientid': 925,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0925'},
#  {'prescriptionid': 'P0926',
#   'patientid': 926,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0926'},
#  {'prescriptionid': 'P0927',
#   'patientid': 927,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0927'},
#  {'prescriptionid': 'P0928',
#   'patientid': 928,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0928'},
#  {'prescriptionid': 'P0929',
#   'patientid': 929,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0929'},
#  {'prescriptionid': 'P0930',
#   'patientid': 930,
#   'medication': 'Lipitor',
#   'drug_quantity': '5ml',
#   '_id': 'P0930'},
#  {'prescriptionid': 'P0931',
#   'patientid': 931,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0931'},
#  {'prescriptionid': 'P0932',
#   'patientid': 932,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0932'},
#  {'prescriptionid': 'P0933',
#   'patientid': 933,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0933'},
#  {'prescriptionid': 'P0934',
#   'patientid': 934,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0934'},
#  {'prescriptionid': 'P0935',
#   'patientid': 935,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0935'},
#  {'prescriptionid': 'P0936',
#   'patientid': 936,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0936'},
#  {'prescriptionid': 'P0937',
#   'patientid': 937,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0937'},
#  {'prescriptionid': 'P0938',
#   'patientid': 938,
#   'medication': 'Lipitor',
#   'drug_quantity': '10mg',
#   '_id': 'P0938'},
#  {'prescriptionid': 'P0939',
#   'patientid': 939,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0939'},
#  {'prescriptionid': 'P0940',
#   'patientid': 940,
#   'medication': 'Aspirin',
#   'drug_quantity': '10mg',
#   '_id': 'P0940'},
#  {'prescriptionid': 'P0941',
#   'patientid': 941,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0941'},
#  {'prescriptionid': 'P0942',
#   'patientid': 942,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0942'},
#  {'prescriptionid': 'P0943',
#   'patientid': 943,
#   'medication': 'Paracetamol',
#   'drug_quantity': '5ml',
#   '_id': 'P0943'},
#  {'prescriptionid': 'P0944',
#   'patientid': 944,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0944'},
#  {'prescriptionid': 'P0945',
#   'patientid': 945,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0945'},
#  {'prescriptionid': 'P0946',
#   'patientid': 946,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '100mg',
#   '_id': 'P0946'},
#  {'prescriptionid': 'P0947',
#   'patientid': 947,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0947'},
#  {'prescriptionid': 'P0948',
#   'patientid': 948,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0948'},
#  {'prescriptionid': 'P0949',
#   'patientid': 949,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0949'},
#  {'prescriptionid': 'P0950',
#   'patientid': 950,
#   'medication': 'Penicillin',
#   'drug_quantity': '500mg',
#   '_id': 'P0950'},
#  {'prescriptionid': 'P0951',
#   'patientid': 951,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0951'},
#  {'prescriptionid': 'P0952',
#   'patientid': 952,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0952'},
#  {'prescriptionid': 'P0953',
#   'patientid': 953,
#   'medication': 'Paracetamol',
#   'drug_quantity': '100mg',
#   '_id': 'P0953'},
#  {'prescriptionid': 'P0954',
#   'patientid': 954,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0954'},
#  {'prescriptionid': 'P0955',
#   'patientid': 955,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0955'},
#  {'prescriptionid': 'P0956',
#   'patientid': 956,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0956'},
#  {'prescriptionid': 'P0957',
#   'patientid': 957,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0957'},
#  {'prescriptionid': 'P0958',
#   'patientid': 958,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0958'},
#  {'prescriptionid': 'P0959',
#   'patientid': 959,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0959'},
#  {'prescriptionid': 'P0960',
#   'patientid': 960,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0960'},
#  {'prescriptionid': 'P0961',
#   'patientid': 961,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0961'},
#  {'prescriptionid': 'P0962',
#   'patientid': 962,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0962'},
#  {'prescriptionid': 'P0963',
#   'patientid': 963,
#   'medication': 'Aspirin',
#   'drug_quantity': '100mg',
#   '_id': 'P0963'},
#  {'prescriptionid': 'P0964',
#   'patientid': 964,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0964'},
#  {'prescriptionid': 'P0965',
#   'patientid': 965,
#   'medication': 'Paracetamol',
#   'drug_quantity': '2ml',
#   '_id': 'P0965'},
#  {'prescriptionid': 'P0966',
#   'patientid': 966,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0966'},
#  {'prescriptionid': 'P0967',
#   'patientid': 967,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0967'},
#  {'prescriptionid': 'P0968',
#   'patientid': 968,
#   'medication': 'Aspirin',
#   'drug_quantity': '500mg',
#   '_id': 'P0968'},
#  {'prescriptionid': 'P0969',
#   'patientid': 969,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0969'},
#  {'prescriptionid': 'P0970',
#   'patientid': 970,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0970'},
#  {'prescriptionid': 'P0971',
#   'patientid': 971,
#   'medication': 'Paracetamol',
#   'drug_quantity': '10mg',
#   '_id': 'P0971'},
#  {'prescriptionid': 'P0972',
#   'patientid': 972,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0972'},
#  {'prescriptionid': 'P0973',
#   'patientid': 973,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0973'},
#  {'prescriptionid': 'P0974',
#   'patientid': 974,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0974'},
#  {'prescriptionid': 'P0975',
#   'patientid': 975,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0975'},
#  {'prescriptionid': 'P0976',
#   'patientid': 976,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0976'},
#  {'prescriptionid': 'P0977',
#   'patientid': 977,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0977'},
#  {'prescriptionid': 'P0978',
#   'patientid': 978,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0978'},
#  {'prescriptionid': 'P0979',
#   'patientid': 979,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0979'},
#  {'prescriptionid': 'P0980',
#   'patientid': 980,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0980'},
#  {'prescriptionid': 'P0981',
#   'patientid': 981,
#   'medication': 'Penicillin',
#   'drug_quantity': '2ml',
#   '_id': 'P0981'},
#  {'prescriptionid': 'P0982',
#   'patientid': 982,
#   'medication': 'Penicillin',
#   'drug_quantity': '10mg',
#   '_id': 'P0982'},
#  {'prescriptionid': 'P0983',
#   'patientid': 983,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0983'},
#  {'prescriptionid': 'P0984',
#   'patientid': 984,
#   'medication': 'Paracetamol',
#   'drug_quantity': '500mg',
#   '_id': 'P0984'},
#  {'prescriptionid': 'P0985',
#   'patientid': 985,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0985'},
#  {'prescriptionid': 'P0986',
#   'patientid': 986,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0986'},
#  {'prescriptionid': 'P0987',
#   'patientid': 987,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P0987'},
#  {'prescriptionid': 'P0988',
#   'patientid': 988,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0988'},
#  {'prescriptionid': 'P0989',
#   'patientid': 989,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0989'},
#  {'prescriptionid': 'P0990',
#   'patientid': 990,
#   'medication': 'Lipitor',
#   'drug_quantity': '2ml',
#   '_id': 'P0990'},
#  {'prescriptionid': 'P0991',
#   'patientid': 991,
#   'medication': 'Lipitor',
#   'drug_quantity': '100mg',
#   '_id': 'P0991'},
#  {'prescriptionid': 'P0992',
#   'patientid': 992,
#   'medication': 'Aspirin',
#   'drug_quantity': '5ml',
#   '_id': 'P0992'},
#  {'prescriptionid': 'P0993',
#   'patientid': 993,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0993'},
#  {'prescriptionid': 'P0994',
#   'patientid': 994,
#   'medication': 'Aspirin',
#   'drug_quantity': '2ml',
#   '_id': 'P0994'},
#  {'prescriptionid': 'P0995',
#   'patientid': 995,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '5ml',
#   '_id': 'P0995'},
#  {'prescriptionid': 'P0996',
#   'patientid': 996,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '500mg',
#   '_id': 'P0996'},
#  {'prescriptionid': 'P0997',
#   'patientid': 997,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0997'},
#  {'prescriptionid': 'P0998',
#   'patientid': 998,
#   'medication': 'Penicillin',
#   'drug_quantity': '100mg',
#   '_id': 'P0998'},
#  {'prescriptionid': 'P0999',
#   'patientid': 999,
#   'medication': 'Lipitor',
#   'drug_quantity': '500mg',
#   '_id': 'P0999'},
#  {'prescriptionid': 'P1000',
#   'patientid': 1000,
#   'medication': 'Ibuprofen',
#   'drug_quantity': '10mg',
#   '_id': 'P1000'},
#  ...]

# %%
def insert_json_to_mongodb(json_file, mongo_uri, db_name, collection_name):
    # Read the JSON file into a DataFrame
    df = pd.read_json(json_file)
    
    # Establish a connection to the MongoDB database
    client = MongoClient(mongo_uri)
    db = client[db_name]
    collection = db[collection_name]
    
    # Insert records into the collection
    documents = json.loads(df.to_json(orient='records'))
    collection.insert_many(documents)
    
    # Close the connection
    client.close()

# %%
conn_string = "mongodb://localhost:27017/"
db_name = "chatdb"
coll_name = "patients"
insert_json_to_mongodb("patients.json", conn_string, db_name, coll_name)

# %%
conn_string = "mongodb://localhost:27017/"
db_name = "chatdb"
coll_name = "hospitals"
insert_json_to_mongodb("hospitals.json", conn_string, db_name, coll_name)

# %%
conn_string = "mongodb://localhost:27017/"
db_name = "chatdb"
coll_name = "insurance"
insert_json_to_mongodb("insurance.json", conn_string, db_name, coll_name)

# %%
with open('db_schema.json', 'w') as db_file:
    json.dump(new_schema, db_file, indent=4)

# %%
with open("/Users/vedanttibrewal/Documents/USC/lectures/sem_1/DSCI-551/project/chatDB-dsci551/src/chatdb/constants/sql_db_schema.json", 'r') as db_file:
    test = json.load(db_file)

test
# Out:
# {'patients': {'patientid': 'INT',
#   'patientname': 'VARCHAR(255)',
#   'age': 'INT',
#   'gender': 'VARCHAR(255)',
#   'bloodtype': 'VARCHAR(255)',
#   'disease': 'VARCHAR(255)',
#   'pk': ['patientid'],
#   'fk': {}},
#  'insurance': {'insuranceid': 'INT',
#   'patientid': 'INT',
#   'insuranceprovider': 'VARCHAR(255)',
#   'billingcost': 'FLOAT',
#   'benefit': 'VARCHAR(255)',
#   'pk': ['insuranceid'],
#   'fk': {'patients': 'patientid'}},
#  'hospitals': {'admissionid': 'INT',
#   'patientid': 'INT',
#   'insuranceid': 'INT',
#   'doctor': 'VARCHAR(255)',
#   'hospitalname': 'VARCHAR(255)',
#   'intakedate': 'VARCHAR(255)',
#   'dischargedate': 'VARCHAR(255)',
#   'roomnumber': 'INT',
#   'carelevel': 'VARCHAR(255)',
#   'testresults': 'VARCHAR(255)',
#   'pk': ['admissionid'],
#   'fk': {'insurance': 'insuranceid', 'patients': 'patientid'}}}
